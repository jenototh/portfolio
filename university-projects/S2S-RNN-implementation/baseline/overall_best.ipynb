# %% [markdown]
# # Dataset: Simple Split

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.utils as torch_utils
import numpy as np

import random
import math
import time

# %%
import pandas as pd
import numpy as np
import requests
from io import StringIO
from concurrent.futures import ThreadPoolExecutor

def download_file(file_url):
    response = requests.get(file_url)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to fetch the file. Status code: {response.status_code}")
        return None

# URLs of the files you want to download
file_urls = [
    'https://raw.githubusercontent.com/brendenlake/SCAN/master/simple_split/tasks_train_simple.txt',
    'https://raw.githubusercontent.com/brendenlake/SCAN/master/simple_split/tasks_test_simple.txt'  # Replace with the actual URL of the second file
]

# Use ThreadPoolExecutor to download files concurrently
with ThreadPoolExecutor(max_workers=len(file_urls)) as executor:
    results = list(executor.map(download_file, file_urls))

# Check if all downloads were successful
if all(result is not None for result in results):
    # Assuming each line in the text file is a sentence
    sentences_list = [result.split('\n') for result in results]

    # Create DataFrames for each file
    dfs = [pd.DataFrame({'Sentences': sentences}) for sentences in sentences_list]

    # Create DataFrames for each file
    train_df = pd.DataFrame({'Sentences': sentences_list[0]})
    eval_df = pd.DataFrame({'Sentences': sentences_list[1]})
else:
    print("One or more downloads failed.")

# %%
print(train_df.head())
# Out:
#                                            Sentences
# 0  IN: jump opposite right twice and turn opposit...
# 1  IN: run opposite left after walk right OUT: I_...
# 2  IN: walk after run around right twice OUT: I_T...
# 3  IN: look around right thrice and turn left OUT...
# 4  IN: walk opposite left twice and walk opposite...

# %%
SEED = 5392

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from torch.utils.data import Dataset

class SentenceDataset(Dataset):
   def __init__(self, sentences):
       self.sentences = sentences

   def __len__(self):
       return len(self.sentences)

   def __getitem__(self, idx):
       sentence = self.sentences[idx]
       in_sentence = sentence.split('IN:')[1].split('OUT:')[0].strip()
       out_sentence = sentence.split('OUT:')[1].strip()
       return [in_sentence, out_sentence]

# %%
train_set = SentenceDataset(train_df['Sentences'])
eval_set = SentenceDataset(eval_df['Sentences'])

# %%
PAD_token = 0
SOS_token = 1
EOS_token = 2

class Vocab:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "PAD", 1: "SOS", 2: "EOS"}
        self.n_words = 3  # Count PAD SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
def indexesFromSentence(vocab, sentence):
    return [vocab.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(1, -1)

# %%
input_vocab = Vocab('IN')
output_vocab = Vocab('OUT')
for line in train_set:
    input_vocab.addSentence(line[0])
    output_vocab.addSentence(line[1])

# %%
print(input_vocab.word2index)
print(input_vocab.index2word)
# Out:
# {'jump': 3, 'opposite': 4, 'right': 5, 'twice': 6, 'and': 7, 'turn': 8, 'thrice': 9, 'run': 10, 'left': 11, 'after': 12, 'walk': 13, 'around': 14, 'look': 15}
# {0: 'PAD', 1: 'SOS', 2: 'EOS', 3: 'jump', 4: 'opposite', 5: 'right', 6: 'twice', 7: 'and', 8: 'turn', 9: 'thrice', 10: 'run', 11: 'left', 12: 'after', 13: 'walk', 14: 'around', 15: 'look'}

# %% [markdown]
# # DATALOADER

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):
    def __init__(self, dataset, in_voacab, out_vocab):
        self.dataset = dataset
        self.in_vocab = in_voacab
        self.out_vocab = out_vocab
        input_sentences = []
        target_sentences = []
        for line in self.dataset:
            input_sentences.append(line[0])
            target_sentences.append(line[1])
        self.input_sentences = input_sentences
        self.target_sentences = target_sentences


    def __len__(self):
        return len(self.input_sentences)

    def __getitem__(self, idx):
        input_sentence = self.input_sentences[idx]
        target_sentence = self.target_sentences[idx]

        # Convert words to indices using word2index dictionary
        input_indices = indexesFromSentence(self.in_vocab, input_sentence)
        input_indices.append(EOS_token)
        target_indices = indexesFromSentence(self.out_vocab, target_sentence)
        target_indices.append(EOS_token)

        return torch.LongTensor(input_indices).to(device), torch.LongTensor(target_indices).to(device)

# %% [markdown]
# # LSTM encoder decoder

# %%
import torch.nn as nn


class EncoderLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_p=0.5):
        super(EncoderLSTM, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.LSTM = nn.LSTM(hidden_size, hidden_size, num_layers=2, batch_first=True)
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, input):
        embedded = self.dropout(self.embedding(input))

        output, hidden = self.LSTM(embedded)
        return output, hidden

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch

class DecoderLSTM(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.5):
        super(DecoderLSTM, self).__init__()
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.LSTM = nn.LSTM(hidden_size, hidden_size, num_layers=2, batch_first=True)
        self.out = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, encoder_outputs, encoder_hidden, epoch=0, target_tensor=None):
        batch_size = encoder_outputs.size(0)
        decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
        #print("decoder input", decoder_input)
        decoder_hidden = encoder_hidden
        decoder_outputs = []
        if target_tensor is not None:
            target_len = target_tensor.size(1)
        else:
            target_len = 48
        #print("target len:", trg_len)
        #print("decoder hidden", decoder_hidden)

        for i in range(target_len):
            decoder_output, decoder_hidden  = self.forward_step(decoder_input, decoder_hidden)
            decoder_outputs.append(decoder_output)
            #print("decoder single output", decoder_output)
            if target_tensor is not None and epoch < 50000:
                # Teacher forcing: Feed the target as the next input
                #print("target tensor", target_tensor)
                #print("epoch:", epoch)
                decoder_input = target_tensor[:, i].unsqueeze(1) # Teacher forcing
                #print("Decoder input case 1 (target)", decoder_input)
            else:
                # Without teacher forcing: use its own predictions as the next input
                _, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze(-1).detach()  # detach from history as input
                #print("Decoder input case 2 (topi)", decoder_input)

        #print("decoder outputs", decoder_outputs)
        decoder_outputs = torch.cat(decoder_outputs, dim=1)
        decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)
        return decoder_outputs, decoder_hidden, None # We return `None` for consistency in the training loop

    def forward_step(self, input, hidden):
        output = self.dropout(self.embedding(input))
        output = F.relu(output)
        output, hidden = self.LSTM(output, hidden)
        output = self.out(output)
        return output, hidden

# %% [markdown]
# # Train encoder decoder

# %%
import torch.nn.utils as torch_utils

def train_epoch(dataloader, encoder, decoder, encoder_optimizer,
          decoder_optimizer, criterion, epoch, max_norm=5.0):

    total_loss = 0

    input_tensor, target_tensor = next(iter(dataloader))
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    encoder_outputs, encoder_hidden = encoder(input_tensor)
    decoder_outputs, _, _ = decoder(encoder_outputs, encoder_hidden, epoch,target_tensor)

    #print("Decoder that get passed =", decoder_outputs.view(-1, decoder_outputs.size(-1)))
    #print("target_tensor that get passed =", target_tensor.view(-1))
    loss = criterion(
        decoder_outputs.view(-1, decoder_outputs.size(-1)),
        target_tensor.view(-1)
    )

    #print("decoder_outputs", decoder_outputs)
    #print("target_tensor", target_tensor)
    loss.backward()

    # Gradient clipping for both encoder and decoder
    torch_utils.clip_grad_norm_(encoder.parameters(), max_norm)
    torch_utils.clip_grad_norm_(decoder.parameters(), max_norm)

    encoder_optimizer.step()
    decoder_optimizer.step()

    total_loss += loss.item()

    return total_loss
    #return total_loss / len(dataloader)

# %%
import time
import math

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np

def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def train(train_dataloader, encoder, decoder, n_epochs, learning_rate=0.001,
               print_every=100, plot_every=100):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = torch.optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()
    for epoch in range(1, n_epochs + 1):
        loss = train_epoch(train_dataloader, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, epoch)
        print_loss_total += loss
        plot_loss_total += loss

        if epoch % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, epoch / n_epochs),
                                        epoch, epoch / n_epochs * 100, print_loss_avg))

        if epoch % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %%
def evaluate(encoder, decoder, test_sentences, input_lang, output_lang):
    success = 0
    success_partial = 0
    with torch.no_grad():
      for i in range(len(test_sentences)):
          print(i)
          input_sentence = test_sentences[i][0]
          input_tensor = tensorFromSentence(input_lang, input_sentence)

          encoder_outputs, encoder_hidden = encoder(input_tensor)
          decoder_outputs, decoder_hidden, decoder_attn = decoder(encoder_outputs, encoder_hidden, epoch=1)

          _, topi = decoder_outputs.topk(1)
          decoded_ids = topi.squeeze()

          decoded_words = []
          for idx in decoded_ids:
              if idx.item() == EOS_token:
                  break
              decoded_words.append(output_lang.index2word[idx.item()])
          #check exact match between decoded_words and test_dataset[i][1]
          #print("Expected output: " + test_sentences[i][1])
          #print("Predicted output: " + " ".join(decoded_words))

          #check exact match
          if (decoded_words == test_sentences[i][1].split()):
              success = success + 1
              print("succes ", success, "out of", i+1)
          #check partial match
          if (test_sentences[i][1] in " ".join(decoded_words)):
              success_partial = success_partial + 1
              print("partial succes ", success_partial, "out of", i+1)


    print(f"Exact match accuracy: {success / len(test_sentences) * 100:.2f}%")
    print(f"Partial match accuracy: {success_partial / len(test_sentences) * 100:.2f}%")
    return (success / len(test_sentences) * 100)

# %% [markdown]
# # Experiment 1

# %%
indexes_001 = random.sample(range(len(train_set)), 210)
train_set_001= [train_set[i] for i in indexes_001]

indexes_002 = random.sample(range(len(train_set)-1), 420)
train_set_002= [train_set[i] for i in indexes_002]
print(len(indexes_001))
print(len(set(indexes_001)))

indexes_004 = random.sample(range(len(train_set)-1), 840)
train_set_004= [train_set[i] for i in indexes_004]

indexes_008 = random.sample(range(len(train_set)-1), int(len(train_set)*0.08))
train_set_008= [train_set[i] for i in indexes_008]

indexes_016 = random.sample(range(len(train_set)-1), int(len(train_set)*0.16))
train_set_016= [train_set[i] for i in indexes_016]

indexes_032 = random.sample(range(len(train_set)-1), int(len(train_set)*0.32))
train_set_032= [train_set[i] for i in indexes_032]

indexes_64 = random.sample(range(len(train_set)-1), int(len(train_set)*0.64))
train_set_64= [train_set[i] for i in indexes_64]
# Out:
# 210
# 210

# %% [markdown]
# 1%

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set_001, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)

train(train_dataloader, encoder, decoder, 100000, print_every=100, plot_every=500)

# %%
results = []

# %%
eval = [eval_set[i] for i in range(4182)]
encoder.eval()
decoder.eval()
result001 = evaluate(encoder, decoder, eval, input_vocab, output_vocab)
results.append(result001)

# %% [markdown]
# 2%

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set_002, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)


train(train_dataloader, encoder, decoder, 100000, print_every=1000, plot_every=500)
# Out:
# 0m 18s (- 29m 43s) (1000 1%) 0.9912
# 0m 35s (- 28m 49s) (2000 2%) 0.5190
# 0m 52s (- 28m 21s) (3000 3%) 0.3514
# 1m 12s (- 28m 52s) (4000 4%) 0.2424
# 1m 29s (- 28m 15s) (5000 5%) 0.1906
# 1m 46s (- 27m 48s) (6000 6%) 0.1538
# 2m 4s (- 27m 40s) (7000 7%) 0.1147
# 2m 22s (- 27m 19s) (8000 8%) 0.1071
# 2m 39s (- 26m 56s) (9000 9%) 0.0842
# 2m 58s (- 26m 45s) (10000 10%) 0.0720
# 3m 15s (- 26m 22s) (11000 11%) 0.0741
# 3m 33s (- 26m 5s) (12000 12%) 0.0624
# 3m 51s (- 25m 49s) (13000 13%) 0.0431
# 4m 9s (- 25m 30s) (14000 14%) 0.0586
# 4m 26s (- 25m 8s) (15000 15%) 0.0391
# 4m 44s (- 24m 55s) (16000 16%) 0.0402
# 5m 2s (- 24m 35s) (17000 17%) 0.0414
# 5m 19s (- 24m 13s) (18000 18%) 0.0346
# 5m 36s (- 23m 56s) (19000 19%) 0.0427
# 5m 54s (- 23m 36s) (20000 20%) 0.0271
# 6m 12s (- 23m 19s) (21000 21%) 0.0295
# 6m 30s (- 23m 3s) (22000 22%) 0.0280
# 6m 47s (- 22m 45s) (23000 23%) 0.0229
# 7m 5s (- 22m 26s) (24000 24%) 0.0337
# 7m 23s (- 22m 10s) (25000 25%) 0.0211
# 7m 41s (- 21m 52s) (26000 26%) 0.0235
# 7m 58s (- 21m 33s) (27000 27%) 0.0201
# 8m 16s (- 21m 17s) (28000 28%) 0.0190
# 8m 34s (- 20m 58s) (29000 28%) 0.0252
# 8m 51s (- 20m 40s) (30000 30%) 0.0197
# 9m 9s (- 20m 24s) (31000 31%) 0.0224
# 9m 27s (- 20m 6s) (32000 32%) 0.0224
# 9m 44s (- 19m 47s) (33000 33%) 0.0168
# 10m 3s (- 19m 30s) (34000 34%) 0.0158
# 10m 20s (- 19m 12s) (35000 35%) 0.0112
# 10m 38s (- 18m 54s) (36000 36%) 0.0098
# 10m 56s (- 18m 37s) (37000 37%) 0.0193
# 27m 1s (- 2m 40s) (91000 91%) 0.0064
# 27m 18s (- 2m 22s) (92000 92%) 0.0026
# 27m 37s (- 2m 4s) (93000 93%) 0.0300
# 27m 55s (- 1m 46s) (94000 94%) 0.0287
# 28m 13s (- 1m 29s) (95000 95%) 0.0104
# 28m 31s (- 1m 11s) (96000 96%) 0.0027
# 28m 49s (- 0m 53s) (97000 97%) 0.0009
# 29m 6s (- 0m 35s) (98000 98%) 0.0225
# 29m 24s (- 0m 17s) (99000 99%) 0.0462
# 29m 42s (- 0m 0s) (100000 100%) 0.0179

# %%
eval = [eval_set[i] for i in range(4182)]
encoder.eval()
decoder.eval()
result002 = evaluate(encoder, decoder, eval, input_vocab, output_vocab)
results.append(result002)
# Out:
# Streaming output truncated to the last 5000 lines.
# partial succes  628 out of 1374
# 1374
# 1375
# 1376
# succes  459 out of 1377
# partial succes  629 out of 1377
# 1377
# succes  460 out of 1378
# partial succes  630 out of 1378
# 1378
# succes  461 out of 1379
# partial succes  631 out of 1379
# 1379
# succes  462 out of 1380
# partial succes  632 out of 1380
# 1380
# 1381
# 1382
# 1383
# partial succes  633 out of 1384
# 1384
# succes  463 out of 1385
# partial succes  634 out of 1385
# 1385
# succes  464 out of 1386
# partial succes  635 out of 1386
# 1386
# partial succes  636 out of 1387
# 1387
# 1388
# succes  465 out of 1389
# partial succes  637 out of 1389
# 1389
# 1390
# succes  466 out of 1391
# partial succes  638 out of 1391
# 1391
# partial succes  639 out of 1392
# 1392
# 1393
# partial succes  640 out of 1394
# 1394
# 1395
# succes  467 out of 1396
# partial succes  641 out of 1396
# 1396
# 1397
# 1398
# 1399
# succes  468 out of 1400
# partial succes  642 out of 1400
# 1400
# 1401
# succes  469 out of 1402
# partial succes  643 out of 1402
# 1402
# partial succes  644 out of 1403
# 1403
# 1404
# 1405
# partial succes  645 out of 1406
# 1406
# 1407
# succes  470 out of 1408
# partial succes  646 out of 1408
# 1408
# 1409
# 1410
# succes  471 out of 1411
# partial succes  647 out of 1411
# 1411
# 1412
# succes  472 out of 1413
# partial succes  648 out of 1413
# 1413
# 1414
# partial succes  649 out of 1415
# 1415
# 1416
# 1417
# 1418
# 1419
# 1420
# succes  473 out of 1421
# partial succes  650 out of 1421
# 1421
# 1422
# 1423
# 1424
# succes  474 out of 1425
# partial succes  651 out of 1425
# 1425
# 1426
# succes  475 out of 1427
# partial succes  652 out of 1427
# 1427
# 1428
# partial succes  653 out of 1429
# 1429
# succes  476 out of 1430
# partial succes  654 out of 1430
# 1430
# 1431
# succes  477 out of 1432
# partial succes  655 out of 1432
# 1432
# 1433
# succes  478 out of 1434
# partial succes  656 out of 1434
# 1434
# 1435
# 1436
# succes  479 out of 1437
# partial succes  657 out of 1437
# 1437
# 1438
# 1439
# 1440
# 1441
# 1442
# 1443
# succes  480 out of 1444
# partial succes  658 out of 1444
# 1444
# succes  481 out of 1445
# partial succes  659 out of 1445
# 1445
# partial succes  660 out of 1446
# 1446
# 1447
# 1448
# succes  482 out of 1449
# partial succes  661 out of 1449
# 1449
# succes  483 out of 1450
# partial succes  662 out of 1450
# 1450
# partial succes  663 out of 1451
# 1451
# 1452
# partial succes  664 out of 1453
# 1453
# 1454
# 1455
# 1456
# 1457
# succes  484 out of 1458
# partial succes  665 out of 1458
# 1458
# succes  485 out of 1459
# partial succes  666 out of 1459
# 1459
# succes  486 out of 1460
# partial succes  667 out of 1460
# 1460
# succes  487 out of 1461
# partial succes  668 out of 1461
# 1461
# succes  488 out of 1462
# partial succes  669 out of 1462
# 1462
# 1463
# succes  489 out of 1464
# partial succes  670 out of 1464
# 1464
# 1465
# succes  490 out of 1466
# partial succes  671 out of 1466
# 1466
# 1467
# 1468
# succes  491 out of 1469
# partial succes  672 out of 1469
# 1469
# succes  492 out of 1470
# partial succes  673 out of 1470
# 1470
# succes  493 out of 1471
# partial succes  674 out of 1471
# 1471
# partial succes  675 out of 1472
# 1472
# 1473
# succes  494 out of 1474
# partial succes  676 out of 1474
# 1474
# 1475
# succes  495 out of 1476
# partial succes  677 out of 1476
# 1476
# succes  496 out of 1477
# partial succes  678 out of 1477
# 1477
# 1478
# 1479
# partial succes  679 out of 1480
# 1480
# succes  497 out of 1481
# partial succes  680 out of 1481
# 1481
# partial succes  681 out of 1482
# 1482
# 1483
# 1484
# succes  498 out of 1485
# partial succes  682 out of 1485
# 1485
# succes  499 out of 1486
# partial succes  683 out of 1486
# 1486
# 1487
# succes  500 out of 1488
# partial succes  684 out of 1488
# 1488
# 1489
# succes  501 out of 1490
# partial succes  685 out of 1490
# 1490
# 1491
# succes  502 out of 1492
# partial succes  686 out of 1492
# 1492
# succes  503 out of 1493
# partial succes  687 out of 1493
# 1493
# succes  504 out of 1494
# partial succes  688 out of 1494
# 1494
# succes  505 out of 1495
# partial succes  689 out of 1495
# 1495
# 1496
# partial succes  690 out of 1497
# 1497
# succes  506 out of 1498
# partial succes  691 out of 1498
# 1498
# 1499
# 1500
# 1501
# succes  507 out of 1502
# partial succes  692 out of 1502
# 1502
# succes  508 out of 1503
# partial succes  693 out of 1503
# 1503
# 1504
# succes  509 out of 1505
# partial succes  694 out of 1505
# 1505
# succes  510 out of 1506
# partial succes  695 out of 1506
# 1506
# 1507
# 1508
# 1509
# partial succes  696 out of 1510
# 1510
# 1511
# succes  511 out of 1512
# partial succes  697 out of 1512
# 1512
# 1513
# 1514
# 1515
# 1516
# succes  512 out of 1517
# partial succes  698 out of 1517
# 1517
# succes  513 out of 1518
# partial succes  699 out of 1518
# 1518
# 1519
# succes  514 out of 1520
# partial succes  700 out of 1520
# 1520
# 1521
# 1522
# 1523
# succes  515 out of 1524
# partial succes  701 out of 1524
# 1524
# 1525
# succes  516 out of 1526
# partial succes  702 out of 1526
# 1526
# succes  517 out of 1527
# partial succes  703 out of 1527
# 1527
# 1528
# succes  518 out of 1529
# partial succes  704 out of 1529
# 1529
# 1530
# succes  519 out of 1531
# partial succes  705 out of 1531
# 1531
# succes  520 out of 1532
# partial succes  706 out of 1532
# 1532
# succes  521 out of 1533
# partial succes  707 out of 1533
# 1533
# 1534
# 1535
# 1536
# succes  522 out of 1537
# partial succes  708 out of 1537
# 1537
# 1538
# 1539
# succes  523 out of 1540
# partial succes  709 out of 1540
# 1540
# succes  524 out of 1541
# partial succes  710 out of 1541
# 1541
# partial succes  711 out of 1542
# 1542
# 1543
# succes  525 out of 1544
# partial succes  712 out of 1544
# 1544
# 1545
# 1546
# succes  526 out of 1547
# partial succes  713 out of 1547
# 1547
# 1548
# 1549
# 1550
# partial succes  714 out of 1551
# 1551
# partial succes  715 out of 1552
# 1552
# 1553
# succes  527 out of 1554
# partial succes  716 out of 1554
# 1554
# succes  528 out of 1555
# partial succes  717 out of 1555
# 1555
# 1556
# 1557
# succes  529 out of 1558
# partial succes  718 out of 1558
# 1558
# succes  530 out of 1559
# partial succes  719 out of 1559
# 1559
# 1560
# succes  531 out of 1561
# partial succes  720 out of 1561
# 1561
# succes  532 out of 1562
# partial succes  721 out of 1562
# 1562
# 1563
# 1564
# 1565
# 1566
# 1567
# succes  533 out of 1568
# partial succes  722 out of 1568
# 1568
# partial succes  723 out of 1569
# 1569
# 1570
# succes  534 out of 1571
# partial succes  724 out of 1571
# 1571
# partial succes  725 out of 1572
# 1572
# 1573
# succes  535 out of 1574
# partial succes  726 out of 1574
# 1574
# 1575
# 1576
# succes  536 out of 1577
# partial succes  727 out of 1577
# 1577
# 1578
# 1579
# 1580
# 1581
# succes  537 out of 1582
# partial succes  728 out of 1582
# 1582
# succes  538 out of 1583
# partial succes  729 out of 1583
# 1583
# 1584
# 1585
# succes  539 out of 1586
# partial succes  730 out of 1586
# 1586
# 1587
# partial succes  731 out of 1588
# 1588
# 1589
# 1590
# 1591
# succes  540 out of 1592
# partial succes  732 out of 1592
# 1592
# 1593
# 1594
# 1595
# 1596
# 1597
# 1598
# 1599
# 1600
# succes  541 out of 1601
# partial succes  733 out of 1601
# 1601
# partial succes  734 out of 1602
# 1602
# succes  542 out of 1603
# partial succes  735 out of 1603
# 1603
# 1604
# succes  543 out of 1605
# partial succes  736 out of 1605
# 1605
# 1606
# 1607
# 1608
# 1609
# 1610
# succes  544 out of 1611
# partial succes  737 out of 1611
# 1611
# 1612
# succes  545 out of 1613
# partial succes  738 out of 1613
# 1613
# succes  546 out of 1614
# partial succes  739 out of 1614
# 1614
# 1615
# 1616
# succes  547 out of 1617
# partial succes  740 out of 1617
# 1617
# succes  548 out of 1618
# partial succes  741 out of 1618
# 1618
# 1619
# 1620
# 1621
# 1622
# succes  549 out of 1623
# partial succes  742 out of 1623
# 1623
# 1624
# succes  550 out of 1625
# partial succes  743 out of 1625
# 1625
# succes  551 out of 1626
# partial succes  744 out of 1626
# 1626
# 1627
# 1628
# 1629
# 1630
# succes  552 out of 1631
# partial succes  745 out of 1631
# 1631
# 1632
# 1633
# 1634
# 1635
# succes  553 out of 1636
# partial succes  746 out of 1636
# 1636
# 1637
# succes  554 out of 1638
# partial succes  747 out of 1638
# 1638
# succes  555 out of 1639
# partial succes  748 out of 1639
# 1639
# 1640
# succes  556 out of 1641
# partial succes  749 out of 1641
# 1641
# 1642
# 1643
# partial succes  750 out of 1644
# 1644
# 1645
# succes  557 out of 1646
# partial succes  751 out of 1646
# 1646
# succes  558 out of 1647
# partial succes  752 out of 1647
# 1647
# 1648
# 1649
# 1650
# 1651
# succes  559 out of 1652
# partial succes  753 out of 1652
# 1652
# 1653
# 1654
# succes  560 out of 1655
# partial succes  754 out of 1655
# 1655
# succes  561 out of 1656
# partial succes  755 out of 1656
# 1656
# 1657
# 1658
# succes  562 out of 1659
# partial succes  756 out of 1659
# 1659
# 1660
# 1661
# 1662
# partial succes  757 out of 1663
# 1663
# 1664
# 1665
# partial succes  758 out of 1666
# 1666
# 1667
# succes  563 out of 1668
# partial succes  759 out of 1668
# 1668
# succes  564 out of 1669
# partial succes  760 out of 1669
# 1669
# 1670
# succes  565 out of 1671
# partial succes  761 out of 1671
# 1671
# succes  566 out of 1672
# partial succes  762 out of 1672
# 1672
# succes  567 out of 1673
# partial succes  763 out of 1673
# 1673
# 1674
# 1675
# partial succes  764 out of 1676
# 1676
# 1677
# succes  568 out of 1678
# partial succes  765 out of 1678
# 1678
# 1679
# partial succes  766 out of 1680
# 1680
# 1681
# 1682
# 1683
# 1684
# partial succes  767 out of 1685
# 1685
# 1686
# 1687
# succes  569 out of 1688
# partial succes  768 out of 1688
# 1688
# 1689
# succes  570 out of 1690
# partial succes  769 out of 1690
# 1690
# partial succes  770 out of 1691
# 1691
# succes  571 out of 1692
# partial succes  771 out of 1692
# 1692
# 1693
# 1694
# 1695
# 1696
# succes  572 out of 1697
# partial succes  772 out of 1697
# 1697
# 1698
# succes  573 out of 1699
# partial succes  773 out of 1699
# 1699
# 1700
# partial succes  774 out of 1701
# 1701
# 1702
# 1703
# 1704
# partial succes  775 out of 1705
# 1705
# partial succes  776 out of 1706
# 1706
# succes  574 out of 1707
# partial succes  777 out of 1707
# 1707
# 1708
# partial succes  778 out of 1709
# 1709
# succes  575 out of 1710
# partial succes  779 out of 1710
# 1710
# succes  576 out of 1711
# partial succes  780 out of 1711
# 1711
# 1712
# partial succes  781 out of 1713
# 1713
# 1714
# partial succes  782 out of 1715
# 1715
# succes  577 out of 1716
# partial succes  783 out of 1716
# 1716
# 1717
# 1718
# succes  578 out of 1719
# partial succes  784 out of 1719
# 1719
# partial succes  785 out of 1720
# 1720
# succes  579 out of 1721
# partial succes  786 out of 1721
# 1721
# 1722
# succes  580 out of 1723
# partial succes  787 out of 1723
# 1723
# 1724
# succes  581 out of 1725
# partial succes  788 out of 1725
# 1725
# 1726
# 1727
# partial succes  789 out of 1728
# 1728
# succes  582 out of 1729
# partial succes  790 out of 1729
# 1729
# succes  583 out of 1730
# partial succes  791 out of 1730
# 1730
# succes  584 out of 1731
# partial succes  792 out of 1731
# 1731
# succes  585 out of 1732
# partial succes  793 out of 1732
# 1732
# 1733
# 1734
# succes  586 out of 1735
# partial succes  794 out of 1735
# 1735
# succes  587 out of 1736
# partial succes  795 out of 1736
# 1736
# 1737
# 1738
# 1739
# 1740
# 1741
# succes  588 out of 1742
# partial succes  796 out of 1742
# 1742
# 1743
# succes  589 out of 1744
# partial succes  797 out of 1744
# 1744
# succes  590 out of 1745
# partial succes  798 out of 1745
# 1745
# 1746
# succes  591 out of 1747
# partial succes  799 out of 1747
# 1747
# succes  592 out of 1748
# partial succes  800 out of 1748
# 1748
# 1749
# partial succes  801 out of 1750
# 1750
# 1751
# succes  593 out of 1752
# partial succes  802 out of 1752
# 1752
# succes  594 out of 1753
# partial succes  803 out of 1753
# 1980
# 1981
# 1982
# succes  666 out of 1983
# partial succes  896 out of 1983
# 1983
# 1984
# 1985
# 1986
# 1987
# succes  667 out of 1988
# partial succes  897 out of 1988
# 1988
# succes  668 out of 1989
# partial succes  898 out of 1989
# 1989
# partial succes  899 out of 1990
# 1990
# 1991
# 1992
# 1993
# 1994
# partial succes  900 out of 1995
# 1995
# partial succes  901 out of 1996
# 1996
# succes  669 out of 1997
# partial succes  902 out of 1997
# 1997
# 1998
# 1999
# 2000
# succes  670 out of 2001
# partial succes  903 out of 2001
# 2001
# 2002
# succes  671 out of 2003
# partial succes  904 out of 2003
# 2003
# succes  672 out of 2004
# partial succes  905 out of 2004
# 2004
# partial succes  906 out of 2005
# 2005
# partial succes  907 out of 2006
# 2006
# 2007
# partial succes  908 out of 2008
# 2008
# 2009
# succes  673 out of 2010
# partial succes  909 out of 2010
# 2010
# 2011
# 2012
# 2013
# succes  674 out of 2014
# partial succes  910 out of 2014
# 2014
# partial succes  911 out of 2015
# 2015
# succes  675 out of 2016
# partial succes  912 out of 2016
# 2016
# succes  676 out of 2017
# partial succes  913 out of 2017
# 2017
# partial succes  914 out of 2018
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023
# succes  677 out of 2024
# partial succes  915 out of 2024
# 2024
# 2025
# 2026
# 2027
# succes  678 out of 2028
# partial succes  916 out of 2028
# 2028
# 2029
# 2030
# succes  679 out of 2031
# partial succes  917 out of 2031
# 2031
# succes  680 out of 2032
# partial succes  918 out of 2032
# 2032
# succes  681 out of 2033
# partial succes  919 out of 2033
# 2033
# 2034
# partial succes  920 out of 2035
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# succes  682 out of 2041
# partial succes  921 out of 2041
# 2041
# partial succes  922 out of 2042
# 2042
# 2043
# 2044
# 2045
# 2046
# partial succes  923 out of 2047
# 2047
# succes  683 out of 2048
# partial succes  924 out of 2048
# 2048
# succes  684 out of 2049
# partial succes  925 out of 2049
# 2049
# succes  685 out of 2050
# partial succes  926 out of 2050
# 2050
# partial succes  927 out of 2051
# 2051
# 2052
# 2053
# succes  686 out of 2054
# partial succes  928 out of 2054
# 2054
# 2055
# 2056
# 2057
# succes  687 out of 2058
# partial succes  929 out of 2058
# 2058
# 2059
# 2060
# partial succes  930 out of 2061
# 2061
# partial succes  931 out of 2062
# 2062
# succes  688 out of 2063
# partial succes  932 out of 2063
# 2063
# succes  689 out of 2064
# partial succes  933 out of 2064
# 2064
# 2065
# partial succes  934 out of 2066
# 2066
# succes  690 out of 2067
# partial succes  935 out of 2067
# 2067
# succes  691 out of 2068
# partial succes  936 out of 2068
# 2068
# 2069
# succes  692 out of 2070
# partial succes  937 out of 2070
# 2070
# 2071
# succes  693 out of 2072
# partial succes  938 out of 2072
# 2072
# succes  694 out of 2073
# partial succes  939 out of 2073
# 2073
# succes  695 out of 2074
# partial succes  940 out of 2074
# 2074
# partial succes  941 out of 2075
# 2075
# succes  696 out of 2076
# partial succes  942 out of 2076
# 2076
# succes  697 out of 2077
# partial succes  943 out of 2077
# 2077
# partial succes  944 out of 2078
# 2078
# succes  698 out of 2079
# partial succes  945 out of 2079
# 2079
# 2080
# succes  699 out of 2081
# partial succes  946 out of 2081
# 2081
# succes  700 out of 2082
# partial succes  947 out of 2082
# 2082
# 2083
# 2084
# 2085
# 2086
# succes  701 out of 2087
# partial succes  948 out of 2087
# 2087
# partial succes  949 out of 2088
# 2088
# 2089
# partial succes  950 out of 2090
# 2090
# succes  702 out of 2091
# partial succes  951 out of 2091
# 2091
# succes  703 out of 2092
# partial succes  952 out of 2092
# 2092
# partial succes  953 out of 2093
# 2093
# succes  704 out of 2094
# partial succes  954 out of 2094
# 2094
# succes  705 out of 2095
# partial succes  955 out of 2095
# 2095
# partial succes  956 out of 2096
# 2096
# 2097
# 2098
# 2099
# partial succes  957 out of 2100
# 2100
# 2101
# 2102
# succes  706 out of 2103
# partial succes  958 out of 2103
# 2103
# 2104
# succes  707 out of 2105
# partial succes  959 out of 2105
# 2105
# 2106
# 2107
# partial succes  960 out of 2108
# 2108
# 2109
# 2110
# 2111
# succes  708 out of 2112
# partial succes  961 out of 2112
# 2112
# succes  709 out of 2113
# partial succes  962 out of 2113
# 2113
# 2114
# succes  710 out of 2115
# partial succes  963 out of 2115
# 2115
# succes  711 out of 2116
# partial succes  964 out of 2116
# 2116
# partial succes  965 out of 2117
# 2117
# 2118
# 2119
# 2120
# 2121
# 2122
# 2123
# 2124
# 2125
# 2126
# partial succes  966 out of 2127
# 2127
# 2128
# succes  712 out of 2129
# partial succes  967 out of 2129
# 2129
# succes  713 out of 2130
# partial succes  968 out of 2130
# 2130
# 2131
# 2132
# 2133
# 2134
# 2135
# 2136
# 2137
# 2138
# partial succes  969 out of 2139
# 2139
# 2140
# partial succes  970 out of 2141
# 2141
# 2142
# 2143
# 2144
# succes  714 out of 2145
# partial succes  971 out of 2145
# 2145
# partial succes  972 out of 2146
# 2146
# 2147
# succes  715 out of 2148
# partial succes  973 out of 2148
# 2148
# succes  716 out of 2149
# partial succes  974 out of 2149
# 2149
# 2150
# partial succes  975 out of 2151
# 2151
# succes  717 out of 2152
# partial succes  976 out of 2152
# 2152
# succes  718 out of 2153
# partial succes  977 out of 2153
# 2153
# 2154
# partial succes  978 out of 2155
# 2155
# 2156
# 2157
# partial succes  979 out of 2158
# 2158
# 2159
# 2160
# succes  719 out of 2161
# partial succes  980 out of 2161
# 2161
# 2162
# 2163
# partial succes  981 out of 2164
# 2164
# 2165
# succes  720 out of 2166
# partial succes  982 out of 2166
# 2166
# 2167
# succes  721 out of 2168
# partial succes  983 out of 2168
# 2168
# partial succes  984 out of 2169
# 2169
# succes  722 out of 2170
# partial succes  985 out of 2170
# 2170
# 2171
# 2172
# 2173
# 2174
# 2175
# 2176
# 2177
# succes  723 out of 2178
# partial succes  986 out of 2178
# 2178
# 2179
# 2180
# partial succes  987 out of 2181
# 2181
# succes  724 out of 2182
# partial succes  988 out of 2182
# 2182
# 2183
# succes  725 out of 2184
# partial succes  989 out of 2184
# 2184
# 2185
# 2186
# succes  726 out of 2187
# partial succes  990 out of 2187
# 2187
# 2188
# 2189
# succes  727 out of 2190
# partial succes  991 out of 2190
# 2190
# 2191
# 2192
# 2193
# partial succes  992 out of 2194
# 2194
# 2195
# 2196
# 2197
# succes  728 out of 2198
# partial succes  993 out of 2198
# 2198
# 2199
# succes  729 out of 2200
# partial succes  994 out of 2200
# 2200
# 2201
# partial succes  995 out of 2202
# 2202
# 2203
# succes  730 out of 2204
# partial succes  996 out of 2204
# 2204
# 2205
# succes  731 out of 2206
# partial succes  997 out of 2206
# 2206
# succes  732 out of 2207
# partial succes  998 out of 2207
# 2207
# 2208
# 2209
# 2210
# 2211
# succes  733 out of 2212
# partial succes  999 out of 2212
# 2212
# succes  734 out of 2213
# partial succes  1000 out of 2213
# 2213
# 2214
# 2215
# 2216
# 2217
# succes  735 out of 2218
# partial succes  1001 out of 2218
# 2218
# partial succes  1002 out of 2219
# 2219
# 2220
# succes  736 out of 2221
# partial succes  1003 out of 2221
# 2221
# 2222
# partial succes  1004 out of 2223
# 2223
# 2224
# succes  737 out of 2225
# partial succes  1005 out of 2225
# 2225
# 2226
# 2227
# succes  738 out of 2228
# partial succes  1006 out of 2228
# 2228
# succes  739 out of 2229
# partial succes  1007 out of 2229
# 2229
# 2230
# 2231
# 2232
# 2233
# 2234
# succes  740 out of 2235
# partial succes  1008 out of 2235
# 2235
# 2236
# succes  741 out of 2237
# partial succes  1009 out of 2237
# 2237
# 2238
# 2239
# 2240
# succes  742 out of 2241
# partial succes  1010 out of 2241
# 2241
# succes  743 out of 2242
# partial succes  1011 out of 2242
# 2242
# succes  744 out of 2243
# partial succes  1012 out of 2243
# 2243
# 2244
# 2245
# partial succes  1013 out of 2246
# 2246
# succes  745 out of 2247
# partial succes  1014 out of 2247
# 2247
# succes  746 out of 2248
# partial succes  1015 out of 2248
# 2248
# partial succes  1016 out of 2249
# 2249
# 2250
# succes  747 out of 2251
# partial succes  1017 out of 2251
# 2251
# 2252
# succes  748 out of 2253
# partial succes  1018 out of 2253
# 2253
# partial succes  1019 out of 2254
# 2254
# 2255
# 2256
# 2257
# succes  749 out of 2258
# partial succes  1020 out of 2258
# 2258
# 2259
# 2260
# succes  750 out of 2261
# partial succes  1021 out of 2261
# 2261
# 2262
# partial succes  1022 out of 2263
# 2263
# 2264
# succes  751 out of 2265
# partial succes  1023 out of 2265
# 2265
# succes  752 out of 2266
# partial succes  1024 out of 2266
# 2266
# 2267
# succes  753 out of 2268
# partial succes  1025 out of 2268
# 2268
# 2269
# 2270
# 2271
# 2272
# 2273
# 2274
# 2275
# 2276
# succes  754 out of 2277
# partial succes  1026 out of 2277
# 2277
# 2278
# succes  755 out of 2279
# partial succes  1027 out of 2279
# 2279
# succes  756 out of 2280
# partial succes  1028 out of 2280
# 2280
# 2281
# 2282
# 2283
# succes  757 out of 2284
# partial succes  1029 out of 2284
# 2284
# 2285
# succes  758 out of 2286
# partial succes  1030 out of 2286
# 2286
# 2287
# 2288
# partial succes  1031 out of 2289
# 2289
# 2290
# 2291
# partial succes  1032 out of 2292
# 2292
# succes  759 out of 2293
# partial succes  1033 out of 2293
# 2293
# succes  760 out of 2294
# partial succes  1034 out of 2294
# 2294
# 2295
# 2296
# 2297
# succes  761 out of 2298
# partial succes  1035 out of 2298
# 2298
# succes  762 out of 2299
# partial succes  1036 out of 2299
# 2299
# partial succes  1037 out of 2300
# 2300
# succes  763 out of 2301
# partial succes  1038 out of 2301
# 2301
# succes  764 out of 2302
# partial succes  1039 out of 2302
# 2302
# 2303
# 2304
# 2305
# succes  765 out of 2306
# partial succes  1040 out of 2306
# 2306
# 2307
# succes  766 out of 2308
# partial succes  1041 out of 2308
# 2308
# 2309
# succes  767 out of 2310
# partial succes  1042 out of 2310
# 2310
# succes  768 out of 2311
# partial succes  1043 out of 2311
# 2311
# 2312
# partial succes  1044 out of 2313
# 2313
# 2314
# succes  769 out of 2315
# partial succes  1045 out of 2315
# 2315
# 2316
# 2317
# succes  770 out of 2318
# partial succes  1046 out of 2318
# 2318
# 2319
# 2320
# partial succes  1047 out of 2321
# 2321
# 2322
# 2323
# 2324
# succes  771 out of 2325
# partial succes  1048 out of 2325
# 2325
# partial succes  1049 out of 2326
# 2326
# 2327
# succes  772 out of 2328
# partial succes  1050 out of 2328
# 2328
# succes  773 out of 2329
# partial succes  1051 out of 2329
# 2329
# succes  774 out of 2330
# partial succes  1052 out of 2330
# 2330
# partial succes  1053 out of 2331
# 2331
# 2332
# 2333
# succes  775 out of 2334
# partial succes  1054 out of 2334
# 2334
# 2335
# 2336
# 2337
# 2338
# 2339
# 2340
# 2341
# 2342
# 2343
# partial succes  1055 out of 2344
# 2344
# succes  776 out of 2345
# partial succes  1056 out of 2345
# 2345
# 2346
# succes  777 out of 2347
# partial succes  1057 out of 2347
# 2347
# 2348
# succes  778 out of 2349
# partial succes  1058 out of 2349
# 2349
# 2350
# succes  779 out of 2351
# partial succes  1059 out of 2351
# 2351
# 2352
# succes  780 out of 2353
# partial succes  1060 out of 2353
# 2353
# 2354
# succes  781 out of 2355
# partial succes  1061 out of 2355
# 2355
# 2356
# 2357
# 2358
# succes  782 out of 2359
# partial succes  1062 out of 2359
# 2359
# succes  783 out of 2360
# partial succes  1063 out of 2360
# 2360
# 2361
# 2362
# 2363
# partial succes  1064 out of 2364
# 2364
# succes  784 out of 2365
# partial succes  1065 out of 2365
# 2365
# succes  785 out of 2366
# partial succes  1066 out of 2366
# 2366
# partial succes  1067 out of 2367
# 2367
# 2368
# partial succes  1068 out of 2369
# 2369
# 2370
# succes  786 out of 2371
# partial succes  1069 out of 2371
# 2371
# succes  787 out of 2372
# partial succes  1070 out of 2372
# 2372
# 2373
# partial succes  1071 out of 2374
# 2374
# 2375
# 2376
# partial succes  1072 out of 2377
# 2377
# partial succes  1073 out of 2378
# 2378
# succes  788 out of 2379
# partial succes  1074 out of 2379
# 2379
# partial succes  1075 out of 2380
# 2380
# succes  789 out of 2381
# partial succes  1076 out of 2381
# 2381
# 2382
# 2383
# 2384
# partial succes  1077 out of 2385
# 2385
# 2386
# 2387
# partial succes  1078 out of 2388
# 2388
# 2389
# 2390
# 2391
# 2392
# partial succes  1079 out of 2393
# 2393
# 2394
# 2395
# succes  790 out of 2396
# partial succes  1080 out of 2396
# 2396
# succes  791 out of 2397
# partial succes  1081 out of 2397
# 2397
# succes  792 out of 2398
# partial succes  1082 out of 2398
# 2398
# 2399
# 2400
# 2401
# 2402
# 2403
# 2404
# 2405
# succes  793 out of 2406
# partial succes  1083 out of 2406
# 2406
# 2407
# succes  794 out of 2408
# partial succes  1084 out of 2408
# 2408
# 2409
# 2410
# 2411
# succes  795 out of 2412
# partial succes  1085 out of 2412
# 2412
# 2413
# succes  796 out of 2414
# partial succes  1086 out of 2414
# 2414
# 2415
# 2416
# 2417
# 2418
# 2419
# succes  797 out of 2420
# partial succes  1087 out of 2420
# 2420
# succes  798 out of 2421
# partial succes  1088 out of 2421
# 2421
# succes  799 out of 2422
# partial succes  1089 out of 2422
# 2422
# 2423
# 2424
# partial succes  1090 out of 2425
# 2425
# 2426
# succes  800 out of 2427
# partial succes  1091 out of 2427
# 2427
# 2428
# 2429
# 2430
# 2431
# 2432
# partial succes  1092 out of 2433
# 2433
# succes  801 out of 2434
# partial succes  1093 out of 2434
# 2434
# succes  802 out of 2435
# partial succes  1094 out of 2435
# 2435
# succes  803 out of 2436
# partial succes  1095 out of 2436
# 2436
# 2437
# succes  804 out of 2438
# partial succes  1096 out of 2438
# 2438
# partial succes  1097 out of 2439
# 2439
# 2440
# succes  805 out of 2441
# partial succes  1098 out of 2441
# 2441
# succes  806 out of 2442
# partial succes  1099 out of 2442
# 2442
# succes  807 out of 2443
# partial succes  1100 out of 2443
# 2443
# 2444
# 2445
# 2446
# partial succes  1101 out of 2447
# 2447
# 2448
# succes  808 out of 2449
# partial succes  1102 out of 2449
# 2449
# succes  809 out of 2450
# partial succes  1103 out of 2450
# 2450
# succes  810 out of 2451
# partial succes  1104 out of 2451
# 2451
# 2452
# succes  811 out of 2453
# partial succes  1105 out of 2453
# 2453
# 2454
# succes  812 out of 2455
# partial succes  1106 out of 2455
# 2455
# succes  813 out of 2456
# partial succes  1107 out of 2456
# 2456
# 2457
# succes  814 out of 2458
# partial succes  1108 out of 2458
# 2458
# 2459
# 2460
# 2461
# 2462
# succes  815 out of 2463
# partial succes  1109 out of 2463
# 2463
# 2464
# 2465
# 2466
# 2467
# succes  816 out of 2468
# partial succes  1110 out of 2468
# 2468
# 2469
# 2470
# partial succes  1111 out of 2471
# 2471
# 2472
# partial succes  1112 out of 2473
# 2473
# 2474
# succes  817 out of 2475
# partial succes  1113 out of 2475
# 2475
# 2476
# succes  818 out of 2477
# partial succes  1114 out of 2477
# 2477
# succes  819 out of 2478
# partial succes  1115 out of 2478
# 2478
# 2479
# 2480
# 2481
# 2482
# succes  820 out of 2483
# partial succes  1116 out of 2483
# 2483
# succes  821 out of 2484
# partial succes  1117 out of 2484
# 2484
# 2485
# 2486
# 2487
# 2488
# succes  822 out of 2489
# partial succes  1118 out of 2489
# 2489
# 2490
# succes  823 out of 2491
# partial succes  1119 out of 2491
# 2491
# 2492
# 2493
# 2494
# succes  824 out of 2495
# partial succes  1120 out of 2495
# 2495
# 2496
# succes  825 out of 2497
# partial succes  1121 out of 2497
# 2497
# 2498
# 2499
# partial succes  1122 out of 2500
# 2500
# succes  826 out of 2501
# partial succes  1123 out of 2501
# 2501
# 2502
# 2503
# succes  827 out of 2504
# partial succes  1124 out of 2504
# 2504
# 2505
# partial succes  1125 out of 2506
# 2506
# 2507
# 2508
# 2509
# succes  828 out of 2510
# partial succes  1126 out of 2510
# 2510
# 2511
# partial succes  1127 out of 2512
# 2512
# 2513
# 2514
# 2515
# 2516
# 2517
# 2518
# partial succes  1128 out of 2519
# 2519
# succes  829 out of 2520
# partial succes  1129 out of 2520
# 2520
# succes  830 out of 2521
# partial succes  1130 out of 2521
# 2521
# 2522
# succes  831 out of 2523
# partial succes  1131 out of 2523
# 2523
# 2524
# partial succes  1132 out of 2525
# 2525
# partial succes  1133 out of 2526
# 2526
# 2527
# 2528
# 2529
# 2530
# partial succes  1134 out of 2531
# 2531
# succes  832 out of 2532
# partial succes  1135 out of 2532
# 2532
# 2533
# succes  833 out of 2534
# partial succes  1136 out of 2534
# 2534
# 2535
# 2536
# 2537
# 2538
# 2539
# partial succes  1137 out of 2540
# 2540
# succes  834 out of 2541
# partial succes  1138 out of 2541
# 2541
# 2542
# 2543
# 2544
# 2545
# 2546
# partial succes  1139 out of 2547
# 2547
# succes  835 out of 2548
# partial succes  1140 out of 2548
# 2548
# 2549
# succes  836 out of 2550
# partial succes  1141 out of 2550
# 2550
# 2551
# 2552
# succes  837 out of 2553
# partial succes  1142 out of 2553
# 2553
# 2554
# 2555
# 2556
# 2557
# 2558
# succes  838 out of 2559
# partial succes  1143 out of 2559
# 2559
# succes  839 out of 2560
# partial succes  1144 out of 2560
# 2560
# partial succes  1145 out of 2561
# 2561
# succes  840 out of 2562
# partial succes  1146 out of 2562
# 2562
# 2563
# succes  841 out of 2564
# partial succes  1147 out of 2564
# 2564
# succes  842 out of 2565
# partial succes  1148 out of 2565
# 2565
# succes  843 out of 2566
# partial succes  1149 out of 2566
# 2566
# 2567
# succes  844 out of 2568
# partial succes  1150 out of 2568
# 2568
# 2569
# 2570
# 2571
# 2572
# succes  845 out of 2573
# partial succes  1151 out of 2573
# 2573
# 2574
# succes  846 out of 2575
# partial succes  1152 out of 2575
# 2575
# partial succes  1153 out of 2576
# 2576
# succes  847 out of 2577
# partial succes  1154 out of 2577
# 2577
# succes  848 out of 2578
# partial succes  1155 out of 2578
# 2578
# 2579
# succes  849 out of 2580
# partial succes  1156 out of 2580
# 2580
# partial succes  1157 out of 2581
# 2581
# 2582
# 2583
# 2584
# 2585
# 2586
# 2587
# succes  850 out of 2588
# partial succes  1158 out of 2588
# 2588
# succes  851 out of 2589
# partial succes  1159 out of 2589
# 2589
# succes  852 out of 2590
# partial succes  1160 out of 2590
# 2590
# succes  853 out of 2591
# partial succes  1161 out of 2591
# 2591
# succes  854 out of 2592
# partial succes  1162 out of 2592
# 2592
# succes  855 out of 2593
# partial succes  1163 out of 2593
# 2593
# succes  856 out of 2594
# partial succes  1164 out of 2594
# 2594
# succes  857 out of 2595
# partial succes  1165 out of 2595
# 2595
# 2596
# succes  858 out of 2597
# partial succes  1166 out of 2597
# 2597
# 2598
# succes  859 out of 2599
# partial succes  1167 out of 2599
# 2599
# 2600
# succes  860 out of 2601
# partial succes  1168 out of 2601
# 2601
# succes  861 out of 2602
# partial succes  1169 out of 2602
# 2602
# 2603
# partial succes  1170 out of 2604
# 2604
# succes  862 out of 2605
# partial succes  1171 out of 2605
# 2605
# 2606
# succes  863 out of 2607
# partial succes  1172 out of 2607
# 2607
# partial succes  1173 out of 2608
# 2608
# 2609
# succes  864 out of 2610
# partial succes  1174 out of 2610
# 2610
# succes  865 out of 2611
# partial succes  1175 out of 2611
# 2611
# succes  866 out of 2612
# partial succes  1176 out of 2612
# 2612
# 2613
# 2614
# 2615
# succes  867 out of 2616
# partial succes  1177 out of 2616
# 2616
# succes  868 out of 2617
# partial succes  1178 out of 2617
# 2617
# 2618
# succes  869 out of 2619
# partial succes  1179 out of 2619
# 2619
# succes  870 out of 2620
# partial succes  1180 out of 2620
# 2620
# 2621
# 2622
# 2623
# 2624
# 2625
# succes  871 out of 2626
# partial succes  1181 out of 2626
# 2626
# 2627
# partial succes  1182 out of 2628
# 2628
# 2629
# partial succes  1183 out of 2630
# 2630
# 2631
# partial succes  1184 out of 2632
# 2632
# succes  872 out of 2633
# partial succes  1185 out of 2633
# 2633
# 2634
# 2635
# succes  873 out of 2636
# partial succes  1186 out of 2636
# 2636
# 2637
# 2638
# succes  874 out of 2639
# partial succes  1187 out of 2639
# 2639
# 2640
# succes  875 out of 2641
# partial succes  1188 out of 2641
# 2641
# 2642
# partial succes  1189 out of 2643
# 2643
# partial succes  1190 out of 2644
# 2644
# succes  876 out of 2645
# partial succes  1191 out of 2645
# 2645
# succes  877 out of 2646
# partial succes  1192 out of 2646
# 2646
# 2647
# 2648
# 2649
# succes  878 out of 2650
# partial succes  1193 out of 2650
# 2650
# succes  879 out of 2651
# partial succes  1194 out of 2651
# 2651
# partial succes  1195 out of 2652
# 2652
# succes  880 out of 2653
# partial succes  1196 out of 2653
# 2653
# succes  881 out of 2654
# partial succes  1197 out of 2654
# 2654
# 2655
# succes  882 out of 2656
# partial succes  1198 out of 2656
# 2656
# 2657
# succes  883 out of 2658
# partial succes  1199 out of 2658
# 2658
# succes  884 out of 2659
# partial succes  1200 out of 2659
# 2659
# partial succes  1201 out of 2660
# 2660
# 2661
# partial succes  1202 out of 2662
# 2662
# succes  885 out of 2663
# partial succes  1203 out of 2663
# 2663
# partial succes  1204 out of 2664
# 2664
# partial succes  1205 out of 2665
# 2665
# succes  886 out of 2666
# partial succes  1206 out of 2666
# 2666
# 2667
# 2668
# 2669
# 2670
# succes  887 out of 2671
# partial succes  1207 out of 2671
# 2671
# succes  888 out of 2672
# partial succes  1208 out of 2672
# 2672
# 2673
# succes  889 out of 2674
# partial succes  1209 out of 2674
# 2674
# partial succes  1210 out of 2675
# 2675
# 2676
# succes  890 out of 2677
# partial succes  1211 out of 2677
# 2677
# 2678
# 2679
# 2680
# succes  891 out of 2681
# partial succes  1212 out of 2681
# 2681
# 2682
# partial succes  1213 out of 2683
# 2683
# succes  892 out of 2684
# partial succes  1214 out of 2684
# 2684
# 2685
# 2686
# succes  893 out of 2687
# partial succes  1215 out of 2687
# 2687
# partial succes  1216 out of 2688
# 2688
# succes  894 out of 2689
# partial succes  1217 out of 2689
# 2689
# 2690
# 2691
# 2692
# succes  895 out of 2693
# partial succes  1218 out of 2693
# 2693
# partial succes  1219 out of 2694
# 2694
# succes  896 out of 2695
# partial succes  1220 out of 2695
# 2695
# succes  897 out of 2696
# partial succes  1221 out of 2696
# 2696
# succes  898 out of 2697
# partial succes  1222 out of 2697
# 2697
# 2698
# partial succes  1223 out of 2699
# 2699
# succes  899 out of 2700
# partial succes  1224 out of 2700
# 2700
# succes  900 out of 2701
# partial succes  1225 out of 2701
# 2701
# 2702
# 2703
# succes  901 out of 2704
# partial succes  1226 out of 2704
# 2704
# succes  902 out of 2705
# partial succes  1227 out of 2705
# 2705
# 2706
# succes  903 out of 2707
# partial succes  1228 out of 2707
# 2707
# 2708
# partial succes  1229 out of 2709
# 2709
# 2710
# succes  904 out of 2711
# partial succes  1230 out of 2711
# 2711
# 2712
# 2713
# 2714
# succes  905 out of 2715
# partial succes  1231 out of 2715
# 2715
# 2716
# 2717
# 2718
# 2719
# 2720
# 2721
# 2722
# succes  906 out of 2723
# partial succes  1232 out of 2723
# 2723
# succes  907 out of 2724
# partial succes  1233 out of 2724
# 2724
# 2725
# 2726
# 2727
# succes  908 out of 2728
# partial succes  1234 out of 2728
# 2728
# 2729
# succes  909 out of 2730
# partial succes  1235 out of 2730
# 2730
# 2731
# succes  910 out of 2732
# partial succes  1236 out of 2732
# 2732
# succes  911 out of 2733
# partial succes  1237 out of 2733
# 2733
# succes  912 out of 2734
# partial succes  1238 out of 2734
# 2734
# partial succes  1239 out of 2735
# 2735
# succes  913 out of 2736
# partial succes  1240 out of 2736
# 2736
# succes  914 out of 2737
# partial succes  1241 out of 2737
# 2737
# succes  915 out of 2738
# partial succes  1242 out of 2738
# 2738
# partial succes  1243 out of 2739
# 2739
# 2740
# 2741
# partial succes  1244 out of 2742
# 2742
# 2743
# 2744
# 2745
# 2746
# 2747
# partial succes  1245 out of 2748
# 2748
# succes  916 out of 2749
# partial succes  1246 out of 2749
# 2749
# succes  917 out of 2750
# partial succes  1247 out of 2750
# 2750
# 2751
# succes  918 out of 2752
# partial succes  1248 out of 2752
# 2752
# succes  919 out of 2753
# partial succes  1249 out of 2753
# 2753
# succes  920 out of 2754
# partial succes  1250 out of 2754
# 2754
# 2755
# succes  921 out of 2756
# partial succes  1251 out of 2756
# 2756
# succes  922 out of 2757
# partial succes  1252 out of 2757
# 2757
# 2758
# succes  923 out of 2759
# partial succes  1253 out of 2759
# 2759
# 2760
# 2761
# 2762
# succes  924 out of 2763
# partial succes  1254 out of 2763
# 2763
# 2764
# succes  925 out of 2765
# partial succes  1255 out of 2765
# 2765
# partial succes  1256 out of 2766
# 2766
# 2767
# 2768
# 2769
# 2770
# 2771
# succes  926 out of 2772
# partial succes  1257 out of 2772
# 2772
# succes  927 out of 2773
# partial succes  1258 out of 2773
# 2773
# succes  928 out of 2774
# partial succes  1259 out of 2774
# 2774
# 2775
# 2776
# succes  929 out of 2777
# partial succes  1260 out of 2777
# 2777
# 2778
# partial succes  1261 out of 2779
# 2779
# 2780
# 2781
# 2782
# 2783
# 2784
# 2785
# 2786
# partial succes  1262 out of 2787
# 2787
# 2788
# succes  930 out of 2789
# partial succes  1263 out of 2789
# 2789
# 2790
# 2791
# 2792
# 2793
# 2794
# succes  931 out of 2795
# partial succes  1264 out of 2795
# 2795
# succes  932 out of 2796
# partial succes  1265 out of 2796
# 2796
# 2797
# 2798
# 2799
# succes  933 out of 2800
# partial succes  1266 out of 2800
# 2800
# 2801
# succes  934 out of 2802
# partial succes  1267 out of 2802
# 2802
# succes  935 out of 2803
# partial succes  1268 out of 2803
# 2803
# succes  936 out of 2804
# partial succes  1269 out of 2804
# 2804
# partial succes  1270 out of 2805
# 2805
# succes  937 out of 2806
# partial succes  1271 out of 2806
# 2806
# succes  938 out of 2807
# partial succes  1272 out of 2807
# 2807
# succes  939 out of 2808
# partial succes  1273 out of 2808
# 2808
# partial succes  1274 out of 2809
# 2809
# succes  940 out of 2810
# partial succes  1275 out of 2810
# 2810
# 2811
# 2812
# 2813
# 2814
# 2815
# 2816
# 2817
# 2818
# 2819
# 2820
# 2821
# succes  941 out of 2822
# partial succes  1276 out of 2822
# 2822
# succes  942 out of 2823
# partial succes  1277 out of 2823
# 2823
# 2824
# partial succes  1278 out of 2825
# 2825
# 2826
# succes  943 out of 2827
# partial succes  1279 out of 2827
# 2827
# partial succes  1280 out of 2828
# 2828
# 2829
# succes  944 out of 2830
# partial succes  1281 out of 2830
# 2830
# succes  945 out of 2831
# partial succes  1282 out of 2831
# 2831
# 2832
# 2833
# 2834
# succes  946 out of 2835
# partial succes  1283 out of 2835
# 2835
# succes  947 out of 2836
# partial succes  1284 out of 2836
# 2836
# 2837
# succes  948 out of 2838
# partial succes  1285 out of 2838
# 2838
# 2839
# 2840
# partial succes  1286 out of 2841
# 2841
# succes  949 out of 2842
# partial succes  1287 out of 2842
# 2842
# succes  950 out of 2843
# partial succes  1288 out of 2843
# 2843
# 2844
# 2845
# succes  951 out of 2846
# partial succes  1289 out of 2846
# 2846
# partial succes  1290 out of 2847
# 2847
# succes  952 out of 2848
# partial succes  1291 out of 2848
# 2848
# succes  953 out of 2849
# partial succes  1292 out of 2849
# 2849
# succes  954 out of 2850
# partial succes  1293 out of 2850
# 2850
# 2851
# 2852
# succes  955 out of 2853
# partial succes  1294 out of 2853
# 2853
# partial succes  1295 out of 2854
# 2854
# 2855
# 2856
# succes  956 out of 2857
# partial succes  1296 out of 2857
# 2857
# 2858
# 2859
# succes  957 out of 2860
# partial succes  1297 out of 2860
# 2860
# succes  958 out of 2861
# partial succes  1298 out of 2861
# 2861
# 2862
# 2863
# partial succes  1299 out of 2864
# 2864
# succes  959 out of 2865
# partial succes  1300 out of 2865
# 2865
# 2866
# 2867
# 2868
# 2869
# 2870
# partial succes  1301 out of 2871
# 2871
# 2872
# succes  960 out of 2873
# partial succes  1302 out of 2873
# 2873
# 2874
# partial succes  1303 out of 2875
# 2875
# 2876
# succes  961 out of 2877
# partial succes  1304 out of 2877
# 2877
# 2878
# 2879
# succes  962 out of 2880
# partial succes  1305 out of 2880
# 2880
# succes  963 out of 2881
# partial succes  1306 out of 2881
# 2881
# succes  964 out of 2882
# partial succes  1307 out of 2882
# 2882
# 2883
# succes  965 out of 2884
# partial succes  1308 out of 2884
# 2884
# 2885
# succes  966 out of 2886
# partial succes  1309 out of 2886
# 2886
# 2887
# 2888
# 2889
# succes  967 out of 2890
# partial succes  1310 out of 2890
# 2890
# succes  968 out of 2891
# partial succes  1311 out of 2891
# 2891
# 2892
# 2893
# partial succes  1312 out of 2894
# 2894
# succes  969 out of 2895
# partial succes  1313 out of 2895
# 2895
# 2896
# 2897
# 2898
# 2899
# succes  970 out of 2900
# partial succes  1314 out of 2900
# 2900
# succes  971 out of 2901
# partial succes  1315 out of 2901
# 2901
# succes  972 out of 2902
# partial succes  1316 out of 2902
# 2902
# 2903
# 2904
# 2905
# succes  973 out of 2906
# partial succes  1317 out of 2906
# 2906
# 2907
# succes  974 out of 2908
# partial succes  1318 out of 2908
# 2908
# 2909
# partial succes  1319 out of 2910
# 2910
# succes  975 out of 2911
# partial succes  1320 out of 2911
# 2911
# 2912
# succes  976 out of 2913
# partial succes  1321 out of 2913
# 2913
# succes  977 out of 2914
# partial succes  1322 out of 2914
# 2914
# 2915
# 2916
# succes  978 out of 2917
# partial succes  1323 out of 2917
# 2917
# 2918
# 2919
# partial succes  1324 out of 2920
# 2920
# succes  979 out of 2921
# partial succes  1325 out of 2921
# 2921
# succes  980 out of 2922
# partial succes  1326 out of 2922
# 2922
# succes  981 out of 2923
# partial succes  1327 out of 2923
# 2923
# succes  982 out of 2924
# partial succes  1328 out of 2924
# 2924
# 2925
# 2926
# succes  983 out of 2927
# partial succes  1329 out of 2927
# 2927
# succes  984 out of 2928
# partial succes  1330 out of 2928
# 2928
# partial succes  1331 out of 2929
# 2929
# succes  985 out of 2930
# partial succes  1332 out of 2930
# 2930
# 2931
# succes  986 out of 2932
# partial succes  1333 out of 2932
# 2932
# partial succes  1334 out of 2933
# 2933
# succes  987 out of 2934
# partial succes  1335 out of 2934
# 2934
# 2935
# succes  988 out of 2936
# partial succes  1336 out of 2936
# 2936
# 2937
# 2938
# partial succes  1337 out of 2939
# 2939
# 2940
# 2941
# 2942
# succes  989 out of 2943
# partial succes  1338 out of 2943
# 2943
# 2944
# succes  990 out of 2945
# partial succes  1339 out of 2945
# 2945
# 2946
# 2947
# partial succes  1340 out of 2948
# 2948
# succes  991 out of 2949
# partial succes  1341 out of 2949
# 2949
# 2950
# 2951
# partial succes  1342 out of 2952
# 2952
# succes  992 out of 2953
# partial succes  1343 out of 2953
# 2953
# partial succes  1344 out of 2954
# 2954
# 2955
# partial succes  1345 out of 2956
# 2956
# succes  993 out of 2957
# partial succes  1346 out of 2957
# 2957
# succes  994 out of 2958
# partial succes  1347 out of 2958
# 2958
# partial succes  1348 out of 2959
# 2959
# 2960
# 2961
# succes  995 out of 2962
# partial succes  1349 out of 2962
# 2962
# succes  996 out of 2963
# partial succes  1350 out of 2963
# 2963
# 2964
# 2965
# succes  997 out of 2966
# partial succes  1351 out of 2966
# 2966
# partial succes  1352 out of 2967
# 2967
# partial succes  1353 out of 2968
# 2968
# partial succes  1354 out of 2969
# 2969
# 2970
# succes  998 out of 2971
# partial succes  1355 out of 2971
# 2971
# 2972
# succes  999 out of 2973
# partial succes  1356 out of 2973
# 2973
# 2974
# 2975
# 2976
# 2977
# succes  1000 out of 2978
# partial succes  1357 out of 2978
# 2978
# partial succes  1358 out of 2979
# 2979
# partial succes  1359 out of 2980
# 2980
# succes  1001 out of 2981
# partial succes  1360 out of 2981
# 2981
# 2982
# partial succes  1361 out of 2983
# 2983
# succes  1002 out of 2984
# partial succes  1362 out of 2984
# 2984
# 2985
# 2986
# succes  1003 out of 2987
# partial succes  1363 out of 2987
# 2987
# 2988
# 2989
# 2990
# succes  1004 out of 2991
# partial succes  1364 out of 2991
# 2991
# 2992
# 2993
# 2994
# 2995
# succes  1005 out of 2996
# partial succes  1365 out of 2996
# 2996
# 2997
# 2998
# succes  1006 out of 2999
# partial succes  1366 out of 2999
# 2999
# succes  1007 out of 3000
# partial succes  1367 out of 3000
# 3000
# succes  1008 out of 3001
# partial succes  1368 out of 3001
# 3001
# succes  1009 out of 3002
# partial succes  1369 out of 3002
# 3002
# succes  1010 out of 3003
# partial succes  1370 out of 3003
# 3003
# succes  1011 out of 3004
# partial succes  1371 out of 3004
# 3004
# 3005
# 3006
# 3007
# succes  1012 out of 3008
# partial succes  1372 out of 3008
# 3008
# succes  1013 out of 3009
# partial succes  1373 out of 3009
# 3009
# partial succes  1374 out of 3010
# 3010
# succes  1014 out of 3011
# partial succes  1375 out of 3011
# 3011
# 3012
# 3013
# 3014
# 3015
# 3016
# 3017
# succes  1015 out of 3018
# partial succes  1376 out of 3018
# 3018
# 3019
# 3020
# 3021
# 3022
# succes  1016 out of 3023
# partial succes  1377 out of 3023
# 3023
# partial succes  1378 out of 3024
# 3024
# succes  1017 out of 3025
# partial succes  1379 out of 3025
# 3025
# succes  1018 out of 3026
# partial succes  1380 out of 3026
# 3026
# partial succes  1381 out of 3027
# 3027
# succes  1019 out of 3028
# partial succes  1382 out of 3028
# 3028
# 3029
# succes  1020 out of 3030
# partial succes  1383 out of 3030
# 3030
# 3031
# 3032
# partial succes  1384 out of 3033
# 3033
# 3034
# 3035
# partial succes  1385 out of 3036
# 3036
# 3037
# succes  1021 out of 3038
# partial succes  1386 out of 3038
# 3038
# 3039
# 3040
# 3041
# 3042
# succes  1022 out of 3043
# partial succes  1387 out of 3043
# 3043
# succes  1023 out of 3044
# partial succes  1388 out of 3044
# 3044
# 3045
# 3046
# partial succes  1389 out of 3047
# 3047
# partial succes  1390 out of 3048
# 3048
# 3049
# succes  1024 out of 3050
# partial succes  1391 out of 3050
# 3050
# 3051
# 3052
# 3053
# 3054
# 3055
# succes  1025 out of 3056
# partial succes  1392 out of 3056
# 3056
# 3057
# succes  1026 out of 3058
# partial succes  1393 out of 3058
# 3058
# 3059
# 3060
# partial succes  1394 out of 3061
# 3061
# succes  1027 out of 3062
# partial succes  1395 out of 3062
# 3062
# 3063
# 3064
# succes  1028 out of 3065
# partial succes  1396 out of 3065
# 3065
# 3066
# 3067
# 3068
# 3069
# partial succes  1397 out of 3070
# 3070
# 3071
# succes  1029 out of 3072
# partial succes  1398 out of 3072
# 3072
# 3073
# succes  1030 out of 3074
# partial succes  1399 out of 3074
# 3074
# partial succes  1400 out of 3075
# 3075
# 3076
# succes  1031 out of 3077
# partial succes  1401 out of 3077
# 3077
# succes  1032 out of 3078
# partial succes  1402 out of 3078
# 3078
# 3079
# partial succes  1403 out of 3080
# 3080
# 3081
# 3082
# 3083
# succes  1033 out of 3084
# partial succes  1404 out of 3084
# 3084
# partial succes  1405 out of 3085
# 3085
# succes  1034 out of 3086
# partial succes  1406 out of 3086
# 3086
# 3087
# 3088
# succes  1035 out of 3089
# partial succes  1407 out of 3089
# 3089
# partial succes  1408 out of 3090
# 3090
# 3091
# 3092
# succes  1036 out of 3093
# partial succes  1409 out of 3093
# 3093
# 3094
# ...
# partial succes  1636 out of 3606
# 3606
# succes  1200 out of 3607
# partial succes  1637 out of 3607
# 3607
# 3608
# 3609
# partial succes  1638 out of 3610
# 3610
# 3611
# 3612
# 3613
# 3614
# 3615
# 3616
# succes  1201 out of 3617
# partial succes  1639 out of 3617
# 3617
# succes  1202 out of 3618
# partial succes  1640 out of 3618
# 3618
# 3619
# 3620
# 3621
# succes  1203 out of 3622
# partial succes  1641 out of 3622
# 3622
# succes  1204 out of 3623
# partial succes  1642 out of 3623
# 3623
# succes  1205 out of 3624
# partial succes  1643 out of 3624
# 3624
# 3625
# succes  1206 out of 3626
# partial succes  1644 out of 3626
# 3626
# 3627
# 3628
# partial succes  1645 out of 3629
# 3629
# 3630
# 3631
# 3632
# succes  1207 out of 3633
# partial succes  1646 out of 3633
# 3633
# 3634
# 3635
# 3636
# succes  1208 out of 3637
# partial succes  1647 out of 3637
# 3637
# 3638
# succes  1209 out of 3639
# partial succes  1648 out of 3639
# 3639
# 3640
# 3641
# 3642
# 3643
# succes  1210 out of 3644
# partial succes  1649 out of 3644
# 3644
# 3645
# 3646
# 3647
# succes  1211 out of 3648
# partial succes  1650 out of 3648
# 3648
# partial succes  1651 out of 3649
# 3649
# succes  1212 out of 3650
# partial succes  1652 out of 3650
# 3650
# succes  1213 out of 3651
# partial succes  1653 out of 3651
# 3651
# 3652
# 3653
# succes  1214 out of 3654
# partial succes  1654 out of 3654
# 3654
# 3655
# succes  1215 out of 3656
# partial succes  1655 out of 3656
# 3656
# 3657
# 3658
# succes  1216 out of 3659
# partial succes  1656 out of 3659
# 3659
# 3660
# 3661
# 3662
# succes  1217 out of 3663
# partial succes  1657 out of 3663
# 3663
# 3664
# succes  1218 out of 3665
# partial succes  1658 out of 3665
# 3665
# partial succes  1659 out of 3666
# 3666
# succes  1219 out of 3667
# partial succes  1660 out of 3667
# 3667
# succes  1220 out of 3668
# partial succes  1661 out of 3668
# 3668
# 3669
# 3670
# partial succes  1662 out of 3671
# 3671
# 3672
# 3673
# 3674
# succes  1221 out of 3675
# partial succes  1663 out of 3675
# 3675
# succes  1222 out of 3676
# partial succes  1664 out of 3676
# 3676
# succes  1223 out of 3677
# partial succes  1665 out of 3677
# 3677
# succes  1224 out of 3678
# partial succes  1666 out of 3678
# 3678
# partial succes  1667 out of 3679
# 3679
# succes  1225 out of 3680
# partial succes  1668 out of 3680
# 3680
# succes  1226 out of 3681
# partial succes  1669 out of 3681
# 3681
# partial succes  1670 out of 3682
# 3682
# 3683
# succes  1227 out of 3684
# partial succes  1671 out of 3684
# 3684
# succes  1228 out of 3685
# partial succes  1672 out of 3685
# 3685
# 3686
# 3687
# 3688
# succes  1229 out of 3689
# partial succes  1673 out of 3689
# 3689
# 3690
# 3691
# 3692
# succes  1230 out of 3693
# partial succes  1674 out of 3693
# 3693
# 3694
# 3695
# succes  1231 out of 3696
# partial succes  1675 out of 3696
# 3696
# 3697
# 3698
# succes  1232 out of 3699
# partial succes  1676 out of 3699
# 3699
# 3700
# 3701
# 3702
# succes  1233 out of 3703
# partial succes  1677 out of 3703
# 3703
# 3704
# succes  1234 out of 3705
# partial succes  1678 out of 3705
# 3705
# 3706
# 3707
# 3708
# 3709
# succes  1235 out of 3710
# partial succes  1679 out of 3710
# 3710
# succes  1236 out of 3711
# partial succes  1680 out of 3711
# 3711
# 3712
# 3713
# succes  1237 out of 3714
# partial succes  1681 out of 3714
# 3714
# 3715
# succes  1238 out of 3716
# partial succes  1682 out of 3716
# 3716
# 3717
# 3718
# 3719
# 3720
# succes  1239 out of 3721
# partial succes  1683 out of 3721
# 3721
# succes  1240 out of 3722
# partial succes  1684 out of 3722
# 3722
# succes  1241 out of 3723
# partial succes  1685 out of 3723
# 3723
# 3724
# 3725
# 3726
# 3727
# 3728
# partial succes  1686 out of 3729
# 3729
# succes  1242 out of 3730
# partial succes  1687 out of 3730
# 3730
# 3731
# 3732
# succes  1243 out of 3733
# partial succes  1688 out of 3733
# 3733
# 3734
# 3735
# succes  1244 out of 3736
# partial succes  1689 out of 3736
# 3736
# partial succes  1690 out of 3737
# 3737
# partial succes  1691 out of 3738
# 3738
# partial succes  1692 out of 3739
# 3739
# succes  1245 out of 3740
# partial succes  1693 out of 3740
# 3740
# succes  1246 out of 3741
# partial succes  1694 out of 3741
# 3741
# succes  1247 out of 3742
# partial succes  1695 out of 3742
# 3742
# 3743
# succes  1248 out of 3744
# partial succes  1696 out of 3744
# 3744
# 3745
# 3746
# partial succes  1697 out of 3747
# 3747
# succes  1249 out of 3748
# partial succes  1698 out of 3748
# 3748
# 3749
# succes  1250 out of 3750
# partial succes  1699 out of 3750
# 3750
# 3751
# 3752
# succes  1251 out of 3753
# partial succes  1700 out of 3753
# 3753
# 3754
# 3755
# 3756
# succes  1252 out of 3757
# partial succes  1701 out of 3757
# 3757
# succes  1253 out of 3758
# partial succes  1702 out of 3758
# 3758
# 3759
# succes  1254 out of 3760
# partial succes  1703 out of 3760
# 3760
# 3761
# 3762
# 3763
# 3764
# succes  1255 out of 3765
# partial succes  1704 out of 3765
# 3765
# 3766
# 3767
# 3768
# 3769
# 3770
# 3771
# 3772
# partial succes  1705 out of 3773
# 3773
# succes  1256 out of 3774
# partial succes  1706 out of 3774
# 3774
# partial succes  1707 out of 3775
# 3775
# 3776
# 3777
# 3778
# partial succes  1708 out of 3779
# 3779
# 3780
# succes  1257 out of 3781
# partial succes  1709 out of 3781
# 3781
# 3782
# 3783
# 3784
# 3785
# 3786
# 3787
# 3788
# partial succes  1710 out of 3789
# 3789
# 3790
# 3791
# 3792
# 3793
# succes  1258 out of 3794
# partial succes  1711 out of 3794
# 3794
# 3795
# 3796
# succes  1259 out of 3797
# partial succes  1712 out of 3797
# 3797
# 3798
# succes  1260 out of 3799
# partial succes  1713 out of 3799
# 3799
# 3800
# succes  1261 out of 3801
# partial succes  1714 out of 3801
# 3801
# succes  1262 out of 3802
# partial succes  1715 out of 3802
# 3802
# succes  1263 out of 3803
# partial succes  1716 out of 3803
# 3803
# 3804
# 3805
# 3806
# 3807
# succes  1264 out of 3808
# partial succes  1717 out of 3808
# 3808
# succes  1265 out of 3809
# partial succes  1718 out of 3809
# 3809
# succes  1266 out of 3810
# partial succes  1719 out of 3810
# 3810
# 3811
# succes  1267 out of 3812
# partial succes  1720 out of 3812
# 3812
# succes  1268 out of 3813
# partial succes  1721 out of 3813
# 3813
# 3814
# 3815
# succes  1269 out of 3816
# partial succes  1722 out of 3816
# 3816
# 3817
# succes  1270 out of 3818
# partial succes  1723 out of 3818
# 3818
# succes  1271 out of 3819
# partial succes  1724 out of 3819
# 3819
# succes  1272 out of 3820
# partial succes  1725 out of 3820
# 3820
# 3821
# 3822
# 3823
# 3824
# 3825
# partial succes  1726 out of 3826
# 3826
# 3827
# succes  1273 out of 3828
# partial succes  1727 out of 3828
# 3828
# 3829
# succes  1274 out of 3830
# partial succes  1728 out of 3830
# 3830
# 3831
# partial succes  1729 out of 3832
# 3832
# succes  1275 out of 3833
# partial succes  1730 out of 3833
# 3833
# 3834
# 3835
# partial succes  1731 out of 3836
# 3836
# 3837
# 3838
# succes  1276 out of 3839
# partial succes  1732 out of 3839
# 3839
# 3840
# succes  1277 out of 3841
# partial succes  1733 out of 3841
# 3841
# succes  1278 out of 3842
# partial succes  1734 out of 3842
# 3842
# succes  1279 out of 3843
# partial succes  1735 out of 3843
# 3843
# partial succes  1736 out of 3844
# 3844
# 3845
# 3846
# 3847
# 3848
# succes  1280 out of 3849
# partial succes  1737 out of 3849
# 3849
# 3850
# 3851
# 3852
# succes  1281 out of 3853
# partial succes  1738 out of 3853
# 3853
# succes  1282 out of 3854
# partial succes  1739 out of 3854
# 3854
# succes  1283 out of 3855
# partial succes  1740 out of 3855
# 3855
# 3856
# partial succes  1741 out of 3857
# 3857
# succes  1284 out of 3858
# partial succes  1742 out of 3858
# 3858
# 3859
# 3860
# 3861
# succes  1285 out of 3862
# partial succes  1743 out of 3862
# 3862
# partial succes  1744 out of 3863
# 3863
# succes  1286 out of 3864
# partial succes  1745 out of 3864
# 3864
# 3865
# succes  1287 out of 3866
# partial succes  1746 out of 3866
# 3866
# 3867
# 3868
# 3869
# succes  1288 out of 3870
# partial succes  1747 out of 3870
# 3870
# succes  1289 out of 3871
# partial succes  1748 out of 3871
# 3871
# 3872
# 3873
# succes  1290 out of 3874
# partial succes  1749 out of 3874
# 3874
# succes  1291 out of 3875
# partial succes  1750 out of 3875
# 3875
# 3876
# 3877
# succes  1292 out of 3878
# partial succes  1751 out of 3878
# 3878
# 3879
# succes  1293 out of 3880
# partial succes  1752 out of 3880
# 3880
# 3881
# 3882
# 3883
# 3884
# 3885
# 3886
# 3887
# partial succes  1753 out of 3888
# 3888
# succes  1294 out of 3889
# partial succes  1754 out of 3889
# 3889
# succes  1295 out of 3890
# partial succes  1755 out of 3890
# 3890
# succes  1296 out of 3891
# partial succes  1756 out of 3891
# 3891
# partial succes  1757 out of 3892
# 3892
# succes  1297 out of 3893
# partial succes  1758 out of 3893
# 3893
# partial succes  1759 out of 3894
# 3894
# 3895
# 3896
# 3897
# 3898
# succes  1298 out of 3899
# partial succes  1760 out of 3899
# 3899
# succes  1299 out of 3900
# partial succes  1761 out of 3900
# 3900
# 3901
# partial succes  1762 out of 3902
# 3902
# 3903
# 3904
# 3905
# 3906
# 3907
# succes  1300 out of 3908
# partial succes  1763 out of 3908
# 3908
# succes  1301 out of 3909
# partial succes  1764 out of 3909
# 3909
# succes  1302 out of 3910
# partial succes  1765 out of 3910
# 3910
# 3911
# succes  1303 out of 3912
# partial succes  1766 out of 3912
# 3912
# partial succes  1767 out of 3913
# 3913
# 3914
# 3915
# 3916
# partial succes  1768 out of 3917
# 3917
# 3918
# 3919
# 3920
# succes  1304 out of 3921
# partial succes  1769 out of 3921
# 3921
# 3922
# 3923
# 3924
# succes  1305 out of 3925
# partial succes  1770 out of 3925
# 3925
# 3926
# 3927
# 3928
# 3929
# 3930
# partial succes  1771 out of 3931
# 3931
# partial succes  1772 out of 3932
# 3932
# 3933
# partial succes  1773 out of 3934
# 3934
# succes  1306 out of 3935
# partial succes  1774 out of 3935
# 3935
# 3936
# succes  1307 out of 3937
# partial succes  1775 out of 3937
# 3937
# 3938
# 3939
# 3940
# succes  1308 out of 3941
# partial succes  1776 out of 3941
# 3941
# 3942
# 3943
# 3944
# succes  1309 out of 3945
# partial succes  1777 out of 3945
# 3945
# partial succes  1778 out of 3946
# 3946
# 3947
# succes  1310 out of 3948
# partial succes  1779 out of 3948
# 3948
# succes  1311 out of 3949
# partial succes  1780 out of 3949
# 3949
# 3950
# succes  1312 out of 3951
# partial succes  1781 out of 3951
# 3951
# 3952
# partial succes  1782 out of 3953
# 3953
# 3954
# succes  1313 out of 3955
# partial succes  1783 out of 3955
# 3955
# partial succes  1784 out of 3956
# 3956
# 3957
# succes  1314 out of 3958
# partial succes  1785 out of 3958
# 3958
# 3959
# 3960
# succes  1315 out of 3961
# partial succes  1786 out of 3961
# 3961
# partial succes  1787 out of 3962
# 3962
# succes  1316 out of 3963
# partial succes  1788 out of 3963
# 3963
# 3964
# succes  1317 out of 3965
# partial succes  1789 out of 3965
# 3965
# 3966
# 3967
# 3968
# succes  1318 out of 3969
# partial succes  1790 out of 3969
# 3969
# 3970
# partial succes  1791 out of 3971
# 3971
# 3972
# partial succes  1792 out of 3973
# 3973
# 3974
# succes  1319 out of 3975
# partial succes  1793 out of 3975
# 3975
# 3976
# 3977
# 3978
# partial succes  1794 out of 3979
# 3979
# 3980
# 3981
# succes  1320 out of 3982
# partial succes  1795 out of 3982
# 3982
# 3983
# succes  1321 out of 3984
# partial succes  1796 out of 3984
# 3984
# succes  1322 out of 3985
# partial succes  1797 out of 3985
# 3985
# 3986
# 3987
# 3988
# succes  1323 out of 3989
# partial succes  1798 out of 3989
# 3989
# 3990
# 3991
# succes  1324 out of 3992
# partial succes  1799 out of 3992
# 3992
# succes  1325 out of 3993
# partial succes  1800 out of 3993
# 3993
# 3994
# succes  1326 out of 3995
# partial succes  1801 out of 3995
# 3995
# 3996
# 3997
# 3998
# succes  1327 out of 3999
# partial succes  1802 out of 3999
# 3999
# 4000
# succes  1328 out of 4001
# partial succes  1803 out of 4001
# 4001
# succes  1329 out of 4002
# partial succes  1804 out of 4002
# 4002
# succes  1330 out of 4003
# partial succes  1805 out of 4003
# 4003
# succes  1331 out of 4004
# partial succes  1806 out of 4004
# 4004
# 4005
# partial succes  1807 out of 4006
# 4006
# partial succes  1808 out of 4007
# 4007
# succes  1332 out of 4008
# partial succes  1809 out of 4008
# 4008
# 4009
# partial succes  1810 out of 4010
# 4010
# partial succes  1811 out of 4011
# 4011
# succes  1333 out of 4012
# partial succes  1812 out of 4012
# 4012
# 4013
# succes  1334 out of 4014
# partial succes  1813 out of 4014
# 4014
# succes  1335 out of 4015
# partial succes  1814 out of 4015
# 4015
# 4016
# 4017
# 4018
# partial succes  1815 out of 4019
# 4019
# 4020
# partial succes  1816 out of 4021
# 4021
# 4022
# succes  1336 out of 4023
# partial succes  1817 out of 4023
# 4023
# succes  1337 out of 4024
# partial succes  1818 out of 4024
# 4024
# 4025
# 4026
# succes  1338 out of 4027
# partial succes  1819 out of 4027
# 4027
# partial succes  1820 out of 4028
# 4028
# partial succes  1821 out of 4029
# 4029
# 4030
# succes  1339 out of 4031
# partial succes  1822 out of 4031
# 4031
# 4032
# 4033
# partial succes  1823 out of 4034
# 4034
# partial succes  1824 out of 4035
# 4035
# partial succes  1825 out of 4036
# 4036
# 4037
# succes  1340 out of 4038
# partial succes  1826 out of 4038
# 4038
# succes  1341 out of 4039
# partial succes  1827 out of 4039
# 4039
# succes  1342 out of 4040
# partial succes  1828 out of 4040
# 4040
# succes  1343 out of 4041
# partial succes  1829 out of 4041
# 4041
# succes  1344 out of 4042
# partial succes  1830 out of 4042
# 4042
# succes  1345 out of 4043
# partial succes  1831 out of 4043
# 4043
# 4044
# 4045
# succes  1346 out of 4046
# partial succes  1832 out of 4046
# 4046
# succes  1347 out of 4047
# partial succes  1833 out of 4047
# 4047
# 4048
# 4049
# succes  1348 out of 4050
# partial succes  1834 out of 4050
# 4050
# partial succes  1835 out of 4051
# 4051
# succes  1349 out of 4052
# partial succes  1836 out of 4052
# 4052
# 4053
# 4054
# succes  1350 out of 4055
# partial succes  1837 out of 4055
# 4055
# 4056
# 4057
# succes  1351 out of 4058
# partial succes  1838 out of 4058
# 4058
# 4059
# 4060
# succes  1352 out of 4061
# partial succes  1839 out of 4061
# 4061
# succes  1353 out of 4062
# partial succes  1840 out of 4062
# 4062
# succes  1354 out of 4063
# partial succes  1841 out of 4063
# 4063
# 4064
# 4065
# succes  1355 out of 4066
# partial succes  1842 out of 4066
# 4066
# 4067
# 4068
# partial succes  1843 out of 4069
# 4069
# 4070
# 4071
# succes  1356 out of 4072
# partial succes  1844 out of 4072
# 4072
# succes  1357 out of 4073
# partial succes  1845 out of 4073
# 4073
# succes  1358 out of 4074
# partial succes  1846 out of 4074
# 4074
# 4075
# 4076
# 4077
# partial succes  1847 out of 4078
# 4078
# 4079
# 4080
# 4081
# succes  1359 out of 4082
# partial succes  1848 out of 4082
# 4082
# partial succes  1849 out of 4083
# 4083
# 4084
# 4085
# partial succes  1850 out of 4086
# 4086
# 4087
# succes  1360 out of 4088
# partial succes  1851 out of 4088
# 4088
# 4089
# 4090
# succes  1361 out of 4091
# partial succes  1852 out of 4091
# 4091
# 4092
# 4093
# 4094
# 4095
# 4096
# 4097
# succes  1362 out of 4098
# partial succes  1853 out of 4098
# 4098
# 4099
# partial succes  1854 out of 4100
# 4100
# succes  1363 out of 4101
# partial succes  1855 out of 4101
# 4101
# 4102
# 4103
# partial succes  1856 out of 4104
# 4104
# 4105
# 4106
# succes  1364 out of 4107
# partial succes  1857 out of 4107
# 4107
# succes  1365 out of 4108
# partial succes  1858 out of 4108
# 4108
# succes  1366 out of 4109
# partial succes  1859 out of 4109
# 4109
# 4110
# succes  1367 out of 4111
# partial succes  1860 out of 4111
# 4111
# succes  1368 out of 4112
# partial succes  1861 out of 4112
# 4112
# succes  1369 out of 4113
# partial succes  1862 out of 4113
# 4113
# 4114
# 4115
# succes  1370 out of 4116
# partial succes  1863 out of 4116
# 4116
# 4117
# partial succes  1864 out of 4118
# 4118
# succes  1371 out of 4119
# partial succes  1865 out of 4119
# 4119
# 4120
# 4121
# succes  1372 out of 4122
# partial succes  1866 out of 4122
# 4122
# partial succes  1867 out of 4123
# 4123
# 4124
# 4125
# partial succes  1868 out of 4126
# 4126
# 4127
# succes  1373 out of 4128
# partial succes  1869 out of 4128
# 4128
# 4129
# 4130
# succes  1374 out of 4131
# partial succes  1870 out of 4131
# 4131
# 4132
# 4133
# succes  1375 out of 4134
# partial succes  1871 out of 4134
# 4134
# 4135
# succes  1376 out of 4136
# partial succes  1872 out of 4136
# 4136
# 4137
# 4138
# partial succes  1873 out of 4139
# 4139
# 4140
# succes  1377 out of 4141
# partial succes  1874 out of 4141
# 4141
# 4142
# 4143
# succes  1378 out of 4144
# partial succes  1875 out of 4144
# 4144
# 4145
# 4146
# 4147
# succes  1379 out of 4148
# partial succes  1876 out of 4148
# 4148
# partial succes  1877 out of 4149
# 4149
# 4150
# 4151
# succes  1380 out of 4152
# partial succes  1878 out of 4152
# 4152
# 4153
# 4154
# succes  1381 out of 4155
# partial succes  1879 out of 4155
# 4155
# 4156
# 4157
# 4158
# succes  1382 out of 4159
# partial succes  1880 out of 4159
# 4159
# succes  1383 out of 4160
# partial succes  1881 out of 4160
# 4160
# 4161
# partial succes  1882 out of 4162
# 4162
# 4163
# 4164
# partial succes  1883 out of 4165
# 4165
# 4166
# partial succes  1884 out of 4167
# 4167
# 4168
# succes  1384 out of 4169
# partial succes  1885 out of 4169
# 4169
# succes  1385 out of 4170
# partial succes  1886 out of 4170
# 4170
# 4171
# 4172
# 4173
# partial succes  1887 out of 4174
# 4174
# partial succes  1888 out of 4175
# 4175
# 4176
# 4177
# 4178
# 4179
# 4180
# succes  1386 out of 4181
# partial succes  1889 out of 4181
# 4181
# Exact match accuracy: 33.14%
# Partial match accuracy: 45.17%

# %% [markdown]
# 4%

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set_004, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)

train(train_dataloader, encoder, decoder, 100000, print_every=1000, plot_every=500)

# %%
eval = [eval_set[i] for i in range(4182)]
encoder.eval()
decoder.eval()
result004 = evaluate(encoder, decoder, eval, input_vocab, output_vocab)
results.append(result004)

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set_008, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)

train(train_dataloader, encoder, decoder, 100000, print_every=1000, plot_every=500)

# %%
eval = [eval_set[i] for i in range(4182)]
encoder.eval()
decoder.eval()
result008 = evaluate(encoder, decoder, eval, input_vocab, output_vocab)
results.append(result008)

# %% [markdown]
# # Experiment 2

# %%
# URLs of the files you want to download
file_urls = [
    'https://raw.githubusercontent.com/brendenlake/SCAN/master/length_split/tasks_train_length.txt',
    'https://raw.githubusercontent.com/brendenlake/SCAN/master/length_split/tasks_test_length.txt'  # Replace with the actual URL of the second file
]

# Use ThreadPoolExecutor to download files concurrently
with ThreadPoolExecutor(max_workers=len(file_urls)) as executor:
    results = list(executor.map(download_file, file_urls))

# Check if all downloads were successful
if all(result is not None for result in results):
    # Assuming each line in the text file is a sentence
    sentences_list = [result.split('\n') for result in results]

    # Create DataFrames for each file
    dfs = [pd.DataFrame({'Sentences': sentences}) for sentences in sentences_list]

    # Create DataFrames for each file
    train_df_exp2 = pd.DataFrame({'Sentences': sentences_list[0]})
    eval_df_exp2 = pd.DataFrame({'Sentences': sentences_list[1]})
else:
    print("One or more downloads failed.")

# %%
train_set_lenght = SentenceDataset(train_df_exp2['Sentences'])
eval_set_lenght = SentenceDataset(eval_df_exp2['Sentences'])

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set_lenght, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)

train(train_dataloader, encoder, decoder, 100000, print_every=100, plot_every=500)
# Out:
# 0m 4s (- 67m 22s) (100 0%) 1.7762
# 0m 5s (- 45m 21s) (200 0%) 1.4891
# 0m 6s (- 37m 39s) (300 0%) 1.3509
# 0m 8s (- 34m 1s) (400 0%) 1.1690
# 0m 10s (- 33m 56s) (500 0%) 1.0978
# 0m 12s (- 33m 19s) (600 0%) 0.9706
# 0m 13s (- 31m 45s) (700 0%) 0.9071
# 0m 14s (- 30m 44s) (800 0%) 0.8429
# 0m 16s (- 29m 47s) (900 0%) 0.8230
# 0m 17s (- 29m 18s) (1000 1%) 0.6910
# 0m 19s (- 28m 45s) (1100 1%) 0.6813
# 0m 20s (- 28m 23s) (1200 1%) 0.6559
# 0m 22s (- 28m 23s) (1300 1%) 0.6641
# 0m 24s (- 28m 43s) (1400 1%) 0.6171
# 0m 26s (- 28m 31s) (1500 1%) 0.5435
# 0m 27s (- 28m 11s) (1600 1%) 0.5534
# 0m 28s (- 27m 54s) (1700 1%) 0.5292
# 0m 30s (- 27m 35s) (1800 1%) 0.5306
# 0m 31s (- 27m 20s) (1900 1%) 0.4989
# 0m 33s (- 27m 17s) (2000 2%) 0.4452
# 0m 35s (- 27m 46s) (2100 2%) 0.4532
# 0m 37s (- 27m 58s) (2200 2%) 0.4294
# 0m 39s (- 27m 54s) (2300 2%) 0.3946
# 0m 40s (- 27m 41s) (2400 2%) 0.4039
# 0m 42s (- 27m 28s) (2500 2%) 0.3730
# 0m 44s (- 27m 43s) (2600 2%) 0.3749
# 0m 46s (- 28m 5s) (2700 2%) 0.3872
# 0m 48s (- 27m 53s) (2800 2%) 0.3320
# 0m 49s (- 27m 53s) (2900 2%) 0.3363
# 0m 51s (- 27m 56s) (3000 3%) 0.3422
# 0m 53s (- 27m 46s) (3100 3%) 0.3159
# 0m 54s (- 27m 36s) (3200 3%) 0.3130
# 0m 56s (- 27m 24s) (3300 3%) 0.2954
# 0m 57s (- 27m 13s) (3400 3%) 0.3290
# 0m 58s (- 27m 1s) (3500 3%) 0.2886
# 1m 0s (- 26m 53s) (3600 3%) 0.2523
# 1m 1s (- 26m 45s) (3700 3%) 0.2397
# 1m 3s (- 26m 52s) (3800 3%) 0.2414
# 5m 15s (- 21m 9s) (19900 19%) 0.0159
# 5m 17s (- 21m 9s) (20000 20%) 0.0180
# 5m 18s (- 21m 7s) (20100 20%) 0.0182
# 5m 20s (- 21m 4s) (20200 20%) 0.0385
# 5m 21s (- 21m 2s) (20300 20%) 0.0239
# 5m 22s (- 20m 59s) (20400 20%) 0.0366
# 5m 24s (- 20m 57s) (20500 20%) 0.0282
# 5m 25s (- 20m 55s) (20600 20%) 0.0196
# 5m 27s (- 20m 53s) (20700 20%) 0.0126
# 5m 29s (- 20m 53s) (20800 20%) 0.0093
# 5m 31s (- 20m 53s) (20900 20%) 0.0111
# 5m 32s (- 20m 51s) (21000 21%) 0.0108
# 5m 34s (- 20m 49s) (21100 21%) 0.0149
# 5m 35s (- 20m 47s) (21200 21%) 0.0124
# 5m 37s (- 20m 45s) (21300 21%) 0.0164
# 5m 38s (- 20m 43s) (21400 21%) 0.0148
# 5m 39s (- 20m 41s) (21500 21%) 0.0105
# 5m 41s (- 20m 39s) (21600 21%) 0.0145
# 5m 43s (- 20m 39s) (21700 21%) 0.0198
# 5m 45s (- 20m 38s) (21800 21%) 0.0310
# 5m 46s (- 20m 36s) (21900 21%) 0.0138
# 5m 48s (- 20m 34s) (22000 22%) 0.0221
# 5m 49s (- 20m 32s) (22100 22%) 0.0189
# 5m 51s (- 20m 30s) (22200 22%) 0.0078
# 5m 52s (- 20m 28s) (22300 22%) 0.0070
# 5m 53s (- 20m 26s) (22400 22%) 0.0065
# 5m 55s (- 20m 25s) (22500 22%) 0.0186
# 5m 57s (- 20m 24s) (22600 22%) 0.0168
# 5m 59s (- 20m 23s) (22700 22%) 0.0316
# 6m 0s (- 20m 20s) (22800 22%) 0.0144
# 6m 1s (- 20m 18s) (22900 22%) 0.0299
# 6m 3s (- 20m 16s) (23000 23%) 0.0135
# 6m 4s (- 20m 14s) (23100 23%) 0.0102
# 6m 6s (- 20m 12s) (23200 23%) 0.0088
# 6m 7s (- 20m 10s) (23300 23%) 0.0308
# 6m 9s (- 20m 10s) (23400 23%) 0.0184
# 6m 11s (- 20m 9s) (23500 23%) 0.0205
# 6m 13s (- 20m 8s) (23600 23%) 0.0145
# 6m 14s (- 20m 6s) (23700 23%) 0.0159
# 6m 15s (- 20m 3s) (23800 23%) 0.0172
# 6m 17s (- 20m 1s) (23900 23%) 0.0081
# 6m 18s (- 19m 58s) (24000 24%) 0.0165
# 6m 20s (- 19m 56s) (24100 24%) 0.0165
# 6m 21s (- 19m 55s) (24200 24%) 0.0055
# 6m 23s (- 19m 54s) (24300 24%) 0.0129
# 6m 25s (- 19m 53s) (24400 24%) 0.0090
# 6m 26s (- 19m 51s) (24500 24%) 0.0253
# 6m 28s (- 19m 49s) (24600 24%) 0.0093
# 6m 29s (- 19m 47s) (24700 24%) 0.0128
# 6m 30s (- 19m 45s) (24800 24%) 0.0087
# 6m 32s (- 19m 43s) (24900 24%) 0.0074
# 6m 33s (- 19m 41s) (25000 25%) 0.0101
# 6m 35s (- 19m 40s) (25100 25%) 0.0133
# 6m 37s (- 19m 40s) (25200 25%) 0.0145
# 10m 44s (- 15m 16s) (41300 41%) 0.0050
# 10m 46s (- 15m 14s) (41400 41%) 0.0038
# 10m 47s (- 15m 13s) (41500 41%) 0.0068
# 10m 49s (- 15m 11s) (41600 41%) 0.0013
# 10m 51s (- 15m 10s) (41700 41%) 0.0025
# 10m 52s (- 15m 9s) (41800 41%) 0.0037
# 10m 54s (- 15m 7s) (41900 41%) 0.0031
# 10m 55s (- 15m 5s) (42000 42%) 0.0010
# 10m 57s (- 15m 3s) (42100 42%) 0.0102
# 10m 58s (- 15m 2s) (42200 42%) 0.0023
# 11m 0s (- 15m 0s) (42300 42%) 0.0007
# 11m 1s (- 14m 58s) (42400 42%) 0.0024
# 11m 3s (- 14m 57s) (42500 42%) 0.0069
# 11m 5s (- 14m 56s) (42600 42%) 0.0138
# 11m 6s (- 14m 54s) (42700 42%) 0.0021
# 11m 7s (- 14m 52s) (42800 42%) 0.0049
# 11m 9s (- 14m 50s) (42900 42%) 0.0029
# 11m 10s (- 14m 49s) (43000 43%) 0.0159
# 11m 12s (- 14m 47s) (43100 43%) 0.0054
# 11m 13s (- 14m 45s) (43200 43%) 0.0079
# 11m 14s (- 14m 43s) (43300 43%) 0.0017
# 11m 16s (- 14m 42s) (43400 43%) 0.0137
# 11m 18s (- 14m 41s) (43500 43%) 0.0014
# 11m 20s (- 14m 39s) (43600 43%) 0.0028
# 11m 21s (- 14m 38s) (43700 43%) 0.0015
# 11m 23s (- 14m 36s) (43800 43%) 0.0060
# 11m 24s (- 14m 34s) (43900 43%) 0.0041
# 11m 25s (- 14m 33s) (44000 44%) 0.0099
# 11m 27s (- 14m 31s) (44100 44%) 0.0065
# 11m 28s (- 14m 29s) (44200 44%) 0.0058
# 11m 30s (- 14m 28s) (44300 44%) 0.0184
# 11m 32s (- 14m 27s) (44400 44%) 0.0125
# 11m 34s (- 14m 25s) (44500 44%) 0.0112
# 11m 35s (- 14m 23s) (44600 44%) 0.0040
# 11m 36s (- 14m 22s) (44700 44%) 0.0053
# 11m 38s (- 14m 20s) (44800 44%) 0.0095
# 11m 39s (- 14m 18s) (44900 44%) 0.0119
# 11m 41s (- 14m 16s) (45000 45%) 0.0037
# 11m 42s (- 14m 15s) (45100 45%) 0.0028
# 11m 44s (- 14m 14s) (45200 45%) 0.0015
# 11m 46s (- 14m 12s) (45300 45%) 0.0012
# 11m 47s (- 14m 11s) (45400 45%) 0.0023
# 11m 49s (- 14m 9s) (45500 45%) 0.0010
# 11m 50s (- 14m 7s) (45600 45%) 0.0094
# 11m 51s (- 14m 5s) (45700 45%) 0.0028
# 11m 53s (- 14m 4s) (45800 45%) 0.0007
# 11m 54s (- 14m 2s) (45900 45%) 0.0009
# 11m 56s (- 14m 1s) (46000 46%) 0.0074
# 11m 58s (- 13m 59s) (46100 46%) 0.0352
# 11m 59s (- 13m 58s) (46200 46%) 0.0065
# 12m 1s (- 13m 56s) (46300 46%) 0.0080
# 12m 2s (- 13m 54s) (46400 46%) 0.0021
# 12m 4s (- 13m 53s) (46500 46%) 0.0084
# 14m 51s (- 11m 3s) (57300 57%) 0.0312
# 14m 52s (- 11m 2s) (57400 57%) 0.0359
# 14m 54s (- 11m 0s) (57500 57%) 0.0151
# 14m 55s (- 10m 59s) (57600 57%) 0.0028
# 14m 57s (- 10m 57s) (57700 57%) 0.0018
# 14m 58s (- 10m 55s) (57800 57%) 0.0173
# 14m 59s (- 10m 54s) (57900 57%) 0.0045
# 15m 1s (- 10m 52s) (58000 57%) 0.0220
# 15m 2s (- 10m 51s) (58100 58%) 0.0012
# 15m 4s (- 10m 49s) (58200 58%) 0.0016
# 15m 6s (- 10m 48s) (58300 58%) 0.0013
# 15m 7s (- 10m 46s) (58400 58%) 0.0048
# 15m 9s (- 10m 44s) (58500 58%) 0.0049
# 15m 10s (- 10m 43s) (58600 58%) 0.0064
# 15m 11s (- 10m 41s) (58700 58%) 0.0027
# 15m 13s (- 10m 39s) (58800 58%) 0.0007
# 15m 14s (- 10m 38s) (58900 58%) 0.0006
# 15m 16s (- 10m 36s) (59000 59%) 0.0013
# 15m 18s (- 10m 35s) (59100 59%) 0.0009
# 15m 20s (- 10m 34s) (59200 59%) 0.0005
# 15m 21s (- 10m 32s) (59300 59%) 0.0026
# 15m 22s (- 10m 30s) (59400 59%) 0.0009
# 15m 24s (- 10m 29s) (59500 59%) 0.0021
# 15m 25s (- 10m 27s) (59600 59%) 0.0084
# 15m 27s (- 10m 25s) (59700 59%) 0.0016
# 15m 28s (- 10m 24s) (59800 59%) 0.0004
# 15m 30s (- 10m 22s) (59900 59%) 0.0060
# 15m 32s (- 10m 21s) (60000 60%) 0.0055
# 15m 33s (- 10m 19s) (60100 60%) 0.0049
# 15m 35s (- 10m 18s) (60200 60%) 0.0100
# 15m 36s (- 10m 16s) (60300 60%) 0.0012
# 15m 37s (- 10m 14s) (60400 60%) 0.0007
# 15m 39s (- 10m 13s) (60500 60%) 0.0007
# 15m 40s (- 10m 11s) (60600 60%) 0.0049
# 15m 42s (- 10m 10s) (60700 60%) 0.0025
# 15m 44s (- 10m 8s) (60800 60%) 0.0188
# 15m 46s (- 10m 7s) (60900 60%) 0.0097
# 15m 47s (- 10m 5s) (61000 61%) 0.0226
# 15m 48s (- 10m 4s) (61100 61%) 0.0060
# 15m 50s (- 10m 2s) (61200 61%) 0.0039
# 15m 51s (- 10m 0s) (61300 61%) 0.0040
# 15m 52s (- 9m 59s) (61400 61%) 0.0033
# 15m 54s (- 9m 57s) (61500 61%) 0.0021
# 15m 55s (- 9m 55s) (61600 61%) 0.0008
# 15m 58s (- 9m 54s) (61700 61%) 0.0012
# 15m 59s (- 9m 53s) (61800 61%) 0.0068
# 16m 1s (- 9m 51s) (61900 61%) 0.0052
# 16m 2s (- 9m 49s) (62000 62%) 0.0035
# 16m 4s (- 9m 48s) (62100 62%) 0.0052
# 16m 5s (- 9m 46s) (62200 62%) 0.0139
# 16m 6s (- 9m 45s) (62300 62%) 0.0015
# 16m 8s (- 9m 43s) (62400 62%) 0.0005
# 16m 10s (- 9m 42s) (62500 62%) 0.0013
# 20m 16s (- 5m 31s) (78600 78%) 0.0009
# 20m 17s (- 5m 29s) (78700 78%) 0.0007
# 20m 19s (- 5m 28s) (78800 78%) 0.0003
# 20m 20s (- 5m 26s) (78900 78%) 0.0031
# 20m 22s (- 5m 24s) (79000 79%) 0.0119
# 20m 24s (- 5m 23s) (79100 79%) 0.0006
# 20m 25s (- 5m 21s) (79200 79%) 0.0006
# 20m 27s (- 5m 20s) (79300 79%) 0.0048
# 20m 28s (- 5m 18s) (79400 79%) 0.0005
# 20m 30s (- 5m 17s) (79500 79%) 0.0038
# 20m 31s (- 5m 15s) (79600 79%) 0.0014
# 20m 33s (- 5m 14s) (79700 79%) 0.0058
# 20m 34s (- 5m 12s) (79800 79%) 0.0026
# 20m 36s (- 5m 11s) (79900 79%) 0.0119
# 20m 38s (- 5m 9s) (80000 80%) 0.0095
# 20m 39s (- 5m 7s) (80100 80%) 0.0010
# 20m 41s (- 5m 6s) (80200 80%) 0.0002
# 20m 42s (- 5m 4s) (80300 80%) 0.0013
# 20m 43s (- 5m 3s) (80400 80%) 0.0007
# 20m 45s (- 5m 1s) (80500 80%) 0.0001
# 20m 46s (- 5m 0s) (80600 80%) 0.0011
# 20m 48s (- 4m 58s) (80700 80%) 0.0046
# 20m 50s (- 4m 57s) (80800 80%) 0.0006
# 20m 52s (- 4m 55s) (80900 80%) 0.0048
# 20m 53s (- 4m 54s) (81000 81%) 0.0172
# 20m 54s (- 4m 52s) (81100 81%) 0.0228
# 20m 56s (- 4m 50s) (81200 81%) 0.0714
# 20m 57s (- 4m 49s) (81300 81%) 0.0052
# 20m 59s (- 4m 47s) (81400 81%) 0.0041
# 21m 0s (- 4m 46s) (81500 81%) 0.0067
# 21m 2s (- 4m 44s) (81600 81%) 0.0014
# 21m 4s (- 4m 43s) (81700 81%) 0.0032
# 21m 5s (- 4m 41s) (81800 81%) 0.0039
# 21m 7s (- 4m 40s) (81900 81%) 0.0007
# 21m 8s (- 4m 38s) (82000 82%) 0.0005
# 21m 10s (- 4m 36s) (82100 82%) 0.0003
# 21m 11s (- 4m 35s) (82200 82%) 0.0005
# 21m 12s (- 4m 33s) (82300 82%) 0.0007
# 21m 14s (- 4m 32s) (82400 82%) 0.0052
# 21m 16s (- 4m 30s) (82500 82%) 0.0009
# 21m 18s (- 4m 29s) (82600 82%) 0.0010
# 21m 19s (- 4m 27s) (82700 82%) 0.0006
# 21m 20s (- 4m 26s) (82800 82%) 0.0003
# 21m 22s (- 4m 24s) (82900 82%) 0.0005
# 21m 23s (- 4m 22s) (83000 83%) 0.0016
# 21m 25s (- 4m 21s) (83100 83%) 0.0009
# 21m 26s (- 4m 19s) (83200 83%) 0.0066
# 21m 28s (- 4m 18s) (83300 83%) 0.0030
# 21m 30s (- 4m 16s) (83400 83%) 0.0051
# 21m 31s (- 4m 15s) (83500 83%) 0.0010
# 21m 33s (- 4m 13s) (83600 83%) 0.0010
# 21m 34s (- 4m 12s) (83700 83%) 0.0026
# 21m 36s (- 4m 10s) (83800 83%) 0.0047
# 21m 37s (- 4m 8s) (83900 83%) 0.0004
# 25m 46s (- 0m 0s) (100000 100%) 0.0001

# %%
len(eval_set_lenght)
# Out:
# 3921

# %%
eval = [eval_set_lenght[i] for i in range(3920)]
encoder.eval()
decoder.eval()
evaluate(encoder, decoder, eval, input_vocab, output_vocab)
# Out:
# Streaming output truncated to the last 5000 lines.
# 28
# succes  27 out of 29
# partial succes  27 out of 29
# 29
# succes  28 out of 30
# partial succes  28 out of 30
# 30
# succes  29 out of 31
# partial succes  29 out of 31
# 31
# succes  30 out of 32
# partial succes  30 out of 32
# 32
# 33
# succes  31 out of 34
# partial succes  31 out of 34
# 34
# succes  32 out of 35
# partial succes  32 out of 35
# 35
# succes  33 out of 36
# partial succes  33 out of 36
# 36
# succes  34 out of 37
# partial succes  34 out of 37
# 37
# 38
# 39
# succes  35 out of 40
# partial succes  35 out of 40
# 40
# succes  36 out of 41
# partial succes  36 out of 41
# 41
# succes  37 out of 42
# partial succes  37 out of 42
# 42
# succes  38 out of 43
# partial succes  38 out of 43
# 43
# succes  39 out of 44
# partial succes  39 out of 44
# 44
# 45
# 46
# succes  40 out of 47
# partial succes  40 out of 47
# 47
# 48
# succes  41 out of 49
# partial succes  41 out of 49
# 49
# succes  42 out of 50
# partial succes  42 out of 50
# 50
# succes  43 out of 51
# partial succes  43 out of 51
# 51
# succes  44 out of 52
# partial succes  44 out of 52
# 52
# succes  45 out of 53
# partial succes  45 out of 53
# 53
# succes  46 out of 54
# partial succes  46 out of 54
# 54
# 55
# succes  47 out of 56
# partial succes  47 out of 56
# 56
# succes  48 out of 57
# partial succes  48 out of 57
# 57
# succes  49 out of 58
# partial succes  49 out of 58
# 58
# 59
# succes  50 out of 60
# partial succes  50 out of 60
# 60
# succes  51 out of 61
# partial succes  51 out of 61
# 61
# succes  52 out of 62
# partial succes  52 out of 62
# 62
# succes  53 out of 63
# partial succes  53 out of 63
# 63
# succes  54 out of 64
# partial succes  54 out of 64
# 64
# succes  55 out of 65
# partial succes  55 out of 65
# 65
# succes  56 out of 66
# partial succes  56 out of 66
# 66
# 67
# succes  57 out of 68
# partial succes  57 out of 68
# 68
# 69
# succes  58 out of 70
# partial succes  58 out of 70
# 70
# succes  59 out of 71
# partial succes  59 out of 71
# 71
# succes  60 out of 72
# partial succes  60 out of 72
# 72
# succes  61 out of 73
# partial succes  61 out of 73
# 73
# 74
# 75
# succes  62 out of 76
# partial succes  62 out of 76
# 76
# succes  63 out of 77
# partial succes  63 out of 77
# 77
# succes  64 out of 78
# partial succes  64 out of 78
# 78
# succes  65 out of 79
# partial succes  65 out of 79
# 79
# succes  66 out of 80
# partial succes  66 out of 80
# 80
# succes  67 out of 81
# partial succes  67 out of 81
# 81
# succes  68 out of 82
# partial succes  68 out of 82
# 82
# succes  69 out of 83
# partial succes  69 out of 83
# 83
# 84
# succes  70 out of 85
# partial succes  70 out of 85
# 85
# succes  71 out of 86
# partial succes  71 out of 86
# 86
# succes  72 out of 87
# partial succes  72 out of 87
# 87
# succes  73 out of 88
# partial succes  73 out of 88
# 88
# succes  74 out of 89
# partial succes  74 out of 89
# 89
# succes  75 out of 90
# partial succes  75 out of 90
# 90
# 91
# succes  76 out of 92
# partial succes  76 out of 92
# 92
# succes  77 out of 93
# partial succes  77 out of 93
# 93
# 94
# 95
# succes  78 out of 96
# partial succes  78 out of 96
# 96
# succes  79 out of 97
# partial succes  79 out of 97
# 97
# 98
# 99
# 100
# succes  80 out of 101
# partial succes  80 out of 101
# 101
# succes  81 out of 102
# partial succes  81 out of 102
# 102
# succes  82 out of 103
# partial succes  82 out of 103
# 103
# succes  83 out of 104
# partial succes  83 out of 104
# 104
# succes  84 out of 105
# partial succes  84 out of 105
# 105
# succes  85 out of 106
# partial succes  85 out of 106
# 106
# 107
# succes  86 out of 108
# partial succes  86 out of 108
# 108
# succes  87 out of 109
# partial succes  87 out of 109
# 109
# succes  88 out of 110
# partial succes  88 out of 110
# 110
# 111
# succes  89 out of 112
# partial succes  89 out of 112
# 112
# succes  90 out of 113
# partial succes  90 out of 113
# 113
# succes  91 out of 114
# partial succes  91 out of 114
# 114
# succes  92 out of 115
# partial succes  92 out of 115
# 115
# succes  93 out of 116
# partial succes  93 out of 116
# 116
# succes  94 out of 117
# partial succes  94 out of 117
# 117
# succes  95 out of 118
# partial succes  95 out of 118
# 118
# succes  96 out of 119
# partial succes  96 out of 119
# 119
# 120
# succes  97 out of 121
# partial succes  97 out of 121
# 121
# succes  98 out of 122
# partial succes  98 out of 122
# 122
# succes  99 out of 123
# partial succes  99 out of 123
# 123
# succes  100 out of 124
# partial succes  100 out of 124
# 124
# succes  101 out of 125
# partial succes  101 out of 125
# 125
# succes  102 out of 126
# partial succes  102 out of 126
# 126
# succes  103 out of 127
# partial succes  103 out of 127
# 127
# 128
# succes  104 out of 129
# partial succes  104 out of 129
# 129
# succes  105 out of 130
# partial succes  105 out of 130
# 130
# succes  106 out of 131
# partial succes  106 out of 131
# 131
# succes  107 out of 132
# partial succes  107 out of 132
# 132
# succes  108 out of 133
# partial succes  108 out of 133
# 133
# succes  109 out of 134
# partial succes  109 out of 134
# 134
# succes  110 out of 135
# partial succes  110 out of 135
# 135
# succes  111 out of 136
# partial succes  111 out of 136
# 136
# succes  112 out of 137
# partial succes  112 out of 137
# 137
# succes  113 out of 138
# partial succes  113 out of 138
# 138
# succes  114 out of 139
# partial succes  114 out of 139
# 139
# succes  115 out of 140
# partial succes  115 out of 140
# 140
# succes  116 out of 141
# partial succes  116 out of 141
# 141
# succes  117 out of 142
# partial succes  117 out of 142
# 142
# succes  118 out of 143
# partial succes  118 out of 143
# 143
# succes  119 out of 144
# partial succes  119 out of 144
# 144
# succes  120 out of 145
# partial succes  120 out of 145
# 145
# succes  121 out of 146
# partial succes  121 out of 146
# 146
# succes  122 out of 147
# partial succes  122 out of 147
# 147
# succes  123 out of 148
# partial succes  123 out of 148
# 148
# succes  124 out of 149
# partial succes  124 out of 149
# 149
# succes  125 out of 150
# partial succes  125 out of 150
# 150
# succes  126 out of 151
# partial succes  126 out of 151
# 151
# succes  127 out of 152
# partial succes  127 out of 152
# 152
# succes  128 out of 153
# partial succes  128 out of 153
# 153
# 154
# succes  129 out of 155
# partial succes  129 out of 155
# 155
# succes  130 out of 156
# partial succes  130 out of 156
# 156
# succes  131 out of 157
# partial succes  131 out of 157
# 157
# succes  132 out of 158
# partial succes  132 out of 158
# 158
# succes  133 out of 159
# partial succes  133 out of 159
# 159
# succes  134 out of 160
# partial succes  134 out of 160
# 160
# succes  135 out of 161
# partial succes  135 out of 161
# 161
# succes  136 out of 162
# partial succes  136 out of 162
# 162
# succes  137 out of 163
# partial succes  137 out of 163
# 163
# succes  138 out of 164
# partial succes  138 out of 164
# 164
# succes  139 out of 165
# partial succes  139 out of 165
# 165
# succes  140 out of 166
# partial succes  140 out of 166
# 166
# succes  141 out of 167
# partial succes  141 out of 167
# 167
# succes  142 out of 168
# partial succes  142 out of 168
# 168
# succes  143 out of 169
# partial succes  143 out of 169
# 169
# succes  144 out of 170
# partial succes  144 out of 170
# 170
# succes  145 out of 171
# partial succes  145 out of 171
# 171
# 172
# succes  146 out of 173
# partial succes  146 out of 173
# 173
# succes  147 out of 174
# partial succes  147 out of 174
# 174
# succes  148 out of 175
# partial succes  148 out of 175
# 175
# succes  149 out of 176
# partial succes  149 out of 176
# 176
# succes  150 out of 177
# partial succes  150 out of 177
# 177
# succes  151 out of 178
# partial succes  151 out of 178
# 178
# succes  152 out of 179
# partial succes  152 out of 179
# 179
# succes  153 out of 180
# partial succes  153 out of 180
# 180
# 181
# succes  154 out of 182
# partial succes  154 out of 182
# 182
# succes  155 out of 183
# partial succes  155 out of 183
# 183
# 184
# succes  156 out of 185
# partial succes  156 out of 185
# 185
# succes  157 out of 186
# partial succes  157 out of 186
# 186
# succes  158 out of 187
# partial succes  158 out of 187
# 187
# 188
# succes  159 out of 189
# partial succes  159 out of 189
# 189
# succes  160 out of 190
# partial succes  160 out of 190
# 190
# succes  161 out of 191
# partial succes  161 out of 191
# 191
# succes  162 out of 192
# partial succes  162 out of 192
# 192
# succes  163 out of 193
# partial succes  163 out of 193
# 193
# 194
# 195
# succes  164 out of 196
# partial succes  164 out of 196
# 196
# succes  165 out of 197
# partial succes  165 out of 197
# 197
# succes  166 out of 198
# partial succes  166 out of 198
# 198
# 199
# succes  167 out of 200
# partial succes  167 out of 200
# 200
# succes  168 out of 201
# partial succes  168 out of 201
# 201
# succes  169 out of 202
# partial succes  169 out of 202
# 202
# succes  170 out of 203
# partial succes  170 out of 203
# 203
# succes  171 out of 204
# partial succes  171 out of 204
# 204
# succes  172 out of 205
# partial succes  172 out of 205
# 205
# succes  173 out of 206
# partial succes  173 out of 206
# 206
# 207
# succes  174 out of 208
# partial succes  174 out of 208
# 208
# succes  175 out of 209
# partial succes  175 out of 209
# 209
# succes  176 out of 210
# partial succes  176 out of 210
# 210
# succes  177 out of 211
# partial succes  177 out of 211
# 211
# succes  178 out of 212
# partial succes  178 out of 212
# 212
# succes  179 out of 213
# partial succes  179 out of 213
# 213
# succes  180 out of 214
# partial succes  180 out of 214
# 214
# succes  181 out of 215
# partial succes  181 out of 215
# 215
# succes  182 out of 216
# partial succes  182 out of 216
# 216
# succes  183 out of 217
# partial succes  183 out of 217
# 217
# succes  184 out of 218
# partial succes  184 out of 218
# 218
# succes  185 out of 219
# partial succes  185 out of 219
# 219
# succes  186 out of 220
# partial succes  186 out of 220
# 220
# succes  187 out of 221
# partial succes  187 out of 221
# 221
# succes  188 out of 222
# partial succes  188 out of 222
# 222
# succes  189 out of 223
# partial succes  189 out of 223
# 223
# succes  190 out of 224
# partial succes  190 out of 224
# 224
# succes  191 out of 225
# partial succes  191 out of 225
# 225
# succes  192 out of 226
# partial succes  192 out of 226
# 226
# 227
# succes  193 out of 228
# partial succes  193 out of 228
# 228
# succes  194 out of 229
# partial succes  194 out of 229
# 229
# succes  195 out of 230
# partial succes  195 out of 230
# 230
# succes  196 out of 231
# partial succes  196 out of 231
# 231
# 232
# succes  197 out of 233
# partial succes  197 out of 233
# 233
# 234
# succes  198 out of 235
# partial succes  198 out of 235
# 235
# succes  199 out of 236
# partial succes  199 out of 236
# 236
# succes  200 out of 237
# partial succes  200 out of 237
# 237
# succes  201 out of 238
# partial succes  201 out of 238
# 238
# succes  202 out of 239
# partial succes  202 out of 239
# 239
# succes  203 out of 240
# partial succes  203 out of 240
# 240
# succes  204 out of 241
# partial succes  204 out of 241
# 241
# succes  205 out of 242
# partial succes  205 out of 242
# 242
# succes  206 out of 243
# partial succes  206 out of 243
# 243
# succes  207 out of 244
# partial succes  207 out of 244
# 244
# 245
# 246
# succes  208 out of 247
# partial succes  208 out of 247
# 247
# succes  209 out of 248
# partial succes  209 out of 248
# 248
# succes  210 out of 249
# partial succes  210 out of 249
# 249
# succes  211 out of 250
# partial succes  211 out of 250
# 250
# succes  212 out of 251
# partial succes  212 out of 251
# 251
# succes  213 out of 252
# partial succes  213 out of 252
# 252
# succes  214 out of 253
# partial succes  214 out of 253
# 253
# succes  215 out of 254
# partial succes  215 out of 254
# 254
# succes  216 out of 255
# partial succes  216 out of 255
# 255
# succes  217 out of 256
# partial succes  217 out of 256
# 256
# succes  218 out of 257
# partial succes  218 out of 257
# 257
# 258
# succes  219 out of 259
# partial succes  219 out of 259
# 259
# succes  220 out of 260
# partial succes  220 out of 260
# 260
# succes  221 out of 261
# partial succes  221 out of 261
# 261
# succes  222 out of 262
# partial succes  222 out of 262
# 262
# succes  223 out of 263
# partial succes  223 out of 263
# 263
# 264
# succes  224 out of 265
# partial succes  224 out of 265
# 265
# succes  225 out of 266
# partial succes  225 out of 266
# 266
# succes  226 out of 267
# partial succes  226 out of 267
# 267
# succes  227 out of 268
# partial succes  227 out of 268
# 268
# 269
# succes  228 out of 270
# partial succes  228 out of 270
# 270
# succes  229 out of 271
# partial succes  229 out of 271
# 271
# 272
# succes  230 out of 273
# partial succes  230 out of 273
# 273
# succes  231 out of 274
# partial succes  231 out of 274
# 274
# succes  232 out of 275
# partial succes  232 out of 275
# 275
# 276
# succes  233 out of 277
# partial succes  233 out of 277
# 277
# succes  234 out of 278
# partial succes  234 out of 278
# 278
# succes  235 out of 279
# partial succes  235 out of 279
# 279
# succes  236 out of 280
# partial succes  236 out of 280
# 280
# succes  237 out of 281
# partial succes  237 out of 281
# 281
# succes  238 out of 282
# partial succes  238 out of 282
# 282
# succes  239 out of 283
# partial succes  239 out of 283
# 283
# succes  240 out of 284
# partial succes  240 out of 284
# 284
# succes  241 out of 285
# partial succes  241 out of 285
# 285
# succes  242 out of 286
# partial succes  242 out of 286
# 286
# succes  243 out of 287
# partial succes  243 out of 287
# 287
# succes  244 out of 288
# partial succes  244 out of 288
# 288
# succes  245 out of 289
# partial succes  245 out of 289
# 289
# succes  246 out of 290
# partial succes  246 out of 290
# 290
# succes  247 out of 291
# partial succes  247 out of 291
# 291
# succes  248 out of 292
# partial succes  248 out of 292
# 292
# succes  249 out of 293
# partial succes  249 out of 293
# 293
# succes  250 out of 294
# partial succes  250 out of 294
# 294
# succes  251 out of 295
# partial succes  251 out of 295
# 295
# succes  252 out of 296
# partial succes  252 out of 296
# 296
# succes  253 out of 297
# partial succes  253 out of 297
# 297
# succes  254 out of 298
# partial succes  254 out of 298
# 298
# succes  255 out of 299
# partial succes  255 out of 299
# 299
# succes  256 out of 300
# partial succes  256 out of 300
# 300
# succes  257 out of 301
# partial succes  257 out of 301
# 301
# succes  258 out of 302
# partial succes  258 out of 302
# 302
# succes  259 out of 303
# partial succes  259 out of 303
# 303
# succes  260 out of 304
# partial succes  260 out of 304
# 304
# succes  261 out of 305
# partial succes  261 out of 305
# 305
# 306
# succes  262 out of 307
# partial succes  262 out of 307
# 307
# 308
# succes  263 out of 309
# partial succes  263 out of 309
# 309
# 310
# succes  264 out of 311
# partial succes  264 out of 311
# 311
# succes  265 out of 312
# partial succes  265 out of 312
# 312
# succes  266 out of 313
# partial succes  266 out of 313
# 313
# succes  267 out of 314
# partial succes  267 out of 314
# 314
# succes  268 out of 315
# partial succes  268 out of 315
# 315
# succes  269 out of 316
# partial succes  269 out of 316
# 316
# succes  270 out of 317
# partial succes  270 out of 317
# 317
# succes  271 out of 318
# partial succes  271 out of 318
# 318
# succes  272 out of 319
# partial succes  272 out of 319
# 319
# succes  273 out of 320
# partial succes  273 out of 320
# 320
# succes  274 out of 321
# partial succes  274 out of 321
# 321
# succes  275 out of 322
# partial succes  275 out of 322
# 322
# succes  276 out of 323
# partial succes  276 out of 323
# 323
# succes  277 out of 324
# partial succes  277 out of 324
# 324
# 325
# succes  278 out of 326
# partial succes  278 out of 326
# 326
# succes  279 out of 327
# partial succes  279 out of 327
# 327
# succes  280 out of 328
# partial succes  280 out of 328
# 328
# succes  281 out of 329
# partial succes  281 out of 329
# 329
# succes  282 out of 330
# partial succes  282 out of 330
# 330
# succes  283 out of 331
# partial succes  283 out of 331
# 331
# succes  284 out of 332
# partial succes  284 out of 332
# 332
# succes  285 out of 333
# partial succes  285 out of 333
# 333
# 334
# succes  286 out of 335
# partial succes  286 out of 335
# 335
# succes  287 out of 336
# partial succes  287 out of 336
# 336
# 337
# succes  288 out of 338
# partial succes  288 out of 338
# 338
# 339
# succes  289 out of 340
# partial succes  289 out of 340
# 340
# succes  290 out of 341
# partial succes  290 out of 341
# 341
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# succes  291 out of 349
# partial succes  291 out of 349
# 349
# succes  292 out of 350
# partial succes  292 out of 350
# 350
# 351
# 352
# succes  293 out of 353
# partial succes  293 out of 353
# 353
# succes  294 out of 354
# partial succes  294 out of 354
# 354
# 355
# succes  295 out of 356
# partial succes  295 out of 356
# 356
# succes  296 out of 357
# partial succes  296 out of 357
# 357
# succes  297 out of 358
# partial succes  297 out of 358
# 358
# succes  298 out of 359
# partial succes  298 out of 359
# 359
# succes  299 out of 360
# partial succes  299 out of 360
# 360
# succes  300 out of 361
# partial succes  300 out of 361
# 361
# 362
# 363
# succes  301 out of 364
# partial succes  301 out of 364
# 364
# 365
# 366
# 367
# succes  302 out of 368
# partial succes  302 out of 368
# 368
# succes  303 out of 369
# partial succes  303 out of 369
# 369
# succes  304 out of 370
# partial succes  304 out of 370
# 370
# succes  305 out of 371
# partial succes  305 out of 371
# 371
# succes  306 out of 372
# partial succes  306 out of 372
# 372
# 373
# succes  307 out of 374
# partial succes  307 out of 374
# 374
# 375
# 376
# succes  308 out of 377
# partial succes  308 out of 377
# 377
# 378
# 379
# 380
# succes  309 out of 381
# partial succes  309 out of 381
# 381
# succes  310 out of 382
# partial succes  310 out of 382
# 382
# 383
# succes  311 out of 384
# partial succes  311 out of 384
# 384
# succes  312 out of 385
# partial succes  312 out of 385
# 385
# 386
# succes  313 out of 387
# partial succes  313 out of 387
# 387
# succes  314 out of 388
# partial succes  314 out of 388
# 388
# 389
# 390
# succes  315 out of 391
# partial succes  315 out of 391
# 391
# succes  316 out of 392
# partial succes  316 out of 392
# 392
# 393
# 394
# 395
# succes  317 out of 396
# partial succes  317 out of 396
# 396
# succes  318 out of 397
# partial succes  318 out of 397
# 397
# succes  319 out of 398
# partial succes  319 out of 398
# 398
# succes  320 out of 399
# partial succes  320 out of 399
# 399
# succes  321 out of 400
# partial succes  321 out of 400
# 400
# succes  322 out of 401
# partial succes  322 out of 401
# 401
# succes  323 out of 402
# partial succes  323 out of 402
# 402
# succes  324 out of 403
# partial succes  324 out of 403
# 403
# succes  325 out of 404
# partial succes  325 out of 404
# 404
# succes  326 out of 405
# partial succes  326 out of 405
# 405
# 406
# succes  327 out of 407
# partial succes  327 out of 407
# 407
# succes  328 out of 408
# partial succes  328 out of 408
# 408
# succes  329 out of 409
# partial succes  329 out of 409
# 409
# 410
# 411
# succes  330 out of 412
# partial succes  330 out of 412
# 412
# succes  331 out of 413
# partial succes  331 out of 413
# 413
# succes  332 out of 414
# partial succes  332 out of 414
# 414
# 415
# succes  333 out of 416
# partial succes  333 out of 416
# 416
# succes  334 out of 417
# partial succes  334 out of 417
# 417
# succes  335 out of 418
# partial succes  335 out of 418
# 418
# 419
# succes  336 out of 420
# partial succes  336 out of 420
# 420
# 421
# succes  337 out of 422
# partial succes  337 out of 422
# 422
# 423
# succes  338 out of 424
# partial succes  338 out of 424
# 424
# succes  339 out of 425
# partial succes  339 out of 425
# 425
# 426
# 427
# 428
# 429
# succes  340 out of 430
# partial succes  340 out of 430
# 430
# 431
# succes  341 out of 432
# partial succes  341 out of 432
# 432
# succes  342 out of 433
# partial succes  342 out of 433
# 433
# succes  343 out of 434
# partial succes  343 out of 434
# 434
# 435
# succes  344 out of 436
# partial succes  344 out of 436
# 436
# succes  345 out of 437
# partial succes  345 out of 437
# 437
# 438
# 439
# succes  346 out of 440
# partial succes  346 out of 440
# 440
# 441
# 442
# succes  347 out of 443
# partial succes  347 out of 443
# 443
# 444
# 445
# succes  348 out of 446
# partial succes  348 out of 446
# 446
# succes  349 out of 447
# partial succes  349 out of 447
# 447
# succes  350 out of 448
# partial succes  350 out of 448
# 448
# 449
# succes  351 out of 450
# partial succes  351 out of 450
# 450
# succes  352 out of 451
# partial succes  352 out of 451
# 451
# succes  353 out of 452
# partial succes  353 out of 452
# 452
# 453
# 454
# succes  354 out of 455
# partial succes  354 out of 455
# 455
# succes  355 out of 456
# partial succes  355 out of 456
# 456
# 457
# succes  356 out of 458
# partial succes  356 out of 458
# 458
# 459
# 460
# succes  357 out of 461
# partial succes  357 out of 461
# 461
# 462
# succes  358 out of 463
# partial succes  358 out of 463
# 463
# succes  359 out of 464
# partial succes  359 out of 464
# 464
# 465
# succes  360 out of 466
# partial succes  360 out of 466
# 466
# succes  361 out of 467
# partial succes  361 out of 467
# 467
# succes  362 out of 468
# partial succes  362 out of 468
# 468
# succes  363 out of 469
# partial succes  363 out of 469
# 469
# 470
# 471
# succes  364 out of 472
# partial succes  364 out of 472
# 472
# 473
# succes  365 out of 474
# partial succes  365 out of 474
# 474
# succes  366 out of 475
# partial succes  366 out of 475
# 475
# 476
# succes  367 out of 477
# partial succes  367 out of 477
# 477
# 478
# succes  368 out of 479
# partial succes  368 out of 479
# 479
# succes  369 out of 480
# partial succes  369 out of 480
# 480
# succes  370 out of 481
# partial succes  370 out of 481
# 481
# succes  371 out of 482
# partial succes  371 out of 482
# 482
# succes  372 out of 483
# partial succes  372 out of 483
# 483
# succes  373 out of 484
# partial succes  373 out of 484
# 484
# succes  374 out of 485
# partial succes  374 out of 485
# 485
# 486
# 487
# 488
# 489
# succes  375 out of 490
# partial succes  375 out of 490
# 490
# succes  376 out of 491
# partial succes  376 out of 491
# 491
# succes  377 out of 492
# partial succes  377 out of 492
# 492
# 493
# 494
# succes  378 out of 495
# partial succes  378 out of 495
# 495
# succes  379 out of 496
# partial succes  379 out of 496
# 496
# succes  380 out of 497
# partial succes  380 out of 497
# 497
# succes  381 out of 498
# partial succes  381 out of 498
# 498
# succes  382 out of 499
# partial succes  382 out of 499
# 499
# 500
# 501
# succes  383 out of 502
# partial succes  383 out of 502
# 502
# succes  384 out of 503
# partial succes  384 out of 503
# 503
# 504
# 505
# succes  385 out of 506
# partial succes  385 out of 506
# 506
# succes  386 out of 507
# partial succes  386 out of 507
# 507
# succes  387 out of 508
# partial succes  387 out of 508
# 508
# succes  388 out of 509
# partial succes  388 out of 509
# 509
# succes  389 out of 510
# partial succes  389 out of 510
# 510
# 511
# 512
# succes  390 out of 513
# partial succes  390 out of 513
# 513
# 514
# 515
# succes  391 out of 516
# partial succes  391 out of 516
# 516
# succes  392 out of 517
# partial succes  392 out of 517
# 517
# succes  393 out of 518
# partial succes  393 out of 518
# 518
# 519
# succes  394 out of 520
# partial succes  394 out of 520
# 520
# 521
# succes  395 out of 522
# partial succes  395 out of 522
# 522
# 523
# succes  396 out of 524
# partial succes  396 out of 524
# 524
# succes  397 out of 525
# partial succes  397 out of 525
# 525
# 526
# succes  398 out of 527
# partial succes  398 out of 527
# 527
# 528
# succes  399 out of 529
# partial succes  399 out of 529
# 529
# 530
# succes  400 out of 531
# partial succes  400 out of 531
# 531
# succes  401 out of 532
# partial succes  401 out of 532
# 532
# succes  402 out of 533
# partial succes  402 out of 533
# 533
# succes  403 out of 534
# partial succes  403 out of 534
# 534
# succes  404 out of 535
# partial succes  404 out of 535
# 535
# succes  405 out of 536
# partial succes  405 out of 536
# 536
# 537
# 538
# succes  406 out of 539
# partial succes  406 out of 539
# 539
# succes  407 out of 540
# partial succes  407 out of 540
# 540
# succes  408 out of 541
# partial succes  408 out of 541
# 541
# succes  409 out of 542
# partial succes  409 out of 542
# 542
# succes  410 out of 543
# partial succes  410 out of 543
# 543
# succes  411 out of 544
# partial succes  411 out of 544
# 544
# succes  412 out of 545
# partial succes  412 out of 545
# 545
# succes  413 out of 546
# partial succes  413 out of 546
# 546
# succes  414 out of 547
# partial succes  414 out of 547
# 547
# succes  415 out of 548
# partial succes  415 out of 548
# 548
# 549
# succes  416 out of 550
# partial succes  416 out of 550
# 550
# succes  417 out of 551
# partial succes  417 out of 551
# 551
# 552
# 553
# succes  418 out of 554
# partial succes  418 out of 554
# 554
# succes  419 out of 555
# partial succes  419 out of 555
# 555
# succes  420 out of 556
# partial succes  420 out of 556
# 556
# succes  421 out of 557
# partial succes  421 out of 557
# 557
# succes  422 out of 558
# partial succes  422 out of 558
# 558
# 559
# 560
# 561
# succes  423 out of 562
# partial succes  423 out of 562
# 562
# succes  424 out of 563
# partial succes  424 out of 563
# 563
# 564
# 565
# succes  425 out of 566
# partial succes  425 out of 566
# 566
# 567
# succes  426 out of 568
# partial succes  426 out of 568
# 568
# 569
# 570
# 571
# succes  427 out of 572
# partial succes  427 out of 572
# 572
# succes  428 out of 573
# partial succes  428 out of 573
# 573
# 574
# succes  429 out of 575
# partial succes  429 out of 575
# 575
# 576
# succes  430 out of 577
# partial succes  430 out of 577
# 577
# succes  431 out of 578
# partial succes  431 out of 578
# 578
# 579
# 580
# 581
# succes  432 out of 582
# partial succes  432 out of 582
# 582
# succes  433 out of 583
# partial succes  433 out of 583
# 583
# succes  434 out of 584
# partial succes  434 out of 584
# 584
# 585
# 586
# 587
# succes  435 out of 588
# partial succes  435 out of 588
# 588
# 589
# 590
# succes  436 out of 591
# partial succes  436 out of 591
# 591
# succes  437 out of 592
# partial succes  437 out of 592
# 592
# succes  438 out of 593
# partial succes  438 out of 593
# 593
# 594
# 595
# 596
# 597
# 598
# succes  439 out of 599
# partial succes  439 out of 599
# 599
# succes  440 out of 600
# partial succes  440 out of 600
# 600
# 601
# 602
# succes  441 out of 603
# partial succes  441 out of 603
# 603
# 604
# succes  442 out of 605
# partial succes  442 out of 605
# 605
# 606
# 607
# 608
# 609
# 610
# 611
# 612
# succes  443 out of 613
# partial succes  443 out of 613
# 613
# 614
# succes  444 out of 615
# partial succes  444 out of 615
# 615
# succes  445 out of 616
# partial succes  445 out of 616
# 616
# succes  446 out of 617
# partial succes  446 out of 617
# 617
# 618
# succes  447 out of 619
# partial succes  447 out of 619
# 619
# succes  448 out of 620
# partial succes  448 out of 620
# 620
# 621
# succes  449 out of 622
# partial succes  449 out of 622
# 622
# 623
# 624
# succes  450 out of 625
# partial succes  450 out of 625
# 625
# 626
# succes  451 out of 627
# partial succes  451 out of 627
# 627
# 628
# 629
# 630
# 631
# succes  452 out of 632
# partial succes  452 out of 632
# 632
# 633
# 634
# 635
# 636
# 637
# succes  453 out of 638
# partial succes  453 out of 638
# 638
# succes  454 out of 639
# partial succes  454 out of 639
# 639
# succes  455 out of 640
# partial succes  455 out of 640
# 640
# succes  456 out of 641
# partial succes  456 out of 641
# 641
# 642
# succes  457 out of 643
# partial succes  457 out of 643
# 643
# 644
# 645
# 646
# 647
# 648
# succes  458 out of 649
# partial succes  458 out of 649
# 649
# 650
# 651
# 652
# succes  459 out of 653
# partial succes  459 out of 653
# 653
# succes  460 out of 654
# partial succes  460 out of 654
# 654
# succes  461 out of 655
# partial succes  461 out of 655
# 655
# succes  462 out of 656
# partial succes  462 out of 656
# 656
# 657
# succes  463 out of 658
# partial succes  463 out of 658
# 658
# succes  464 out of 659
# partial succes  464 out of 659
# 659
# 660
# succes  465 out of 661
# partial succes  465 out of 661
# 661
# succes  466 out of 662
# partial succes  466 out of 662
# 662
# succes  467 out of 663
# partial succes  467 out of 663
# 663
# succes  468 out of 664
# partial succes  468 out of 664
# 664
# succes  469 out of 665
# partial succes  469 out of 665
# 665
# succes  470 out of 666
# partial succes  470 out of 666
# 666
# succes  471 out of 667
# partial succes  471 out of 667
# 667
# 668
# succes  472 out of 669
# partial succes  472 out of 669
# 669
# succes  473 out of 670
# partial succes  473 out of 670
# 670
# 671
# 672
# 673
# succes  474 out of 674
# partial succes  474 out of 674
# 674
# succes  475 out of 675
# partial succes  475 out of 675
# 675
# succes  476 out of 676
# partial succes  476 out of 676
# 676
# succes  477 out of 677
# partial succes  477 out of 677
# 677
# 678
# succes  478 out of 679
# partial succes  478 out of 679
# 679
# succes  479 out of 680
# partial succes  479 out of 680
# 680
# succes  480 out of 681
# partial succes  480 out of 681
# 681
# 682
# 683
# succes  481 out of 684
# partial succes  481 out of 684
# 684
# 685
# 686
# succes  482 out of 687
# partial succes  482 out of 687
# 687
# succes  483 out of 688
# partial succes  483 out of 688
# 688
# succes  484 out of 689
# partial succes  484 out of 689
# 689
# succes  485 out of 690
# partial succes  485 out of 690
# 690
# succes  486 out of 691
# partial succes  486 out of 691
# 691
# succes  487 out of 692
# partial succes  487 out of 692
# 692
# succes  488 out of 693
# partial succes  488 out of 693
# 693
# 694
# succes  489 out of 695
# partial succes  489 out of 695
# 695
# 696
# succes  490 out of 697
# partial succes  490 out of 697
# 697
# 698
# succes  491 out of 699
# partial succes  491 out of 699
# 699
# succes  492 out of 700
# partial succes  492 out of 700
# 700
# succes  493 out of 701
# partial succes  493 out of 701
# 701
# 702
# 703
# 704
# succes  494 out of 705
# partial succes  494 out of 705
# 705
# 706
# 707
# succes  495 out of 708
# partial succes  495 out of 708
# 708
# succes  496 out of 709
# partial succes  496 out of 709
# 709
# 710
# succes  497 out of 711
# partial succes  497 out of 711
# 711
# succes  498 out of 712
# partial succes  498 out of 712
# 712
# 713
# 714
# succes  499 out of 715
# partial succes  499 out of 715
# 715
# succes  500 out of 716
# partial succes  500 out of 716
# 716
# succes  501 out of 717
# partial succes  501 out of 717
# 717
# 718
# 719
# succes  502 out of 720
# partial succes  502 out of 720
# 720
# 721
# succes  503 out of 722
# partial succes  503 out of 722
# 722
# succes  504 out of 723
# partial succes  504 out of 723
# 723
# succes  505 out of 724
# partial succes  505 out of 724
# 724
# 725
# 726
# succes  506 out of 727
# partial succes  506 out of 727
# 727
# 728
# 729
# 730
# succes  507 out of 731
# partial succes  507 out of 731
# 731
# succes  508 out of 732
# partial succes  508 out of 732
# 732
# succes  509 out of 733
# partial succes  509 out of 733
# 733
# 734
# 735
# succes  510 out of 736
# partial succes  510 out of 736
# 736
# 737
# succes  511 out of 738
# partial succes  511 out of 738
# 738
# 739
# 740
# succes  512 out of 741
# partial succes  512 out of 741
# 741
# succes  513 out of 742
# partial succes  513 out of 742
# 742
# succes  514 out of 743
# partial succes  514 out of 743
# 743
# 744
# 745
# 746
# 747
# succes  515 out of 748
# partial succes  515 out of 748
# 748
# succes  516 out of 749
# partial succes  516 out of 749
# 749
# 750
# succes  517 out of 751
# partial succes  517 out of 751
# 751
# succes  518 out of 752
# partial succes  518 out of 752
# 752
# succes  519 out of 753
# partial succes  519 out of 753
# 753
# 754
# succes  520 out of 755
# partial succes  520 out of 755
# 755
# 756
# 757
# succes  521 out of 758
# partial succes  521 out of 758
# 758
# succes  522 out of 759
# partial succes  522 out of 759
# 759
# 760
# 761
# succes  523 out of 762
# partial succes  523 out of 762
# 762
# succes  524 out of 763
# partial succes  524 out of 763
# 763
# 764
# succes  525 out of 765
# partial succes  525 out of 765
# 765
# succes  526 out of 766
# partial succes  526 out of 766
# 766
# succes  527 out of 767
# partial succes  527 out of 767
# 767
# succes  528 out of 768
# partial succes  528 out of 768
# 768
# succes  529 out of 769
# partial succes  529 out of 769
# 769
# succes  530 out of 770
# partial succes  530 out of 770
# 770
# succes  531 out of 771
# partial succes  531 out of 771
# 771
# succes  532 out of 772
# partial succes  532 out of 772
# 772
# 773
# succes  533 out of 774
# partial succes  533 out of 774
# 774
# succes  534 out of 775
# partial succes  534 out of 775
# 775
# 776
# 777
# succes  535 out of 778
# partial succes  535 out of 778
# 778
# succes  536 out of 779
# partial succes  536 out of 779
# 779
# 780
# 781
# succes  537 out of 782
# partial succes  537 out of 782
# 782
# succes  538 out of 783
# partial succes  538 out of 783
# 783
# succes  539 out of 784
# partial succes  539 out of 784
# 784
# 785
# 786
# 787
# 788
# 789
# 790
# 791
# 792
# 793
# 794
# 795
# 796
# 797
# 798
# 799
# 800
# 801
# 802
# 803
# 804
# 805
# 806
# 807
# 808
# 809
# 810
# 811
# 812
# 813
# 814
# 815
# 816
# 817
# 818
# 819
# 820
# 821
# 822
# 823
# 824
# 825
# 826
# 827
# 828
# 829
# 830
# 831
# 832
# 833
# 834
# 835
# 836
# 837
# 838
# 839
# 840
# 841
# 842
# 843
# 844
# 845
# 846
# 847
# 848
# 849
# 850
# 851
# 852
# 853
# 854
# 855
# 856
# 857
# 858
# 859
# 860
# 861
# 862
# 863
# 864
# 865
# 866
# 867
# 868
# 869
# 870
# 871
# 872
# 873
# 874
# 875
# 876
# 877
# 878
# 879
# 880
# 881
# 882
# 883
# 884
# 885
# 886
# 887
# 888
# 889
# 890
# 891
# 892
# 893
# 894
# 895
# 896
# 897
# 898
# 899
# 900
# 901
# 902
# 903
# 904
# 905
# 906
# 907
# 908
# 909
# 910
# 911
# 912
# 913
# 914
# 915
# 916
# 917
# 918
# 919
# 920
# 921
# 922
# 923
# 924
# 925
# 926
# 927
# 928
# 929
# 930
# 931
# 932
# 933
# 934
# 935
# 936
# 937
# 938
# 939
# 940
# 941
# 942
# 943
# 944
# 945
# 946
# 947
# 948
# 949
# 950
# 951
# 952
# 953
# 954
# 955
# 956
# 957
# 958
# 959
# 960
# 961
# 962
# 963
# 964
# 965
# 966
# 967
# 968
# 969
# 970
# 971
# 972
# 973
# 974
# 975
# 976
# 977
# 978
# 979
# 980
# 981
# 982
# 983
# 984
# 985
# 986
# 987
# 988
# 989
# 990
# 991
# 992
# 993
# 994
# 995
# 996
# 997
# 998
# 999
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# 1086
# 1087
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1129
# 1130
# 1131
# 1132
# 1133
# 1134
# 1135
# 1136
# 1137
# 1138
# 1139
# 1140
# 1141
# 1142
# 1143
# 1144
# 1145
# 1146
# 1147
# 1148
# 1149
# 1150
# 1151
# 1152
# 1153
# 1154
# 1155
# 1156
# 1157
# 1158
# 1159
# 1160
# 1161
# 1162
# 1163
# 1164
# 1165
# 1166
# 1167
# 1168
# 1169
# 1170
# 1171
# 1172
# 1173
# 1174
# 1175
# 1176
# 1177
# 1178
# 1179
# 1180
# 1181
# 1182
# 1183
# 1184
# 1185
# 1186
# 1187
# 1188
# 1189
# 1190
# 1191
# 1192
# 1193
# 1194
# 1195
# 1196
# 1197
# 1198
# 1199
# 1200
# 1201
# 1202
# 1203
# 1204
# 1205
# 1206
# 1207
# 1208
# 1209
# 1210
# 1211
# 1212
# 1213
# 1214
# 1215
# 1216
# 1217
# 1218
# 1219
# 1220
# 1221
# 1222
# 1223
# 1224
# 1225
# 1226
# 1227
# 1228
# 1229
# 1230
# 1231
# 1232
# 1233
# 1234
# 1235
# 1236
# 1237
# 1238
# 1239
# 1240
# 1241
# 1242
# 1243
# 1244
# 1245
# 1246
# 1247
# 1248
# 1249
# 1250
# 1251
# 1252
# 1253
# 1254
# 1255
# 1256
# 1257
# 1258
# 1259
# 1260
# 1261
# 1262
# 1263
# 1264
# 1265
# 1266
# 1267
# 1268
# 1269
# 1270
# 1271
# 1272
# 1273
# 1274
# 1275
# 1276
# 1277
# 1278
# 1279
# 1280
# 1281
# 1282
# 1283
# 1284
# 1285
# 1286
# 1287
# 1288
# 1289
# 1290
# 1291
# 1292
# 1293
# 1294
# 1295
# 1296
# 1297
# 1298
# 1299
# 1300
# 1301
# 1302
# 1303
# 1304
# 1305
# 1306
# 1307
# 1308
# 1309
# 1310
# 1311
# 1312
# 1313
# 1314
# 1315
# 1316
# 1317
# 1318
# 1319
# 1320
# 1321
# 1322
# 1323
# 1324
# 1325
# 1326
# 1327
# 1328
# 1329
# 1330
# 1331
# 1332
# 1333
# 1334
# 1335
# 1336
# 1337
# 1338
# 1339
# 1340
# 1341
# 1342
# 1343
# 1344
# 1345
# 1346
# 1347
# 1348
# 1349
# 1350
# 1351
# 1352
# 1353
# 1354
# 1355
# 1356
# 1357
# 1358
# 1359
# 1360
# 1361
# 1362
# 1363
# 1364
# 1365
# 1366
# 1367
# 1368
# 1369
# 1370
# 1371
# 1372
# 1373
# 1374
# 1375
# 1376
# 1377
# 1378
# 1379
# 1380
# 1381
# 1382
# 1383
# 1384
# 1385
# 1386
# 1387
# 1388
# 1389
# 1390
# 1391
# 1392
# 1393
# 1394
# 1395
# 1396
# 1397
# 1398
# 1399
# 1400
# 1401
# 1402
# 1403
# 1404
# 1405
# 1406
# 1407
# 1408
# 1409
# 1410
# 1411
# 1412
# 1413
# 1414
# 1415
# 1416
# 1417
# 1418
# 1419
# 1420
# 1421
# 1422
# 1423
# 1424
# 1425
# 1426
# 1427
# 1428
# 1429
# 1430
# 1431
# 1432
# 1433
# 1434
# 1435
# 1436
# 1437
# 1438
# 1439
# 1440
# 1441
# 1442
# 1443
# 1444
# 1445
# 1446
# 1447
# 1448
# 1449
# 1450
# 1451
# 1452
# 1453
# 1454
# 1455
# 1456
# 1457
# 1458
# 1459
# 1460
# 1461
# 1462
# 1463
# 1464
# 1465
# 1466
# 1467
# 1468
# 1469
# 1470
# 1471
# 1472
# 1473
# 1474
# 1475
# 1476
# 1477
# 1478
# 1479
# 1480
# 1481
# 1482
# 1483
# 1484
# 1485
# 1486
# 1487
# 1488
# 1489
# 1490
# 1491
# 1492
# 1493
# 1494
# 1495
# 1496
# 1497
# 1498
# 1499
# 1500
# 1501
# 1502
# 1503
# 1504
# 1505
# 1506
# 1507
# 1508
# 1509
# 1510
# 1511
# 1512
# 1513
# 1514
# 1515
# 1516
# 1517
# 1518
# 1519
# 1520
# 1521
# 1522
# 1523
# 1524
# 1525
# 1526
# 1527
# 1528
# 1529
# 1530
# 1531
# 1532
# 1533
# 1534
# 1535
# 1536
# 1537
# 1538
# 1539
# 1540
# 1541
# 1542
# 1543
# 1544
# 1545
# 1546
# 1547
# 1548
# 1549
# 1550
# 1551
# 1552
# 1553
# 1554
# 1555
# 1556
# 1557
# 1558
# 1559
# 1560
# 1561
# 1562
# 1563
# 1564
# 1565
# 1566
# 1567
# 1568
# 1569
# 1570
# 1571
# 1572
# 1573
# 1574
# 1575
# 1576
# 1577
# 1578
# 1579
# 1580
# 1581
# 1582
# 1583
# 1584
# 1585
# 1586
# 1587
# 1588
# 1589
# 1590
# 1591
# 1592
# 1593
# 1594
# 1595
# 1596
# 1597
# 1598
# 1599
# 1600
# 1601
# 1602
# 1603
# 1604
# 1605
# 1606
# 1607
# 1608
# 1609
# 1610
# 1611
# 1612
# 1613
# 1614
# 1615
# 1616
# 1617
# 1618
# 1619
# 1620
# 1621
# 1622
# 1623
# 1624
# 1625
# 1626
# 1627
# 1628
# 1629
# 1630
# 1631
# 1632
# 1633
# 1634
# 1635
# 1636
# 1637
# 1638
# 1639
# 1640
# 1641
# 1642
# 1643
# 1644
# 1645
# 1646
# 1647
# 1648
# 1649
# 1650
# 1651
# 1652
# 1653
# 1654
# 1655
# 1656
# 1657
# 1658
# 1659
# 1660
# 1661
# 1662
# 1663
# 1664
# 1665
# 1666
# 1667
# 1668
# 1669
# 1670
# 1671
# 1672
# 1673
# 1674
# 1675
# 1676
# 1677
# 1678
# 1679
# 1680
# 1681
# 1682
# 1683
# 1684
# 1685
# 1686
# 1687
# 1688
# 1689
# 1690
# 1691
# 1692
# 1693
# 1694
# 1695
# 1696
# 1697
# 1698
# 1699
# 1700
# 1701
# 1702
# 1703
# 1704
# 1705
# 1706
# 1707
# 1708
# 1709
# 1710
# 1711
# 1712
# 1713
# 1714
# 1715
# 1716
# 1717
# 1718
# 1719
# 1720
# 1721
# 1722
# 1723
# 1724
# 1725
# 1726
# 1727
# 1728
# 1729
# 1730
# 1731
# 1732
# 1733
# 1734
# 1735
# 1736
# 1737
# 1738
# 1739
# 1740
# 1741
# 1742
# 1743
# 1744
# 1745
# 1746
# 1747
# 1748
# 1749
# 1750
# succes  540 out of 1751
# partial succes  540 out of 1751
# 1751
# 1752
# 1753
# 1754
# 1755
# 1756
# 1757
# succes  541 out of 1758
# partial succes  541 out of 1758
# 1758
# 1759
# 1760
# 1761
# 1762
# succes  542 out of 1763
# partial succes  542 out of 1763
# 1763
# 1764
# 1765
# 1766
# 1767
# 1768
# 1769
# 1770
# 1771
# 1772
# 1773
# 1774
# 1775
# 1776
# 1777
# 1778
# succes  543 out of 1779
# partial succes  543 out of 1779
# 1779
# 1780
# 1781
# 1782
# 1783
# 1784
# succes  544 out of 1785
# partial succes  544 out of 1785
# 1785
# 1786
# 1787
# 1788
# succes  545 out of 1789
# partial succes  545 out of 1789
# 1789
# 1790
# 1791
# 1792
# 1793
# 1794
# 1795
# 1796
# 1797
# 1798
# 1799
# 1800
# 1801
# 1802
# 1803
# 1804
# 1805
# 1806
# 1807
# 1808
# 1809
# 1810
# 1811
# 1812
# 1813
# 1814
# succes  546 out of 1815
# partial succes  546 out of 1815
# 1815
# 1816
# 1817
# 1818
# 1819
# 1820
# 1821
# 1822
# 1823
# 1824
# 1825
# 1826
# succes  547 out of 1827
# partial succes  547 out of 1827
# 1827
# 1828
# 1829
# 1830
# 1831
# succes  548 out of 1832
# partial succes  548 out of 1832
# 1832
# 1833
# 1834
# 1835
# 1836
# 1837
# 1838
# 1839
# 1840
# 1841
# 1842
# 1843
# 1844
# 1845
# 1846
# 1847
# 1848
# 1849
# 1850
# 1851
# 1852
# succes  549 out of 1853
# partial succes  549 out of 1853
# 1853
# 1854
# 1855
# succes  550 out of 1856
# partial succes  550 out of 1856
# 1856
# 1857
# 1858
# 1859
# 1860
# 1861
# 1862
# 1863
# 1864
# 1865
# 1866
# 1867
# succes  551 out of 1868
# partial succes  551 out of 1868
# 1868
# 1869
# 1870
# 1871
# 1872
# 1873
# 1874
# 1875
# 1876
# 1877
# 1878
# 1879
# 1880
# 1881
# 1882
# 1883
# 1884
# 1885
# 1886
# 1887
# 1888
# 1889
# 1890
# 1891
# succes  552 out of 1892
# partial succes  552 out of 1892
# 1892
# 1893
# 1894
# 1895
# 1896
# 1897
# 1898
# 1899
# 1900
# 1901
# 1902
# 1903
# 1904
# 1905
# 1906
# 1907
# 1908
# 1909
# 1910
# 1911
# 1912
# 1913
# 1914
# 1915
# 1916
# 1917
# 1918
# 1919
# 1920
# 1921
# 1922
# 1923
# 1924
# 1925
# 1926
# 1927
# 1928
# 1929
# 1930
# 1931
# 1932
# 1933
# 1934
# succes  553 out of 1935
# partial succes  553 out of 1935
# 1935
# 1936
# 1937
# 1938
# succes  554 out of 1939
# partial succes  554 out of 1939
# 1939
# 1940
# 1941
# 1942
# 1943
# 1944
# 1945
# 1946
# 1947
# succes  555 out of 1948
# partial succes  555 out of 1948
# 1948
# 1949
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# succes  556 out of 1959
# partial succes  556 out of 1959
# 1959
# 1960
# 1961
# 1962
# 1963
# succes  557 out of 1964
# partial succes  557 out of 1964
# 1964
# 1965
# 1966
# succes  558 out of 1967
# partial succes  558 out of 1967
# 1967
# 1968
# 1969
# succes  559 out of 1970
# partial succes  559 out of 1970
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# succes  560 out of 1979
# partial succes  560 out of 1979
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# succes  561 out of 1985
# partial succes  561 out of 1985
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# succes  562 out of 2023
# partial succes  562 out of 2023
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# succes  563 out of 2038
# partial succes  563 out of 2038
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# 2051
# 2052
# 2053
# 2054
# 2055
# 2056
# 2057
# 2058
# 2059
# 2060
# 2061
# 2062
# 2063
# succes  564 out of 2064
# partial succes  564 out of 2064
# 2064
# 2065
# 2066
# 2067
# 2068
# 2069
# 2070
# succes  565 out of 2071
# partial succes  565 out of 2071
# 2071
# 2072
# 2073
# 2074
# 2075
# 2076
# 2077
# 2078
# 2079
# 2080
# 2081
# 2082
# 2083
# 2084
# 2085
# 2086
# 2087
# 2088
# 2089
# 2090
# 2091
# 2092
# 2093
# 2094
# 2095
# 2096
# 2097
# succes  566 out of 2098
# partial succes  566 out of 2098
# 2098
# 2099
# succes  567 out of 2100
# partial succes  567 out of 2100
# 2100
# 2101
# 2102
# 2103
# 2104
# 2105
# succes  568 out of 2106
# partial succes  568 out of 2106
# 2106
# 2107
# 2108
# 2109
# 2110
# 2111
# 2112
# 2113
# 2114
# 2115
# 2116
# succes  569 out of 2117
# partial succes  569 out of 2117
# 2117
# 2118
# 2119
# 2120
# 2121
# 2122
# 2123
# 2124
# 2125
# 2126
# 2127
# 2128
# 2129
# 2130
# 2131
# 2132
# 2133
# 2134
# 2135
# 2136
# 2137
# 2138
# 2139
# 2140
# 2141
# 2142
# 2143
# 2144
# 2145
# 2146
# 2147
# 2148
# 2149
# 2150
# 2151
# 2152
# 2153
# succes  570 out of 2154
# partial succes  570 out of 2154
# 2154
# 2155
# 2156
# 2157
# 2158
# 2159
# 2160
# 2161
# 2162
# 2163
# 2164
# 2165
# 2166
# 2167
# 2168
# 2169
# 2170
# 2171
# 2172
# 2173
# 2174
# 2175
# 2176
# 2177
# 2178
# 2179
# 2180
# 2181
# 2182
# 2183
# succes  571 out of 2184
# partial succes  571 out of 2184
# 2184
# 2185
# 2186
# 2187
# 2188
# 2189
# 2190
# 2191
# 2192
# 2193
# 2194
# 2195
# 2196
# 2197
# 2198
# 2199
# 2200
# 2201
# 2202
# 2203
# 2204
# 2205
# 2206
# 2207
# 2208
# 2209
# 2210
# 2211
# 2212
# 2213
# 2214
# 2215
# 2216
# 2217
# 2218
# 2219
# 2220
# 2221
# 2222
# 2223
# 2224
# 2225
# 2226
# 2227
# 2228
# 2229
# 2230
# 2231
# 2232
# 2233
# 2234
# 2235
# 2236
# 2237
# 2238
# 2239
# 2240
# 2241
# 2242
# 2243
# 2244
# 2245
# 2246
# 2247
# 2248
# 2249
# 2250
# 2251
# 2252
# 2253
# 2254
# 2255
# 2256
# 2257
# 2258
# 2259
# 2260
# 2261
# 2262
# 2263
# 2264
# 2265
# 2266
# 2267
# 2268
# 2269
# 2270
# 2271
# 2272
# 2273
# 2274
# 2275
# 2276
# 2277
# 2278
# 2279
# 2280
# 2281
# 2282
# 2283
# 2284
# 2285
# 2286
# 2287
# 2288
# 2289
# 2290
# 2291
# 2292
# 2293
# 2294
# 2295
# 2296
# 2297
# 2298
# 2299
# 2300
# 2301
# 2302
# 2303
# 2304
# 2305
# 2306
# 2307
# 2308
# 2309
# 2310
# 2311
# 2312
# 2313
# 2314
# 2315
# 2316
# 2317
# 2318
# 2319
# 2320
# 2321
# 2322
# 2323
# 2324
# 2325
# 2326
# 2327
# 2328
# 2329
# 2330
# 2331
# 2332
# 2333
# 2334
# 2335
# 2336
# 2337
# 2338
# 2339
# 2340
# 2341
# 2342
# 2343
# 2344
# 2345
# 2346
# 2347
# 2348
# 2349
# 2350
# 2351
# 2352
# 2353
# 2354
# 2355
# 2356
# 2357
# 2358
# 2359
# 2360
# 2361
# 2362
# 2363
# 2364
# 2365
# 2366
# 2367
# 2368
# 2369
# 2370
# 2371
# 2372
# 2373
# 2374
# 2375
# 2376
# 2377
# 2378
# 2379
# 2380
# 2381
# 2382
# 2383
# 2384
# 2385
# 2386
# 2387
# 2388
# 2389
# 2390
# 2391
# 2392
# 2393
# 2394
# 2395
# 2396
# 2397
# 2398
# 2399
# 2400
# 2401
# 2402
# 2403
# 2404
# 2405
# 2406
# 2407
# 2408
# 2409
# 2410
# 2411
# 2412
# 2413
# 2414
# 2415
# 2416
# 2417
# 2418
# 2419
# 2420
# 2421
# 2422
# 2423
# 2424
# 2425
# 2426
# 2427
# 2428
# 2429
# 2430
# 2431
# 2432
# 2433
# 2434
# 2435
# 2436
# 2437
# 2438
# 2439
# 2440
# 2441
# 2442
# 2443
# 2444
# 2445
# 2446
# 2447
# 2448
# 2449
# 2450
# 2451
# 2452
# 2453
# 2454
# 2455
# 2456
# 2457
# 2458
# 2459
# 2460
# 2461
# 2462
# 2463
# 2464
# 2465
# 2466
# 2467
# 2468
# 2469
# 2470
# 2471
# 2472
# 2473
# 2474
# 2475
# 2476
# 2477
# 2478
# 2479
# 2480
# 2481
# 2482
# 2483
# 2484
# 2485
# 2486
# 2487
# 2488
# 2489
# 2490
# 2491
# 2492
# 2493
# 2494
# 2495
# 2496
# 2497
# 2498
# 2499
# 2500
# 2501
# 2502
# 2503
# 2504
# 2505
# 2506
# 2507
# 2508
# 2509
# 2510
# 2511
# 2512
# 2513
# 2514
# 2515
# 2516
# 2517
# 2518
# 2519
# 2520
# 2521
# 2522
# 2523
# 2524
# 2525
# 2526
# 2527
# 2528
# 2529
# 2530
# 2531
# 2532
# 2533
# 2534
# 2535
# 2536
# 2537
# 2538
# 2539
# 2540
# 2541
# 2542
# 2543
# 2544
# 2545
# 2546
# 2547
# 2548
# 2549
# 2550
# 2551
# 2552
# 2553
# 2554
# 2555
# 2556
# 2557
# 2558
# 2559
# 2560
# 2561
# 2562
# 2563
# 2564
# 2565
# 2566
# 2567
# 2568
# 2569
# 2570
# 2571
# 2572
# 2573
# 2574
# 2575
# 2576
# 2577
# 2578
# 2579
# 2580
# 2581
# 2582
# 2583
# 2584
# 2585
# 2586
# 2587
# 2588
# 2589
# 2590
# 2591
# 2592
# 2593
# 2594
# 2595
# 2596
# 2597
# 2598
# 2599
# 2600
# 2601
# 2602
# 2603
# 2604
# 2605
# 2606
# 2607
# 2608
# 2609
# 2610
# 2611
# 2612
# 2613
# 2614
# 2615
# 2616
# 2617
# 2618
# 2619
# 2620
# 2621
# 2622
# 2623
# 2624
# 2625
# 2626
# 2627
# 2628
# 2629
# 2630
# 2631
# 2632
# 2633
# 2634
# 2635
# 2636
# 2637
# 2638
# 2639
# 2640
# 2641
# 2642
# 2643
# 2644
# 2645
# 2646
# 2647
# 2648
# 2649
# 2650
# 2651
# 2652
# 2653
# 2654
# 2655
# 2656
# 2657
# 2658
# 2659
# 2660
# 2661
# 2662
# 2663
# 2664
# 2665
# 2666
# 2667
# 2668
# 2669
# 2670
# 2671
# 2672
# 2673
# 2674
# 2675
# 2676
# 2677
# 2678
# 2679
# 2680
# 2681
# 2682
# 2683
# 2684
# 2685
# 2686
# 2687
# 2688
# 2689
# 2690
# 2691
# 2692
# 2693
# 2694
# 2695
# 2696
# 2697
# 2698
# 2699
# 2700
# 2701
# 2702
# 2703
# 2704
# 2705
# 2706
# 2707
# 2708
# 2709
# 2710
# 2711
# 2712
# 2713
# 2714
# 2715
# 2716
# 2717
# 2718
# 2719
# 2720
# 2721
# 2722
# 2723
# 2724
# 2725
# 2726
# 2727
# 2728
# 2729
# 2730
# 2731
# 2732
# 2733
# 2734
# 2735
# 2736
# 2737
# 2738
# 2739
# 2740
# 2741
# 2742
# 2743
# 2744
# 2745
# 2746
# 2747
# 2748
# 2749
# 2750
# 2751
# 2752
# 2753
# 2754
# 2755
# 2756
# 2757
# 2758
# 2759
# 2760
# 2761
# 2762
# 2763
# 2764
# 2765
# 2766
# 2767
# 2768
# 2769
# 2770
# 2771
# 2772
# 2773
# 2774
# 2775
# 2776
# 2777
# 2778
# 2779
# 2780
# 2781
# 2782
# 2783
# 2784
# 2785
# 2786
# 2787
# 2788
# 2789
# succes  572 out of 2790
# partial succes  572 out of 2790
# 2790
# 2791
# 2792
# 2793
# succes  573 out of 2794
# partial succes  573 out of 2794
# 2794
# 2795
# 2796
# 2797
# 2798
# 2799
# 2800
# succes  574 out of 2801
# partial succes  574 out of 2801
# 2801
# 2802
# 2803
# 2804
# 2805
# 2806
# 2807
# 2808
# 2809
# 2810
# 2811
# 2812
# 2813
# 2814
# 2815
# 2816
# 2817
# 2818
# 2819
# 2820
# 2821
# 2822
# 2823
# 2824
# 2825
# 2826
# 2827
# 2828
# 2829
# 2830
# 2831
# 2832
# 2833
# 2834
# 2835
# 2836
# 2837
# 2838
# 2839
# 2840
# 2841
# 2842
# 2843
# 2844
# 2845
# 2846
# 2847
# 2848
# 2849
# 2850
# 2851
# 2852
# 2853
# 2854
# 2855
# succes  575 out of 2856
# partial succes  575 out of 2856
# 2856
# 2857
# 2858
# 2859
# 2860
# 2861
# 2862
# 2863
# 2864
# 2865
# 2866
# 2867
# 2868
# 2869
# 2870
# 2871
# 2872
# 2873
# 2874
# 2875
# 2876
# 2877
# 2878
# 2879
# 2880
# 2881
# 2882
# 2883
# 2884
# 2885
# 2886
# 2887
# 2888
# 2889
# 2890
# 2891
# 2892
# 2893
# 2894
# 2895
# 2896
# 2897
# 2898
# 2899
# 2900
# 2901
# 2902
# 2903
# 2904
# 2905
# 2906
# 2907
# 2908
# 2909
# 2910
# 2911
# 2912
# 2913
# 2914
# 2915
# 2916
# 2917
# 2918
# 2919
# 2920
# 2921
# 2922
# 2923
# 2924
# 2925
# succes  576 out of 2926
# partial succes  576 out of 2926
# 2926
# 2927
# 2928
# 2929
# 2930
# 2931
# 2932
# 2933
# 2934
# 2935
# 2936
# 2937
# 2938
# 2939
# 2940
# 2941
# 2942
# 2943
# 2944
# 2945
# 2946
# 2947
# 2948
# 2949
# 2950
# 2951
# 2952
# 2953
# 2954
# 2955
# 2956
# 2957
# 2958
# 2959
# 2960
# 2961
# 2962
# succes  577 out of 2963
# partial succes  577 out of 2963
# 2963
# 2964
# 2965
# 2966
# 2967
# 2968
# 2969
# 2970
# 2971
# 2972
# 2973
# 2974
# 2975
# 2976
# 2977
# 2978
# 2979
# 2980
# 2981
# 2982
# 2983
# 2984
# 2985
# 2986
# 2987
# 2988
# 2989
# 2990
# 2991
# 2992
# 2993
# 2994
# 2995
# 2996
# 2997
# 2998
# 2999
# 3000
# 3001
# 3002
# 3003
# 3004
# 3005
# 3006
# 3007
# 3008
# 3009
# 3010
# 3011
# 3012
# 3013
# 3014
# 3015
# 3016
# 3017
# 3018
# 3019
# 3020
# 3021
# 3022
# 3023
# 3024
# 3025
# 3026
# 3027
# 3028
# 3029
# 3030
# 3031
# 3032
# 3033
# 3034
# 3035
# 3036
# 3037
# 3038
# 3039
# 3040
# 3041
# 3042
# 3043
# 3044
# 3045
# 3046
# 3047
# 3048
# 3049
# 3050
# 3051
# 3052
# 3053
# 3054
# 3055
# 3056
# 3057
# 3058
# succes  578 out of 3059
# partial succes  578 out of 3059
# 3059
# 3060
# 3061
# 3062
# 3063
# 3064
# 3065
# 3066
# 3067
# 3068
# 3069
# 3070
# 3071
# 3072
# 3073
# 3074
# 3075
# 3076
# 3077
# 3078
# 3079
# 3080
# 3081
# 3082
# 3083
# 3084
# 3085
# 3086
# succes  579 out of 3087
# partial succes  579 out of 3087
# 3087
# 3088
# 3089
# 3090
# 3091
# 3092
# 3093
# 3094
# 3095
# 3096
# 3097
# 3098
# 3099
# 3100
# 3101
# 3102
# 3103
# 3104
# 3105
# 3106
# 3107
# 3108
# 3109
# 3110
# 3111
# 3112
# 3113
# 3114
# 3115
# 3116
# 3117
# 3118
# 3119
# 3120
# 3121
# 3122
# 3123
# 3124
# 3125
# 3126
# 3127
# 3128
# 3129
# 3130
# 3131
# 3132
# 3133
# 3134
# 3135
# 3136
# 3137
# 3138
# 3139
# 3140
# 3141
# 3142
# 3143
# 3144
# 3145
# 3146
# 3147
# 3148
# 3149
# 3150
# 3151
# 3152
# 3153
# 3154
# 3155
# 3156
# 3157
# 3158
# 3159
# 3160
# 3161
# 3162
# 3163
# 3164
# 3165
# 3166
# 3167
# 3168
# 3169
# 3170
# 3171
# 3172
# 3173
# 3174
# 3175
# 3176
# 3177
# 3178
# 3179
# 3180
# 3181
# 3182
# 3183
# 3184
# 3185
# 3186
# 3187
# 3188
# 3189
# 3190
# 3191
# 3192
# 3193
# 3194
# 3195
# 3196
# 3197
# 3198
# 3199
# 3200
# 3201
# 3202
# 3203
# 3204
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# 3211
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3218
# 3219
# 3220
# 3221
# 3222
# 3223
# 3224
# 3225
# 3226
# 3227
# 3228
# 3229
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3236
# 3237
# 3238
# 3239
# 3240
# 3241
# 3242
# 3243
# 3244
# 3245
# 3246
# 3247
# 3248
# 3249
# 3250
# 3251
# 3252
# 3253
# 3254
# 3255
# 3256
# 3257
# 3258
# 3259
# 3260
# 3261
# 3262
# 3263
# 3264
# 3265
# 3266
# 3267
# 3268
# 3269
# 3270
# 3271
# 3272
# 3273
# 3274
# 3275
# 3276
# 3277
# 3278
# 3279
# 3280
# 3281
# 3282
# 3283
# 3284
# 3285
# 3286
# 3287
# 3288
# 3289
# 3290
# 3291
# 3292
# 3293
# 3294
# 3295
# 3296
# 3297
# 3298
# 3299
# 3300
# 3301
# 3302
# 3303
# 3304
# 3305
# 3306
# 3307
# 3308
# 3309
# 3310
# 3311
# 3312
# 3313
# 3314
# 3315
# 3316
# 3317
# 3318
# 3319
# 3320
# 3321
# 3322
# 3323
# 3324
# 3325
# 3326
# 3327
# 3328
# 3329
# 3330
# 3331
# 3332
# 3333
# 3334
# 3335
# 3336
# 3337
# 3338
# 3339
# 3340
# 3341
# 3342
# 3343
# 3344
# 3345
# 3346
# 3347
# 3348
# 3349
# 3350
# 3351
# 3352
# 3353
# 3354
# 3355
# 3356
# 3357
# 3358
# 3359
# 3360
# 3361
# 3362
# 3363
# 3364
# 3365
# 3366
# 3367
# 3368
# 3369
# 3370
# 3371
# 3372
# 3373
# 3374
# 3375
# 3376
# 3377
# 3378
# 3379
# 3380
# 3381
# 3382
# 3383
# 3384
# 3385
# 3386
# 3387
# 3388
# 3389
# 3390
# 3391
# 3392
# 3393
# 3394
# 3395
# 3396
# 3397
# 3398
# 3399
# 3400
# 3401
# 3402
# 3403
# 3404
# 3405
# 3406
# 3407
# 3408
# 3409
# 3410
# 3411
# 3412
# 3413
# 3414
# 3415
# 3416
# 3417
# 3418
# 3419
# 3420
# 3421
# 3422
# 3423
# 3424
# 3425
# 3426
# 3427
# 3428
# 3429
# 3430
# 3431
# 3432
# 3433
# 3434
# 3435
# 3436
# 3437
# 3438
# 3439
# 3440
# 3441
# 3442
# 3443
# 3444
# 3445
# 3446
# 3447
# 3448
# 3449
# 3450
# 3451
# 3452
# 3453
# 3454
# 3455
# 3456
# 3457
# 3458
# 3459
# 3460
# 3461
# 3462
# 3463
# 3464
# 3465
# 3466
# 3467
# 3468
# 3469
# 3470
# 3471
# 3472
# 3473
# 3474
# 3475
# 3476
# 3477
# 3478
# 3479
# 3480
# 3481
# 3482
# 3483
# 3484
# 3485
# 3486
# 3487
# 3488
# 3489
# 3490
# 3491
# 3492
# 3493
# 3494
# 3495
# 3496
# 3497
# 3498
# 3499
# 3500
# 3501
# 3502
# 3503
# 3504
# 3505
# 3506
# 3507
# 3508
# 3509
# 3510
# 3511
# 3512
# 3513
# 3514
# 3515
# 3516
# 3517
# 3518
# 3519
# 3520
# 3521
# 3522
# 3523
# 3524
# 3525
# 3526
# 3527
# 3528
# 3529
# 3530
# 3531
# 3532
# 3533
# 3534
# 3535
# 3536
# 3537
# 3538
# 3539
# 3540
# 3541
# 3542
# 3543
# 3544
# 3545
# 3546
# 3547
# 3548
# 3549
# 3550
# 3551
# 3552
# 3553
# 3554
# 3555
# 3556
# 3557
# 3558
# 3559
# 3560
# 3561
# 3562
# 3563
# 3564
# 3565
# 3566
# 3567
# 3568
# 3569
# 3570
# 3571
# 3572
# 3573
# 3574
# 3575
# 3576
# 3577
# 3578
# 3579
# 3580
# 3581
# 3582
# 3583
# 3584
# 3585
# 3586
# 3587
# 3588
# 3589
# 3590
# 3591
# 3592
# 3593
# 3594
# 3595
# 3596
# 3597
# 3598
# 3599
# 3600
# 3601
# 3602
# 3603
# 3604
# 3605
# 3606
# 3607
# 3608
# 3609
# 3610
# 3611
# 3612
# 3613
# 3614
# 3615
# 3616
# 3617
# 3618
# 3619
# 3620
# 3621
# 3622
# 3623
# 3624
# 3625
# 3626
# 3627
# 3628
# 3629
# 3630
# 3631
# 3632
# 3633
# 3634
# 3635
# 3636
# 3637
# 3638
# 3639
# 3640
# 3641
# 3642
# 3643
# 3644
# 3645
# 3646
# 3647
# 3648
# 3649
# 3650
# 3651
# 3652
# 3653
# 3654
# 3655
# 3656
# 3657
# 3658
# 3659
# 3660
# 3661
# 3662
# 3663
# 3664
# 3665
# 3666
# 3667
# 3668
# 3669
# 3670
# 3671
# 3672
# 3673
# 3674
# 3675
# 3676
# 3677
# 3678
# 3679
# 3680
# 3681
# 3682
# 3683
# 3684
# 3685
# 3686
# 3687
# 3688
# 3689
# 3690
# 3691
# 3692
# 3693
# 3694
# 3695
# 3696
# 3697
# 3698
# 3699
# 3700
# 3701
# 3702
# 3703
# 3704
# 3705
# 3706
# 3707
# 3708
# 3709
# 3710
# 3711
# 3712
# 3713
# 3714
# 3715
# 3716
# 3717
# 3718
# 3719
# 3720
# 3721
# 3722
# 3723
# 3724
# 3725
# 3726
# 3727
# 3728
# 3729
# 3730
# 3731
# 3732
# 3733
# 3734
# 3735
# 3736
# 3737
# 3738
# 3739
# 3740
# 3741
# 3742
# 3743
# 3744
# 3745
# 3746
# 3747
# 3748
# 3749
# 3750
# 3751
# 3752
# 3753
# 3754
# 3755
# 3756
# 3757
# 3758
# 3759
# 3760
# 3761
# 3762
# 3763
# 3764
# 3765
# 3766
# 3767
# 3768
# 3769
# 3770
# 3771
# 3772
# 3773
# 3774
# 3775
# 3776
# 3777
# 3778
# 3779
# 3780
# 3781
# 3782
# 3783
# 3784
# 3785
# 3786
# 3787
# 3788
# 3789
# 3790
# 3791
# 3792
# 3793
# 3794
# 3795
# 3796
# 3797
# 3798
# 3799
# 3800
# 3801
# 3802
# 3803
# 3804
# 3805
# 3806
# 3807
# 3808
# 3809
# 3810
# 3811
# 3812
# 3813
# 3814
# 3815
# 3816
# 3817
# 3818
# 3819
# 3820
# 3821
# 3822
# 3823
# 3824
# 3825
# 3826
# 3827
# 3828
# 3829
# 3830
# 3831
# 3832
# 3833
# 3834
# 3835
# 3836
# 3837
# 3838
# 3839
# 3840
# 3841
# 3842
# 3843
# 3844
# 3845
# 3846
# 3847
# 3848
# 3849
# 3850
# 3851
# 3852
# 3853
# 3854
# 3855
# 3856
# 3857
# 3858
# 3859
# 3860
# 3861
# 3862
# 3863
# 3864
# 3865
# 3866
# 3867
# 3868
# 3869
# 3870
# 3871
# 3872
# 3873
# 3874
# 3875
# 3876
# 3877
# 3878
# 3879
# 3880
# 3881
# 3882
# 3883
# 3884
# 3885
# 3886
# 3887
# 3888
# 3889
# 3890
# 3891
# 3892
# 3893
# 3894
# 3895
# 3896
# 3897
# 3898
# 3899
# 3900
# 3901
# 3902
# 3903
# 3904
# 3905
# 3906
# 3907
# 3908
# 3909
# 3910
# 3911
# 3912
# 3913
# 3914
# 3915
# 3916
# 3917
# 3918
# 3919
# Exact match accuracy: 14.77%
# Partial match accuracy: 14.77%

# %% [markdown]
# # Experiment 3

# %%
# URLs of the files you want to download
file_urls = [
    'https://raw.githubusercontent.com/brendenlake/SCAN/master/add_prim_split/tasks_train_addprim_jump.txt',
    'https://raw.githubusercontent.com/brendenlake/SCAN/master/add_prim_split/tasks_test_addprim_jump.txt'  # Replace with the actual URL of the second file
]

# Use ThreadPoolExecutor to download files concurrently
with ThreadPoolExecutor(max_workers=len(file_urls)) as executor:
    results = list(executor.map(download_file, file_urls))

# Check if all downloads were successful
if all(result is not None for result in results):
    # Assuming each line in the text file is a sentence
    sentences_list = [result.split('\n') for result in results]

    # Create DataFrames for each file
    dfs = [pd.DataFrame({'Sentences': sentences}) for sentences in sentences_list]

    # Create DataFrames for each file
    train_df_jump = pd.DataFrame({'Sentences': sentences_list[0]})
    eval_df_jump = pd.DataFrame({'Sentences': sentences_list[1]})
else:
    print("One or more downloads failed.")

# %% [markdown]
# rewrite vocabulary to include "JUMP"

# %%
train_set_jump = SentenceDataset(train_df_jump['Sentences'])
eval_set_jump = SentenceDataset(eval_df_jump['Sentences'])

# %%
for i in range(len(train_set_jump)-1):
  if "jump" in train_set_jump[i][0]:
    print(train_set_jump[i])

# %%
input_vocab = Vocab('IN')
output_vocab = Vocab('OUT')
for line in train_set_jump:
    input_vocab.addSentence(line[0])
    output_vocab.addSentence(line[1])

# %% [markdown]
# train and evaluate

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set_jump, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)

train(train_dataloader, encoder, decoder, 100000, print_every=100, plot_every=500)

# %%
eval = [eval_set_jump[i] for i in range(len(eval_set_jump)-1)]
encoder.eval()
decoder.eval()
result = evaluate(encoder, decoder, eval, input_vocab, output_vocab)

# %% [markdown]
# now the with "TURN LEFT"

# %%
# URLs of the files you want to download
file_urls = [
    'https://raw.githubusercontent.com/brendenlake/SCAN/master/add_prim_split/tasks_train_addprim_turn_left.txt',
    'https://raw.githubusercontent.com/brendenlake/SCAN/master/add_prim_split/tasks_test_addprim_turn_left.txt'  # Replace with the actual URL of the second file
]

# Use ThreadPoolExecutor to download files concurrently
with ThreadPoolExecutor(max_workers=len(file_urls)) as executor:
    results = list(executor.map(download_file, file_urls))

# Check if all downloads were successful
if all(result is not None for result in results):
    # Assuming each line in the text file is a sentence
    sentences_list = [result.split('\n') for result in results]

    # Create DataFrames for each file
    dfs = [pd.DataFrame({'Sentences': sentences}) for sentences in sentences_list]

    # Create DataFrames for each file
    train_df_tleft = pd.DataFrame({'Sentences': sentences_list[0]})
    eval_df_tleft = pd.DataFrame({'Sentences': sentences_list[1]})
else:
    print("One or more downloads failed.")

# %% [markdown]
# rewrite vocabulary to include "JUMP"

# %%
train_set_tleft = SentenceDataset(train_df_tleft['Sentences'])
eval_set_tleft = SentenceDataset(eval_df_tleft['Sentences'])

# %%
input_vocab = Vocab('IN')
output_vocab = Vocab('OUT')
for line in train_set_tleft:
    input_vocab.addSentence(line[0])
    output_vocab.addSentence(line[1])

# %% [markdown]
# train and evaluate

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set_tleft, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)

train(train_dataloader, encoder, decoder, 100000, print_every=100, plot_every=500)

# %%
eval = [eval_set_tleft[i] for i in range(len(eval_set_tleft)-1)]
encoder.eval()
decoder.eval()
result = evaluate(encoder, decoder, eval, input_vocab, output_vocab)

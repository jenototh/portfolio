# %% [markdown]
# #Select an Architecture

# %%
architecture = "best" # choose this for the overall best architecture
# architecture = "task" # choose this for the task specific best architecture

# %% [markdown]
# # Dataset: Simple Split

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.utils as torch_utils
import numpy as np

import random
import math
import time

# %%
import pandas as pd
import numpy as np
import requests
from io import StringIO
from concurrent.futures import ThreadPoolExecutor

def download_file(file_url):
    response = requests.get(file_url)
    if response.status_code == 200:
        return response.text
    else:
        print(f"Failed to fetch the file. Status code: {response.status_code}")
        return None

# URLs of the files you want to download
file_urls = [
    'https://raw.githubusercontent.com/brendenlake/SCAN/master/simple_split/tasks_train_simple.txt',
    'https://raw.githubusercontent.com/brendenlake/SCAN/master/simple_split/tasks_test_simple.txt'  # Replace with the actual URL of the second file
]

# Use ThreadPoolExecutor to download files concurrently
with ThreadPoolExecutor(max_workers=len(file_urls)) as executor:
    results = list(executor.map(download_file, file_urls))

# Check if all downloads were successful
if all(result is not None for result in results):
    # Assuming each line in the text file is a sentence
    sentences_list = [result.split('\n') for result in results]

    # Create DataFrames for each file
    dfs = [pd.DataFrame({'Sentences': sentences}) for sentences in sentences_list]

    # Create DataFrames for each file
    train_df = pd.DataFrame({'Sentences': sentences_list[0]})
    eval_df = pd.DataFrame({'Sentences': sentences_list[1]})
else:
    print("One or more downloads failed.")

# %%
print(train_df.head())
# Out:
#                                            Sentences
# 0  IN: jump opposite right twice and turn opposit...
# 1  IN: run opposite left after walk right OUT: I_...
# 2  IN: walk after run around right twice OUT: I_T...
# 3  IN: look around right thrice and turn left OUT...
# 4  IN: walk opposite left twice and walk opposite...

# %%
SEED = 4389

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from torch.utils.data import Dataset

class SentenceDataset(Dataset):
   def __init__(self, sentences):
       self.sentences = sentences

   def __len__(self):
       return len(self.sentences)

   def __getitem__(self, idx):
       sentence = self.sentences[idx]
       in_sentence = sentence.split('IN:')[1].split('OUT:')[0].strip()
       out_sentence = sentence.split('OUT:')[1].strip()
       return [in_sentence, out_sentence]

# %%
train_set = SentenceDataset(train_df['Sentences'])
eval_set = SentenceDataset(eval_df['Sentences'])

# %%
PAD_token = 0
SOS_token = 1
EOS_token = 2

class Vocab:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "PAD", 1: "SOS", 2: "EOS"}
        self.n_words = 3  # Count PAD SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
def indexesFromSentence(vocab, sentence):
    return [vocab.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(1, -1)

# %%
input_vocab = Vocab('IN')
output_vocab = Vocab('OUT')
for line in train_set:
    input_vocab.addSentence(line[0])
    output_vocab.addSentence(line[1])

# %%
print(input_vocab.word2index)
print(input_vocab.index2word)
# Out:
# {'jump': 3, 'opposite': 4, 'right': 5, 'twice': 6, 'and': 7, 'turn': 8, 'thrice': 9, 'run': 10, 'left': 11, 'after': 12, 'walk': 13, 'around': 14, 'look': 15}
# {0: 'PAD', 1: 'SOS', 2: 'EOS', 3: 'jump', 4: 'opposite', 5: 'right', 6: 'twice', 7: 'and', 8: 'turn', 9: 'thrice', 10: 'run', 11: 'left', 12: 'after', 13: 'walk', 14: 'around', 15: 'look'}

# %% [markdown]
# # DATALOADER

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class CustomDataset(Dataset):
    def __init__(self, dataset, in_voacab, out_vocab):
        self.dataset = dataset
        self.in_vocab = in_voacab
        self.out_vocab = out_vocab
        input_sentences = []
        target_sentences = []
        for line in self.dataset:
            input_sentences.append(line[0])
            target_sentences.append(line[1])
        self.input_sentences = input_sentences
        self.target_sentences = target_sentences


    def __len__(self):
        return len(self.input_sentences)

    def __getitem__(self, idx):
        input_sentence = self.input_sentences[idx]
        target_sentence = self.target_sentences[idx]

        # Convert words to indices using word2index dictionary
        input_indices = indexesFromSentence(self.in_vocab, input_sentence)
        input_indices.append(EOS_token)
        target_indices = indexesFromSentence(self.out_vocab, target_sentence)
        target_indices.append(EOS_token)

        return torch.LongTensor(input_indices).to(device), torch.LongTensor(target_indices).to(device)

# %% [markdown]
# # LSTM encoder decoder

# %%
import torch.nn as nn


class EncoderLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_p=0.0):
        super(EncoderLSTM, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.LSTM = nn.LSTM(hidden_size, hidden_size, num_layers=2, batch_first=True)
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, input):
        embedded = self.dropout(self.embedding(input))

        output, hidden = self.LSTM(embedded)
        return output, hidden

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch

class DecoderLSTM(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderLSTM, self).__init__()
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.LSTM = nn.LSTM(hidden_size, hidden_size, num_layers=2, batch_first=True)
        self.out = nn.Linear(hidden_size, output_size)

    def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
        batch_size = encoder_outputs.size(0)
        decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
        #print("decoder input", decoder_input)
        decoder_hidden = encoder_hidden
        decoder_outputs = []
        if target_tensor is not None:
            target_len = target_tensor.size(1)
        else:
            target_len = 48
        #print("target len:", trg_len)
        #print("decoder hidden", decoder_hidden)

        for i in range(target_len):
            decoder_output, decoder_hidden  = self.forward_step(decoder_input, decoder_hidden)
            decoder_outputs.append(decoder_output)
            #print("decoder single output", decoder_output)
            if target_tensor is not None:
                # Teacher forcing: Feed the target as the next input
                #print("target tensor", target_tensor)
                decoder_input = target_tensor[:, i].unsqueeze(1) # Teacher forcing
                #print("Decoder input case 1 (target)", decoder_input)
            else:
                # Without teacher forcing: use its own predictions as the next input
                _, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze(-1).detach()  # detach from history as input
                #print("Decoder input case 2 (topi)", decoder_input)

        #print("decoder outputs", decoder_outputs)
        decoder_outputs = torch.cat(decoder_outputs, dim=1)
        decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)
        return decoder_outputs, decoder_hidden, None # We return `None` for consistency in the training loop

    def forward_step(self, input, hidden):
        output = self.embedding(input)
        output = F.relu(output)
        output, hidden = self.LSTM(output, hidden)
        output = self.out(output)
        return output, hidden

# %% [markdown]
# # Train encoder decoder

# %%
import torch.nn.utils as torch_utils

def train_epoch(dataloader, encoder, decoder, encoder_optimizer,
          decoder_optimizer, criterion, max_norm=5.0):

    total_loss = 0

    input_tensor, target_tensor = next(iter(dataloader))
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    encoder_outputs, encoder_hidden = encoder(input_tensor)
    decoder_outputs, _, _ = decoder(encoder_outputs, encoder_hidden, target_tensor)

    #print("Decoder that get passed =", decoder_outputs.view(-1, decoder_outputs.size(-1)))
    #print("target_tensor that get passed =", target_tensor.view(-1))
    loss = criterion(
        decoder_outputs.view(-1, decoder_outputs.size(-1)),
        target_tensor.view(-1)
    )
    #print("len of Decoder outputus:", len(decoder_outputs.view(-1, decoder_outputs.size(-1))))
    #print("len of target_tensor:", len(target_tensor.view(-1)))

    #print("decoder_outputs", decoder_outputs)
    #print("target_tensor", target_tensor)
    loss.backward()

    # Gradient clipping for both encoder and decoder
    torch_utils.clip_grad_norm_(encoder.parameters(), max_norm)
    torch_utils.clip_grad_norm_(decoder.parameters(), max_norm)

    encoder_optimizer.step()
    decoder_optimizer.step()

    total_loss += loss.item()

    return total_loss
    #return total_loss / len(dataloader)

# %%
import time
import math

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np

def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def train(train_dataloader, encoder, decoder, n_epochs, learning_rate=0.001,
               print_every=100, plot_every=100):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = torch.optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = torch.optim.Adam(decoder.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(1, n_epochs + 1):
        loss = train_epoch(train_dataloader, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if epoch % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, epoch / n_epochs),
                                        epoch, epoch / n_epochs * 100, print_loss_avg))

        if epoch % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %%
def evaluate(encoder, decoder, test_sentences, input_lang, output_lang):
    success = 0
    success_partial = 0
    with torch.no_grad():
      for i in range(len(test_sentences)):
          print(i)
          input_sentence = test_sentences[i][0]
          input_tensor = tensorFromSentence(input_lang, input_sentence)

          encoder_outputs, encoder_hidden = encoder(input_tensor)
          decoder_outputs, decoder_hidden, decoder_attn = decoder(encoder_outputs, encoder_hidden)

          _, topi = decoder_outputs.topk(1)
          decoded_ids = topi.squeeze()

          decoded_words = []
          for idx in decoded_ids:
              if idx.item() == EOS_token:
                  break
              decoded_words.append(output_lang.index2word[idx.item()])
          #check exact match between decoded_words and test_dataset[i][1]
          #print("Expected output: " + test_sentences[i][1])
          #print("Predicted output: " + " ".join(decoded_words))

          #check exact match
          if (decoded_words == test_sentences[i][1].split()):
              success = success + 1
              print("succes ", success, "out of", i+1)
          #check partial match
          if (test_sentences[i][1] in " ".join(decoded_words)):
              success_partial = success_partial + 1
              print("partial succes ", success_partial, "out of", i+1)


    print(f"Exact match accuracy: {success / len(test_sentences) * 100:.2f}%")
    print(f"Partial match accuracy: {success_partial / len(test_sentences) * 100:.2f}%")
    return (success / len(test_sentences) * 100)

# %% [markdown]
# # Experiment 1

# %%
indexes_001 = random.sample(range(len(train_set)), int(len(train_set)*0.01))
train_set_001= [train_set[i] for i in indexes_001]

indexes_002 = random.sample(range(len(train_set)-1), int(len(train_set)*0.02))
train_set_002= [train_set[i] for i in indexes_002]

indexes_004 = random.sample(range(len(train_set)-1), int(len(train_set)*0.04))
train_set_004= [train_set[i] for i in indexes_004]

indexes_008 = random.sample(range(len(train_set)-1), int(len(train_set)*0.08))
train_set_008= [train_set[i] for i in indexes_008]

indexes_016 = random.sample(range(len(train_set)-1), int(len(train_set)*0.16))
train_set_016= [train_set[i] for i in indexes_016]

indexes_032 = random.sample(range(len(train_set)-1), int(len(train_set)*0.32))
train_set_032= [train_set[i] for i in indexes_032]

indexes_64 = random.sample(range(len(train_set)-1), int(len(train_set)*0.64))
train_set_64= [train_set[i] for i in indexes_64]

# %%
print(indexes_001[:10])
# Out:
# [5476, 15543, 14420, 623, 10390, 15643, 1756, 8810, 3513, 1757]

# %%
#Dropout change based on the chosen architecture:
if architecture == "best":
  dropout = 0.5
else:
  dropout = 0

# %% [markdown]
# 1%

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set_001, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size, dropout).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)

train(train_dataloader, encoder, decoder, 15, print_every=100, plot_every=500)

# %%
results = []

# %%
eval = [eval_set[i] for i in range(4182)]
encoder.eval()
decoder.eval()
result001 = evaluate(encoder, decoder, eval, input_vocab, output_vocab)
results.append(result001)

# %% [markdown]
# 2%

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set_002, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size, dropout).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)


train(train_dataloader, encoder, decoder, 100000, print_every=1000, plot_every=500)

# %%
eval = [eval_set[i] for i in range(4182)]
encoder.eval()
decoder.eval()
result002 = evaluate(encoder, decoder, eval, input_vocab, output_vocab)
#results.append(result002)
# Out:
# Streaming output truncated to the last 5000 lines.
# 950
# 951
# 952
# succes  211 out of 953
# partial succes  335 out of 953
# 953
# succes  212 out of 954
# partial succes  336 out of 954
# 954
# 955
# 956
# 957
# 958
# succes  213 out of 959
# partial succes  337 out of 959
# 959
# 960
# 961
# succes  214 out of 962
# partial succes  338 out of 962
# 962
# 963
# succes  215 out of 964
# partial succes  339 out of 964
# 964
# 965
# 966
# succes  216 out of 967
# partial succes  340 out of 967
# 967
# 968
# partial succes  341 out of 969
# 969
# 970
# partial succes  342 out of 971
# 971
# partial succes  343 out of 972
# 972
# 973
# succes  217 out of 974
# partial succes  344 out of 974
# 974
# 975
# 976
# 977
# 978
# 979
# 980
# 981
# 982
# 983
# 984
# 985
# 986
# 987
# 988
# 989
# 990
# 991
# 992
# 993
# 994
# 995
# 996
# partial succes  345 out of 997
# 997
# succes  218 out of 998
# partial succes  346 out of 998
# 998
# 999
# 1000
# 1001
# 1002
# 1003
# succes  219 out of 1004
# partial succes  347 out of 1004
# 1004
# succes  220 out of 1005
# partial succes  348 out of 1005
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# succes  221 out of 1012
# partial succes  349 out of 1012
# 1012
# partial succes  350 out of 1013
# 1013
# 1014
# 1015
# 1016
# succes  222 out of 1017
# partial succes  351 out of 1017
# 1017
# succes  223 out of 1018
# partial succes  352 out of 1018
# 1018
# succes  224 out of 1019
# partial succes  353 out of 1019
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# partial succes  354 out of 1032
# 1032
# 1033
# partial succes  355 out of 1034
# 1034
# succes  225 out of 1035
# partial succes  356 out of 1035
# 1035
# succes  226 out of 1036
# partial succes  357 out of 1036
# 1036
# 1037
# partial succes  358 out of 1038
# 1038
# partial succes  359 out of 1039
# 1039
# 1040
# succes  227 out of 1041
# partial succes  360 out of 1041
# 1041
# partial succes  361 out of 1042
# 1042
# 1043
# partial succes  362 out of 1044
# 1044
# succes  228 out of 1045
# partial succes  363 out of 1045
# 1045
# 1046
# 1047
# 1048
# 1049
# succes  229 out of 1050
# partial succes  364 out of 1050
# 1050
# succes  230 out of 1051
# partial succes  365 out of 1051
# 1051
# 1052
# partial succes  366 out of 1053
# 1053
# 1054
# partial succes  367 out of 1055
# 1055
# 1056
# 1057
# 1058
# 1059
# succes  231 out of 1060
# partial succes  368 out of 1060
# 1060
# 1061
# 1062
# 1063
# 1064
# partial succes  369 out of 1065
# 1065
# partial succes  370 out of 1066
# 1066
# 1067
# 1068
# 1069
# succes  232 out of 1070
# partial succes  371 out of 1070
# 1070
# 1071
# partial succes  372 out of 1072
# 1072
# 1073
# 1074
# partial succes  373 out of 1075
# 1075
# partial succes  374 out of 1076
# 1076
# 1077
# 1078
# succes  233 out of 1079
# partial succes  375 out of 1079
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# succes  234 out of 1086
# partial succes  376 out of 1086
# 1086
# partial succes  377 out of 1087
# 1087
# partial succes  378 out of 1088
# 1088
# 1089
# succes  235 out of 1090
# partial succes  379 out of 1090
# 1090
# 1091
# succes  236 out of 1092
# partial succes  380 out of 1092
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# partial succes  381 out of 1098
# 1098
# partial succes  382 out of 1099
# 1099
# succes  237 out of 1100
# partial succes  383 out of 1100
# 1100
# 1101
# partial succes  384 out of 1102
# 1102
# succes  238 out of 1103
# partial succes  385 out of 1103
# 1103
# 1104
# 1105
# succes  239 out of 1106
# partial succes  386 out of 1106
# 1106
# 1107
# 1108
# 1109
# partial succes  387 out of 1110
# 1110
# succes  240 out of 1111
# partial succes  388 out of 1111
# 1111
# succes  241 out of 1112
# partial succes  389 out of 1112
# 1112
# 1113
# succes  242 out of 1114
# partial succes  390 out of 1114
# 1114
# succes  243 out of 1115
# partial succes  391 out of 1115
# 1115
# 1116
# partial succes  392 out of 1117
# 1117
# succes  244 out of 1118
# partial succes  393 out of 1118
# 1118
# succes  245 out of 1119
# partial succes  394 out of 1119
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# succes  246 out of 1125
# partial succes  395 out of 1125
# 1125
# 1126
# 1127
# 1128
# partial succes  396 out of 1129
# 1129
# 1130
# 1131
# 1132
# 1133
# 1134
# succes  247 out of 1135
# partial succes  397 out of 1135
# 1135
# 1136
# 1137
# 1138
# partial succes  398 out of 1139
# 1139
# 1140
# succes  248 out of 1141
# partial succes  399 out of 1141
# 1141
# 1142
# 1143
# 1144
# 1145
# partial succes  400 out of 1146
# 1146
# 1147
# 1148
# 1149
# 1150
# 1151
# 1152
# 1153
# 1154
# 1155
# partial succes  401 out of 1156
# 1156
# 1157
# partial succes  402 out of 1158
# 1158
# partial succes  403 out of 1159
# 1159
# 1160
# succes  249 out of 1161
# partial succes  404 out of 1161
# 1161
# 1162
# succes  250 out of 1163
# partial succes  405 out of 1163
# 1163
# 1164
# 1165
# 1166
# 1167
# 1168
# partial succes  406 out of 1169
# 1169
# 1170
# partial succes  407 out of 1171
# 1171
# 1172
# succes  251 out of 1173
# partial succes  408 out of 1173
# 1173
# 1174
# 1175
# 1176
# partial succes  409 out of 1177
# 1177
# 1178
# 1179
# 1180
# 1181
# partial succes  410 out of 1182
# 1182
# succes  252 out of 1183
# partial succes  411 out of 1183
# 1183
# 1184
# 1185
# 1186
# succes  253 out of 1187
# partial succes  412 out of 1187
# 1187
# 1188
# partial succes  413 out of 1189
# 1189
# 1190
# 1191
# succes  254 out of 1192
# partial succes  414 out of 1192
# 1192
# 1193
# succes  255 out of 1194
# partial succes  415 out of 1194
# 1194
# 1195
# 1196
# partial succes  416 out of 1197
# 1197
# 1198
# 1199
# succes  256 out of 1200
# partial succes  417 out of 1200
# 1200
# 1201
# 1202
# 1203
# 1204
# 1205
# 1206
# partial succes  418 out of 1207
# 1207
# 1208
# 1209
# partial succes  419 out of 1210
# 1210
# partial succes  420 out of 1211
# 1211
# partial succes  421 out of 1212
# 1212
# 1213
# 1214
# partial succes  422 out of 1215
# 1215
# 1216
# 1217
# 1218
# succes  257 out of 1219
# partial succes  423 out of 1219
# 1219
# 1220
# partial succes  424 out of 1221
# 1221
# 1222
# 1223
# 1224
# partial succes  425 out of 1225
# 1225
# 1226
# 1227
# 1228
# partial succes  426 out of 1229
# 1229
# 1230
# succes  258 out of 1231
# partial succes  427 out of 1231
# 1231
# 1232
# succes  259 out of 1233
# partial succes  428 out of 1233
# 1233
# 1234
# 1235
# succes  260 out of 1236
# partial succes  429 out of 1236
# 1236
# partial succes  430 out of 1237
# 1237
# 1238
# succes  261 out of 1239
# partial succes  431 out of 1239
# 1239
# 1240
# 1241
# 1242
# 1243
# succes  262 out of 1244
# partial succes  432 out of 1244
# 1244
# 1245
# partial succes  433 out of 1246
# 1246
# 1247
# 1248
# succes  263 out of 1249
# partial succes  434 out of 1249
# 1249
# 1250
# 1251
# 1252
# succes  264 out of 1253
# partial succes  435 out of 1253
# 1253
# partial succes  436 out of 1254
# 1254
# 1255
# partial succes  437 out of 1256
# 1256
# succes  265 out of 1257
# partial succes  438 out of 1257
# 1257
# succes  266 out of 1258
# partial succes  439 out of 1258
# 1258
# partial succes  440 out of 1259
# 1259
# succes  267 out of 1260
# partial succes  441 out of 1260
# 1260
# 1261
# succes  268 out of 1262
# partial succes  442 out of 1262
# 1262
# succes  269 out of 1263
# partial succes  443 out of 1263
# 1263
# 1264
# 1265
# 1266
# 1267
# 1268
# succes  270 out of 1269
# partial succes  444 out of 1269
# 1269
# 1270
# succes  271 out of 1271
# partial succes  445 out of 1271
# 1271
# 1272
# 1273
# 1274
# 1275
# 1276
# 1277
# partial succes  446 out of 1278
# 1278
# 1279
# succes  272 out of 1280
# partial succes  447 out of 1280
# 1280
# 1281
# 1282
# succes  273 out of 1283
# partial succes  448 out of 1283
# 1283
# succes  274 out of 1284
# partial succes  449 out of 1284
# 1284
# partial succes  450 out of 1285
# 1285
# 1286
# 1287
# succes  275 out of 1288
# partial succes  451 out of 1288
# 1288
# 1289
# partial succes  452 out of 1290
# 1290
# 1291
# partial succes  453 out of 1292
# 1292
# 1293
# 1294
# 1295
# 1296
# 1297
# 1298
# 1299
# 1300
# 1301
# succes  276 out of 1302
# partial succes  454 out of 1302
# 1302
# partial succes  455 out of 1303
# 1303
# 1304
# 1305
# partial succes  456 out of 1306
# 1306
# 1307
# succes  277 out of 1308
# partial succes  457 out of 1308
# 1308
# partial succes  458 out of 1309
# 1309
# 1310
# 1311
# partial succes  459 out of 1312
# 1312
# 1313
# 1314
# partial succes  460 out of 1315
# 1315
# 1316
# 1317
# 1318
# succes  278 out of 1319
# partial succes  461 out of 1319
# 1319
# succes  279 out of 1320
# partial succes  462 out of 1320
# 1320
# 1321
# 1322
# succes  280 out of 1323
# partial succes  463 out of 1323
# 1323
# succes  281 out of 1324
# partial succes  464 out of 1324
# 1324
# 1325
# 1326
# succes  282 out of 1327
# partial succes  465 out of 1327
# 1327
# partial succes  466 out of 1328
# 1328
# partial succes  467 out of 1329
# 1329
# 1330
# 1331
# 1332
# 1333
# 1334
# 1335
# 1336
# succes  283 out of 1337
# partial succes  468 out of 1337
# 1337
# succes  284 out of 1338
# partial succes  469 out of 1338
# 1338
# succes  285 out of 1339
# partial succes  470 out of 1339
# 1339
# 1340
# 1341
# 1342
# succes  286 out of 1343
# partial succes  471 out of 1343
# 1343
# partial succes  472 out of 1344
# 1344
# 1345
# 1346
# succes  287 out of 1347
# partial succes  473 out of 1347
# 1347
# partial succes  474 out of 1348
# 1348
# succes  288 out of 1349
# partial succes  475 out of 1349
# 1349
# succes  289 out of 1350
# partial succes  476 out of 1350
# 1350
# 1351
# 1352
# 1353
# partial succes  477 out of 1354
# 1354
# partial succes  478 out of 1355
# 1355
# 1356
# 1357
# succes  290 out of 1358
# partial succes  479 out of 1358
# 1358
# partial succes  480 out of 1359
# 1359
# 1360
# succes  291 out of 1361
# partial succes  481 out of 1361
# 1361
# 1362
# 1363
# 1364
# 1365
# succes  292 out of 1366
# partial succes  482 out of 1366
# 1366
# 1367
# 1368
# partial succes  483 out of 1369
# 1369
# partial succes  484 out of 1370
# 1370
# succes  293 out of 1371
# partial succes  485 out of 1371
# 1371
# partial succes  486 out of 1372
# 1372
# succes  294 out of 1373
# partial succes  487 out of 1373
# 1373
# partial succes  488 out of 1374
# 1374
# partial succes  489 out of 1375
# 1375
# partial succes  490 out of 1376
# 1376
# succes  295 out of 1377
# partial succes  491 out of 1377
# 1377
# 1378
# 1379
# succes  296 out of 1380
# partial succes  492 out of 1380
# 1380
# 1381
# 1382
# 1383
# 1384
# 1385
# 1386
# partial succes  493 out of 1387
# 1387
# 1388
# 1389
# 1390
# 1391
# 1392
# 1393
# partial succes  494 out of 1394
# 1394
# 1395
# 1396
# 1397
# succes  297 out of 1398
# partial succes  495 out of 1398
# 1398
# 1399
# succes  298 out of 1400
# partial succes  496 out of 1400
# 1400
# succes  299 out of 1401
# partial succes  497 out of 1401
# 1401
# 1402
# 1403
# partial succes  498 out of 1404
# 1404
# succes  300 out of 1405
# partial succes  499 out of 1405
# 1405
# succes  301 out of 1406
# partial succes  500 out of 1406
# 1406
# succes  302 out of 1407
# partial succes  501 out of 1407
# 1407
# 1408
# 1409
# 1410
# 1411
# 1412
# 1413
# partial succes  502 out of 1414
# 1414
# 1415
# succes  303 out of 1416
# partial succes  503 out of 1416
# 1416
# 1417
# 1418
# 1419
# 1420
# 1421
# 1422
# 1423
# partial succes  504 out of 1424
# 1424
# 1425
# 1426
# 1427
# 1428
# partial succes  505 out of 1429
# 1429
# 1430
# 1431
# 1432
# 1433
# succes  304 out of 1434
# partial succes  506 out of 1434
# 1434
# 1435
# 1436
# 1437
# partial succes  507 out of 1438
# 1438
# 1439
# 1440
# 1441
# 1442
# succes  305 out of 1443
# partial succes  508 out of 1443
# 1443
# 1444
# succes  306 out of 1445
# partial succes  509 out of 1445
# 1445
# 1446
# 1447
# 1448
# partial succes  510 out of 1449
# 1449
# succes  307 out of 1450
# partial succes  511 out of 1450
# 1450
# 1451
# 1452
# partial succes  512 out of 1453
# 1453
# 1454
# 1455
# succes  308 out of 1456
# partial succes  513 out of 1456
# 1456
# 1457
# 1458
# 1459
# 1460
# 1461
# 1462
# 1463
# partial succes  514 out of 1464
# 1464
# succes  309 out of 1465
# partial succes  515 out of 1465
# 1465
# succes  310 out of 1466
# partial succes  516 out of 1466
# 1466
# 1467
# 1468
# 1469
# succes  311 out of 1470
# partial succes  517 out of 1470
# 1470
# 1471
# partial succes  518 out of 1472
# 1472
# 1473
# succes  312 out of 1474
# partial succes  519 out of 1474
# 1474
# 1475
# partial succes  520 out of 1476
# 1476
# 1477
# 1478
# succes  313 out of 1479
# partial succes  521 out of 1479
# 1479
# 1480
# 1481
# succes  314 out of 1482
# partial succes  522 out of 1482
# 1482
# 1483
# succes  315 out of 1484
# partial succes  523 out of 1484
# 1484
# succes  316 out of 1485
# partial succes  524 out of 1485
# 1485
# 1486
# 1487
# succes  317 out of 1488
# partial succes  525 out of 1488
# 1488
# 1489
# 1490
# succes  318 out of 1491
# partial succes  526 out of 1491
# 1491
# partial succes  527 out of 1492
# 1492
# 1493
# 1494
# 1495
# succes  319 out of 1496
# partial succes  528 out of 1496
# 1496
# 1497
# 1498
# 1499
# 1500
# 1501
# succes  320 out of 1502
# partial succes  529 out of 1502
# 1502
# 1503
# succes  321 out of 1504
# partial succes  530 out of 1504
# 1504
# 1505
# succes  322 out of 1506
# partial succes  531 out of 1506
# 1506
# 1507
# 1508
# 1509
# 1510
# partial succes  532 out of 1511
# 1511
# 1512
# succes  323 out of 1513
# partial succes  533 out of 1513
# 1513
# 1514
# 1515
# partial succes  534 out of 1516
# 1516
# 1517
# partial succes  535 out of 1518
# 1518
# 1519
# succes  324 out of 1520
# partial succes  536 out of 1520
# 1520
# 1521
# 1522
# 1523
# succes  325 out of 1524
# partial succes  537 out of 1524
# 1524
# 1525
# 1526
# 1527
# 1528
# succes  326 out of 1529
# partial succes  538 out of 1529
# 1529
# 1530
# 1531
# 1532
# succes  327 out of 1533
# partial succes  539 out of 1533
# 1533
# succes  328 out of 1534
# partial succes  540 out of 1534
# 1534
# 1535
# partial succes  541 out of 1536
# 1536
# 1537
# partial succes  542 out of 1538
# 1538
# succes  329 out of 1539
# partial succes  543 out of 1539
# 1539
# succes  330 out of 1540
# partial succes  544 out of 1540
# 1540
# 1541
# succes  331 out of 1542
# partial succes  545 out of 1542
# 1542
# succes  332 out of 1543
# partial succes  546 out of 1543
# 1543
# 1544
# 1545
# 1546
# partial succes  547 out of 1547
# 1547
# 1548
# 1549
# 1550
# 1551
# 1552
# succes  333 out of 1553
# partial succes  548 out of 1553
# 1553
# 1554
# 1555
# 1556
# 1557
# partial succes  549 out of 1558
# 1558
# succes  334 out of 1559
# partial succes  550 out of 1559
# 1559
# 1560
# succes  335 out of 1561
# partial succes  551 out of 1561
# 1561
# 1562
# 1563
# 1564
# 1565
# 1566
# 1567
# 1568
# 1569
# 1570
# 1571
# 1572
# 1573
# 1574
# 1575
# partial succes  552 out of 1576
# 1576
# 1577
# 1578
# partial succes  553 out of 1579
# 1579
# 1580
# 1581
# 1582
# 1583
# 1584
# 1585
# 1586
# 1587
# succes  336 out of 1588
# partial succes  554 out of 1588
# 1588
# succes  337 out of 1589
# partial succes  555 out of 1589
# 1589
# succes  338 out of 1590
# partial succes  556 out of 1590
# 1590
# 1591
# succes  339 out of 1592
# partial succes  557 out of 1592
# 1592
# 1593
# 1594
# 1595
# succes  340 out of 1596
# partial succes  558 out of 1596
# 1596
# 1597
# succes  341 out of 1598
# partial succes  559 out of 1598
# 1598
# succes  342 out of 1599
# partial succes  560 out of 1599
# 1599
# 1600
# 1601
# 1602
# 1603
# 1604
# 1605
# partial succes  561 out of 1606
# 1606
# 1607
# 1608
# succes  343 out of 1609
# partial succes  562 out of 1609
# 1609
# 1610
# 1611
# partial succes  563 out of 1612
# 1612
# succes  344 out of 1613
# partial succes  564 out of 1613
# 1613
# 1614
# 1615
# succes  345 out of 1616
# partial succes  565 out of 1616
# 1616
# succes  346 out of 1617
# partial succes  566 out of 1617
# 1617
# succes  347 out of 1618
# partial succes  567 out of 1618
# 1618
# 1619
# 1620
# 1621
# 1622
# 1623
# succes  348 out of 1624
# partial succes  568 out of 1624
# 1624
# 1625
# succes  349 out of 1626
# partial succes  569 out of 1626
# 1626
# 1627
# 1628
# 1629
# succes  350 out of 1630
# partial succes  570 out of 1630
# 1630
# 1631
# partial succes  571 out of 1632
# 1632
# 1633
# 1634
# succes  351 out of 1635
# partial succes  572 out of 1635
# 1635
# partial succes  573 out of 1636
# 1636
# 1637
# 1638
# 1639
# 1640
# partial succes  574 out of 1641
# 1641
# 1642
# 1643
# 1644
# 1645
# succes  352 out of 1646
# partial succes  575 out of 1646
# 1646
# succes  353 out of 1647
# partial succes  576 out of 1647
# 1647
# 1648
# 1649
# 1650
# 1651
# 1652
# 1653
# 1654
# partial succes  577 out of 1655
# 1655
# 1656
# 1657
# 1658
# 1659
# 1660
# 1661
# 1662
# succes  354 out of 1663
# partial succes  578 out of 1663
# 1663
# 1664
# 1665
# 1666
# succes  355 out of 1667
# partial succes  579 out of 1667
# 1667
# succes  356 out of 1668
# partial succes  580 out of 1668
# 1668
# 1669
# 1670
# partial succes  581 out of 1671
# 1671
# succes  357 out of 1672
# partial succes  582 out of 1672
# 1672
# 1673
# 1674
# 1675
# partial succes  583 out of 1676
# 1676
# 1677
# 1678
# 1679
# partial succes  584 out of 1680
# 1680
# partial succes  585 out of 1681
# 1681
# 1682
# 1683
# 1684
# 1685
# 1686
# succes  358 out of 1687
# partial succes  586 out of 1687
# 1687
# 1688
# 1689
# 1690
# 1691
# 1692
# 1693
# partial succes  587 out of 1694
# 1694
# succes  359 out of 1695
# partial succes  588 out of 1695
# 1695
# succes  360 out of 1696
# partial succes  589 out of 1696
# 1696
# 1697
# 1698
# 1699
# 1700
# partial succes  590 out of 1701
# 1701
# 1702
# succes  361 out of 1703
# partial succes  591 out of 1703
# 1703
# 1704
# 1705
# partial succes  592 out of 1706
# 1706
# 1707
# 1708
# 1709
# 1710
# 1711
# 1712
# 1713
# succes  362 out of 1714
# partial succes  593 out of 1714
# 1714
# succes  363 out of 1715
# partial succes  594 out of 1715
# 1715
# 1716
# 1717
# partial succes  595 out of 1718
# 1718
# succes  364 out of 1719
# partial succes  596 out of 1719
# 1719
# 1720
# partial succes  597 out of 1721
# 1721
# 1722
# 1723
# 1724
# 1725
# 1726
# 1727
# partial succes  598 out of 1728
# 1728
# succes  365 out of 1729
# partial succes  599 out of 1729
# 1729
# partial succes  600 out of 1730
# 1730
# 1731
# partial succes  601 out of 1732
# 1732
# succes  366 out of 1733
# partial succes  602 out of 1733
# 1733
# 1734
# 1735
# succes  367 out of 1736
# partial succes  603 out of 1736
# 1736
# succes  368 out of 1737
# partial succes  604 out of 1737
# 1737
# 1738
# 1739
# 1740
# succes  369 out of 1741
# partial succes  605 out of 1741
# 1741
# 1742
# 1743
# 1744
# 1745
# partial succes  606 out of 1746
# 1746
# 1747
# 1748
# partial succes  607 out of 1749
# 1749
# 1750
# 1751
# 1752
# 1753
# 1754
# 1755
# 1756
# 1757
# 1758
# 1759
# 1760
# 1761
# succes  370 out of 1762
# partial succes  608 out of 1762
# 1762
# 1763
# 1764
# 1765
# 1766
# 1767
# 1768
# succes  371 out of 1769
# partial succes  609 out of 1769
# 1769
# succes  372 out of 1770
# partial succes  610 out of 1770
# 1770
# partial succes  611 out of 1771
# 1771
# 1772
# 1773
# succes  373 out of 1774
# partial succes  612 out of 1774
# 1774
# 1775
# 1776
# 1777
# 1778
# partial succes  613 out of 1779
# 1779
# partial succes  614 out of 1780
# 1780
# succes  374 out of 1781
# partial succes  615 out of 1781
# 1781
# 1782
# 1783
# succes  375 out of 1784
# partial succes  616 out of 1784
# 1784
# 1785
# 1786
# succes  376 out of 1787
# partial succes  617 out of 1787
# 1787
# partial succes  618 out of 1788
# 1788
# succes  377 out of 1789
# partial succes  619 out of 1789
# 1789
# succes  378 out of 1790
# partial succes  620 out of 1790
# 1790
# succes  379 out of 1791
# partial succes  621 out of 1791
# 1791
# 1792
# 1793
# 1794
# 1795
# 1796
# 1797
# partial succes  622 out of 1798
# 1798
# 1799
# 1800
# 1801
# partial succes  623 out of 1802
# 1802
# 1803
# 1804
# 1805
# partial succes  624 out of 1806
# 1806
# 1807
# 1808
# 1809
# succes  380 out of 1810
# partial succes  625 out of 1810
# 1810
# succes  381 out of 1811
# partial succes  626 out of 1811
# 1811
# 1812
# succes  382 out of 1813
# partial succes  627 out of 1813
# 1813
# 1814
# 1815
# succes  383 out of 1816
# partial succes  628 out of 1816
# 1816
# 1817
# succes  384 out of 1818
# partial succes  629 out of 1818
# 1818
# succes  385 out of 1819
# partial succes  630 out of 1819
# 1819
# partial succes  631 out of 1820
# 1820
# partial succes  632 out of 1821
# 1821
# 1822
# 1823
# succes  386 out of 1824
# partial succes  633 out of 1824
# 1824
# 1825
# 1826
# 1827
# 1828
# 1829
# 1830
# succes  387 out of 1831
# partial succes  634 out of 1831
# 1831
# 1832
# 1833
# 1834
# 1835
# 1836
# 1837
# 1838
# 1839
# 1840
# 1841
# 1842
# 1843
# 1844
# 1845
# 1846
# partial succes  635 out of 1847
# 1847
# 1848
# 1849
# partial succes  636 out of 1850
# 1850
# succes  388 out of 1851
# partial succes  637 out of 1851
# 1851
# 1852
# 1853
# 1854
# succes  389 out of 1855
# partial succes  638 out of 1855
# 1855
# 1856
# succes  390 out of 1857
# partial succes  639 out of 1857
# 1857
# partial succes  640 out of 1858
# 1858
# 1859
# 1860
# 1861
# succes  391 out of 1862
# partial succes  641 out of 1862
# 1862
# 1863
# 1864
# 1865
# 1866
# 1867
# 1868
# 1869
# partial succes  642 out of 1870
# 1870
# succes  392 out of 1871
# partial succes  643 out of 1871
# 1871
# 1872
# 1873
# partial succes  644 out of 1874
# 1874
# succes  393 out of 1875
# partial succes  645 out of 1875
# 1875
# 1876
# 1877
# 1878
# 1879
# succes  394 out of 1880
# partial succes  646 out of 1880
# 1880
# 1881
# 1882
# succes  395 out of 1883
# partial succes  647 out of 1883
# 1883
# partial succes  648 out of 1884
# 1884
# partial succes  649 out of 1885
# 1885
# 1886
# 1887
# 1888
# succes  396 out of 1889
# partial succes  650 out of 1889
# 1889
# partial succes  651 out of 1890
# 1890
# partial succes  652 out of 1891
# 1891
# succes  397 out of 1892
# partial succes  653 out of 1892
# 1892
# 1893
# 1894
# succes  398 out of 1895
# partial succes  654 out of 1895
# 1895
# partial succes  655 out of 1896
# 1896
# partial succes  656 out of 1897
# 1897
# 1898
# 1899
# partial succes  657 out of 1900
# 1900
# 1901
# 1902
# partial succes  658 out of 1903
# 1903
# 1904
# 1905
# succes  399 out of 1906
# partial succes  659 out of 1906
# 1906
# succes  400 out of 1907
# partial succes  660 out of 1907
# 1907
# succes  401 out of 1908
# partial succes  661 out of 1908
# 1908
# succes  402 out of 1909
# partial succes  662 out of 1909
# 1909
# 1910
# 1911
# 1912
# 1913
# 1914
# 1915
# succes  403 out of 1916
# partial succes  663 out of 1916
# 1916
# 1917
# 1918
# 1919
# 1920
# 1921
# 1922
# partial succes  664 out of 1923
# 1923
# partial succes  665 out of 1924
# 1924
# 1925
# succes  404 out of 1926
# partial succes  666 out of 1926
# 1926
# succes  405 out of 1927
# partial succes  667 out of 1927
# 1927
# partial succes  668 out of 1928
# 1928
# 1929
# succes  406 out of 1930
# partial succes  669 out of 1930
# 1930
# 1931
# partial succes  670 out of 1932
# 1932
# 1933
# 1934
# 1935
# 1936
# succes  407 out of 1937
# partial succes  671 out of 1937
# 1937
# 1938
# 1939
# 1940
# 1941
# succes  408 out of 1942
# partial succes  672 out of 1942
# 1942
# 1943
# 1944
# succes  409 out of 1945
# partial succes  673 out of 1945
# 1945
# 1946
# 1947
# 1948
# succes  410 out of 1949
# partial succes  674 out of 1949
# 1949
# succes  411 out of 1950
# partial succes  675 out of 1950
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# partial succes  676 out of 1959
# 1959
# 1960
# succes  412 out of 1961
# partial succes  677 out of 1961
# 1961
# succes  413 out of 1962
# partial succes  678 out of 1962
# 1962
# 1963
# 1964
# 1965
# partial succes  679 out of 1966
# 1966
# succes  414 out of 1967
# partial succes  680 out of 1967
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# partial succes  681 out of 1978
# 1978
# 1979
# succes  415 out of 1980
# partial succes  682 out of 1980
# 1980
# partial succes  683 out of 1981
# 1981
# 1982
# 1983
# 1984
# succes  416 out of 1985
# partial succes  684 out of 1985
# 1985
# 1986
# 1987
# succes  417 out of 1988
# partial succes  685 out of 1988
# 1988
# partial succes  686 out of 1989
# 1989
# succes  418 out of 1990
# partial succes  687 out of 1990
# 1990
# 1991
# 1992
# 1993
# partial succes  688 out of 1994
# 1994
# 1995
# succes  419 out of 1996
# partial succes  689 out of 1996
# 1996
# partial succes  690 out of 1997
# 1997
# partial succes  691 out of 1998
# 1998
# 1999
# 2000
# succes  420 out of 2001
# partial succes  692 out of 2001
# 2001
# 2002
# succes  421 out of 2003
# partial succes  693 out of 2003
# 2003
# 2004
# 2005
# succes  422 out of 2006
# partial succes  694 out of 2006
# 2006
# 2007
# partial succes  695 out of 2008
# 2008
# 2009
# partial succes  696 out of 2010
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# succes  423 out of 2016
# partial succes  697 out of 2016
# 2016
# 2017
# 2018
# succes  424 out of 2019
# partial succes  698 out of 2019
# 2019
# succes  425 out of 2020
# partial succes  699 out of 2020
# 2020
# 2021
# 2022
# 2023
# 2024
# 2025
# 2026
# 2027
# succes  426 out of 2028
# partial succes  700 out of 2028
# 2028
# 2029
# succes  427 out of 2030
# partial succes  701 out of 2030
# 2030
# partial succes  702 out of 2031
# 2031
# 2032
# 2033
# succes  428 out of 2034
# partial succes  703 out of 2034
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# succes  429 out of 2041
# partial succes  704 out of 2041
# 2041
# succes  430 out of 2042
# partial succes  705 out of 2042
# 2042
# 2043
# 2044
# succes  431 out of 2045
# partial succes  706 out of 2045
# 2045
# 2046
# 2047
# partial succes  707 out of 2048
# 2048
# partial succes  708 out of 2049
# 2049
# 2050
# 2051
# 2052
# 2053
# partial succes  709 out of 2054
# 2054
# 2055
# 2056
# 2057
# partial succes  710 out of 2058
# 2058
# 2059
# partial succes  711 out of 2060
# 2060
# 2061
# partial succes  712 out of 2062
# 2062
# partial succes  713 out of 2063
# 2063
# 2064
# 2065
# 2066
# 2067
# succes  432 out of 2068
# partial succes  714 out of 2068
# 2068
# partial succes  715 out of 2069
# 2069
# succes  433 out of 2070
# partial succes  716 out of 2070
# 2070
# 2071
# partial succes  717 out of 2072
# 2072
# 2073
# partial succes  718 out of 2074
# 2074
# 2075
# succes  434 out of 2076
# partial succes  719 out of 2076
# 2076
# succes  435 out of 2077
# partial succes  720 out of 2077
# 2077
# succes  436 out of 2078
# partial succes  721 out of 2078
# 2078
# succes  437 out of 2079
# partial succes  722 out of 2079
# 2079
# 2080
# partial succes  723 out of 2081
# 2081
# succes  438 out of 2082
# partial succes  724 out of 2082
# 2082
# succes  439 out of 2083
# partial succes  725 out of 2083
# 2083
# 2084
# 2085
# 2086
# 2087
# 2088
# 2089
# 2090
# succes  440 out of 2091
# partial succes  726 out of 2091
# 2091
# succes  441 out of 2092
# partial succes  727 out of 2092
# 2092
# 2093
# partial succes  728 out of 2094
# 2094
# 2095
# 2096
# succes  442 out of 2097
# partial succes  729 out of 2097
# 2097
# succes  443 out of 2098
# partial succes  730 out of 2098
# 2098
# 2099
# 2100
# 2101
# 2102
# succes  444 out of 2103
# partial succes  731 out of 2103
# 2103
# succes  445 out of 2104
# partial succes  732 out of 2104
# 2104
# 2105
# 2106
# 2107
# 2108
# 2109
# 2110
# 2111
# 2112
# succes  446 out of 2113
# partial succes  733 out of 2113
# 2113
# partial succes  734 out of 2114
# 2114
# partial succes  735 out of 2115
# 2115
# 2116
# succes  447 out of 2117
# partial succes  736 out of 2117
# 2117
# 2118
# 2119
# 2120
# 2121
# 2122
# 2123
# 2124
# 2125
# 2126
# 2127
# 2128
# 2129
# partial succes  737 out of 2130
# 2130
# 2131
# partial succes  738 out of 2132
# 2132
# succes  448 out of 2133
# partial succes  739 out of 2133
# 2133
# succes  449 out of 2134
# partial succes  740 out of 2134
# 2134
# 2135
# partial succes  741 out of 2136
# 2136
# 2137
# partial succes  742 out of 2138
# 2138
# partial succes  743 out of 2139
# 2139
# 2140
# partial succes  744 out of 2141
# 2141
# 2142
# succes  450 out of 2143
# partial succes  745 out of 2143
# 2143
# 2144
# 2145
# partial succes  746 out of 2146
# 2146
# 2147
# partial succes  747 out of 2148
# 2148
# partial succes  748 out of 2149
# 2149
# 2150
# succes  451 out of 2151
# partial succes  749 out of 2151
# 2151
# succes  452 out of 2152
# partial succes  750 out of 2152
# 2152
# 2153
# 2154
# 2155
# 2156
# 2157
# 2158
# 2159
# 2160
# 2161
# 2162
# 2163
# succes  453 out of 2164
# partial succes  751 out of 2164
# 2164
# partial succes  752 out of 2165
# 2165
# succes  454 out of 2166
# partial succes  753 out of 2166
# 2166
# 2167
# partial succes  754 out of 2168
# 2168
# 2169
# succes  455 out of 2170
# partial succes  755 out of 2170
# 2170
# 2171
# 2172
# 2173
# succes  456 out of 2174
# partial succes  756 out of 2174
# 2174
# 2175
# 2176
# 2177
# succes  457 out of 2178
# partial succes  757 out of 2178
# 2178
# 2179
# partial succes  758 out of 2180
# 2180
# partial succes  759 out of 2181
# 2181
# 2182
# 2183
# partial succes  760 out of 2184
# 2184
# partial succes  761 out of 2185
# 2185
# 2186
# 2187
# 2188
# 2189
# succes  458 out of 2190
# partial succes  762 out of 2190
# 2190
# 2191
# 2192
# 2193
# partial succes  763 out of 2194
# 2194
# 2195
# 2196
# partial succes  764 out of 2197
# 2197
# partial succes  765 out of 2198
# 2198
# 2199
# succes  459 out of 2200
# partial succes  766 out of 2200
# 2200
# 2201
# partial succes  767 out of 2202
# 2202
# 2203
# 2204
# 2205
# succes  460 out of 2206
# partial succes  768 out of 2206
# 2206
# 2207
# 2208
# 2209
# 2210
# 2211
# 2212
# partial succes  769 out of 2213
# 2213
# 2214
# 2215
# succes  461 out of 2216
# partial succes  770 out of 2216
# 2216
# 2217
# 2218
# succes  462 out of 2219
# partial succes  771 out of 2219
# 2219
# partial succes  772 out of 2220
# 2220
# 2221
# succes  463 out of 2222
# partial succes  773 out of 2222
# 2222
# partial succes  774 out of 2223
# 2223
# 2224
# partial succes  775 out of 2225
# 2225
# partial succes  776 out of 2226
# 2226
# 2227
# 2228
# 2229
# 2230
# 2231
# 2232
# 2233
# 2234
# partial succes  777 out of 2235
# 2235
# succes  464 out of 2236
# partial succes  778 out of 2236
# 2236
# partial succes  779 out of 2237
# 2237
# partial succes  780 out of 2238
# 2238
# succes  465 out of 2239
# partial succes  781 out of 2239
# 2239
# 2240
# 2241
# 2242
# 2243
# 2244
# 2245
# partial succes  782 out of 2246
# 2246
# 2247
# partial succes  783 out of 2248
# 2248
# 2249
# 2250
# 2251
# 2252
# succes  466 out of 2253
# partial succes  784 out of 2253
# 2253
# succes  467 out of 2254
# partial succes  785 out of 2254
# 2254
# 2255
# partial succes  786 out of 2256
# 2256
# 2257
# 2258
# 2259
# 2260
# 2261
# 2262
# partial succes  787 out of 2263
# 2263
# 2264
# 2265
# 2266
# 2267
# partial succes  788 out of 2268
# 2268
# 2269
# 2270
# 2271
# 2272
# 2273
# 2274
# 2275
# partial succes  789 out of 2276
# 2276
# partial succes  790 out of 2277
# 2277
# 2278
# succes  468 out of 2279
# partial succes  791 out of 2279
# 2279
# 2280
# 2281
# 2282
# 2283
# 2284
# 2285
# succes  469 out of 2286
# partial succes  792 out of 2286
# 2286
# 2287
# 2288
# 2289
# 2290
# succes  470 out of 2291
# partial succes  793 out of 2291
# 2291
# 2292
# 2293
# partial succes  794 out of 2294
# 2294
# 2295
# 2296
# 2297
# 2298
# 2299
# succes  471 out of 2300
# partial succes  795 out of 2300
# 2300
# succes  472 out of 2301
# partial succes  796 out of 2301
# 2301
# 2302
# 2303
# 2304
# succes  473 out of 2305
# partial succes  797 out of 2305
# 2305
# partial succes  798 out of 2306
# 2306
# 2307
# 2308
# 2309
# 2310
# partial succes  799 out of 2311
# 2311
# succes  474 out of 2312
# partial succes  800 out of 2312
# 2312
# 2313
# 2314
# 2315
# succes  475 out of 2316
# partial succes  801 out of 2316
# 2316
# 2317
# 2318
# 2319
# 2320
# 2321
# 2322
# 2323
# 2324
# 2325
# 2326
# 2327
# partial succes  802 out of 2328
# 2328
# succes  476 out of 2329
# partial succes  803 out of 2329
# 2329
# 2330
# 2331
# 2332
# 2333
# partial succes  804 out of 2334
# 2334
# 2335
# 2336
# succes  477 out of 2337
# partial succes  805 out of 2337
# 2337
# 2338
# succes  478 out of 2339
# partial succes  806 out of 2339
# 2339
# 2340
# 2341
# 2342
# 2343
# 2344
# 2345
# 2346
# succes  479 out of 2347
# partial succes  807 out of 2347
# 2347
# 2348
# succes  480 out of 2349
# partial succes  808 out of 2349
# 2349
# 2350
# succes  481 out of 2351
# partial succes  809 out of 2351
# 2351
# 2352
# 2353
# 2354
# 2355
# succes  482 out of 2356
# partial succes  810 out of 2356
# 2356
# 2357
# 2358
# 2359
# 2360
# partial succes  811 out of 2361
# 2361
# succes  483 out of 2362
# partial succes  812 out of 2362
# 2362
# partial succes  813 out of 2363
# 2363
# succes  484 out of 2364
# partial succes  814 out of 2364
# 2364
# succes  485 out of 2365
# partial succes  815 out of 2365
# 2365
# 2366
# 2367
# 2368
# partial succes  816 out of 2369
# 2369
# 2370
# succes  486 out of 2371
# partial succes  817 out of 2371
# 2371
# partial succes  818 out of 2372
# 2372
# 2373
# succes  487 out of 2374
# partial succes  819 out of 2374
# 2374
# succes  488 out of 2375
# partial succes  820 out of 2375
# 2375
# 2376
# partial succes  821 out of 2377
# 2377
# 2378
# partial succes  822 out of 2379
# 2379
# 2380
# partial succes  823 out of 2381
# 2381
# 2382
# 2383
# 2384
# 2385
# partial succes  824 out of 2386
# 2386
# 2387
# 2388
# 2389
# 2390
# 2391
# 2392
# 2393
# 2394
# succes  489 out of 2395
# partial succes  825 out of 2395
# 2395
# 2396
# succes  490 out of 2397
# partial succes  826 out of 2397
# 2397
# 2398
# 2399
# 2400
# 2401
# 2402
# 2403
# 2404
# 2405
# 2406
# 2407
# partial succes  827 out of 2408
# 2408
# 2409
# 2410
# partial succes  828 out of 2411
# 2411
# succes  491 out of 2412
# partial succes  829 out of 2412
# 2412
# 2413
# 2414
# succes  492 out of 2415
# partial succes  830 out of 2415
# 2415
# 2416
# 2417
# succes  493 out of 2418
# partial succes  831 out of 2418
# 2418
# 2419
# 2420
# 2421
# succes  494 out of 2422
# partial succes  832 out of 2422
# 2422
# succes  495 out of 2423
# partial succes  833 out of 2423
# 2423
# partial succes  834 out of 2424
# 2424
# 2425
# 2426
# succes  496 out of 2427
# partial succes  835 out of 2427
# 2427
# 2428
# 2429
# 2430
# succes  497 out of 2431
# partial succes  836 out of 2431
# 2431
# 2432
# 2433
# 2434
# 2435
# 2436
# succes  498 out of 2437
# partial succes  837 out of 2437
# 2437
# 2438
# partial succes  838 out of 2439
# 2439
# succes  499 out of 2440
# partial succes  839 out of 2440
# 2440
# succes  500 out of 2441
# partial succes  840 out of 2441
# 2441
# succes  501 out of 2442
# partial succes  841 out of 2442
# 2442
# succes  502 out of 2443
# partial succes  842 out of 2443
# 2443
# 2444
# 2445
# partial succes  843 out of 2446
# 2446
# succes  503 out of 2447
# partial succes  844 out of 2447
# 2447
# 2448
# 2449
# 2450
# 2451
# 2452
# succes  504 out of 2453
# partial succes  845 out of 2453
# 2453
# partial succes  846 out of 2454
# 2454
# 2455
# succes  505 out of 2456
# partial succes  847 out of 2456
# 2456
# 2457
# succes  506 out of 2458
# partial succes  848 out of 2458
# 2458
# 2459
# succes  507 out of 2460
# partial succes  849 out of 2460
# 2460
# 2461
# partial succes  850 out of 2462
# 2462
# 2463
# 2464
# 2465
# 2466
# 2467
# 2468
# partial succes  851 out of 2469
# 2469
# partial succes  852 out of 2470
# 2470
# partial succes  853 out of 2471
# 2471
# partial succes  854 out of 2472
# 2472
# 2473
# 2474
# succes  508 out of 2475
# partial succes  855 out of 2475
# 2475
# partial succes  856 out of 2476
# 2476
# 2477
# 2478
# 2479
# partial succes  857 out of 2480
# 2480
# succes  509 out of 2481
# partial succes  858 out of 2481
# 2481
# 2482
# 2483
# 2484
# 2485
# 2486
# 2487
# 2488
# 2489
# 2490
# partial succes  859 out of 2491
# 2491
# 2492
# 2493
# 2494
# succes  510 out of 2495
# partial succes  860 out of 2495
# 2495
# 2496
# succes  511 out of 2497
# partial succes  861 out of 2497
# 2497
# succes  512 out of 2498
# partial succes  862 out of 2498
# 2498
# 2499
# partial succes  863 out of 2500
# 2500
# succes  513 out of 2501
# partial succes  864 out of 2501
# 2501
# partial succes  865 out of 2502
# 2502
# 2503
# 2504
# 2505
# partial succes  866 out of 2506
# 2506
# succes  514 out of 2507
# partial succes  867 out of 2507
# 2507
# 2508
# partial succes  868 out of 2509
# 2509
# 2510
# 2511
# partial succes  869 out of 2512
# 2512
# 2513
# succes  515 out of 2514
# partial succes  870 out of 2514
# 2514
# 2515
# 2516
# 2517
# 2518
# 2519
# 2520
# 2521
# 2522
# 2523
# 2524
# succes  516 out of 2525
# partial succes  871 out of 2525
# 2525
# succes  517 out of 2526
# partial succes  872 out of 2526
# 2526
# 2527
# 2528
# 2529
# 2530
# partial succes  873 out of 2531
# 2531
# partial succes  874 out of 2532
# 2532
# 2533
# 2534
# partial succes  875 out of 2535
# 2535
# 2536
# 2537
# 2538
# 2539
# partial succes  876 out of 2540
# 2540
# succes  518 out of 2541
# partial succes  877 out of 2541
# 2541
# 2542
# succes  519 out of 2543
# partial succes  878 out of 2543
# 2543
# 2544
# 2545
# 2546
# 2547
# 2548
# 2549
# 2550
# 2551
# 2552
# partial succes  879 out of 2553
# 2553
# succes  520 out of 2554
# partial succes  880 out of 2554
# 2554
# 2555
# 2556
# 2557
# 2558
# succes  521 out of 2559
# partial succes  881 out of 2559
# 2559
# 2560
# 2561
# succes  522 out of 2562
# partial succes  882 out of 2562
# 2562
# succes  523 out of 2563
# partial succes  883 out of 2563
# 2563
# 2564
# 2565
# partial succes  884 out of 2566
# 2566
# partial succes  885 out of 2567
# 2567
# partial succes  886 out of 2568
# 2568
# 2569
# 2570
# 2571
# 2572
# 2573
# 2574
# succes  524 out of 2575
# partial succes  887 out of 2575
# 2575
# 2576
# partial succes  888 out of 2577
# 2577
# succes  525 out of 2578
# partial succes  889 out of 2578
# 2578
# 2579
# succes  526 out of 2580
# partial succes  890 out of 2580
# 2580
# 2581
# 2582
# 2583
# 2584
# 2585
# 2586
# 2587
# 2588
# 2589
# 2590
# 2591
# succes  527 out of 2592
# partial succes  891 out of 2592
# 2592
# succes  528 out of 2593
# partial succes  892 out of 2593
# 2593
# partial succes  893 out of 2594
# 2594
# partial succes  894 out of 2595
# 2595
# 2596
# partial succes  895 out of 2597
# 2597
# 2598
# succes  529 out of 2599
# partial succes  896 out of 2599
# 2599
# partial succes  897 out of 2600
# 2600
# 2601
# 2602
# succes  530 out of 2603
# partial succes  898 out of 2603
# 2603
# 2604
# partial succes  899 out of 2605
# 2605
# partial succes  900 out of 2606
# 2606
# 2607
# 2608
# 2609
# 2610
# partial succes  901 out of 2611
# 2611
# 2612
# partial succes  902 out of 2613
# 2613
# 2614
# 2615
# succes  531 out of 2616
# partial succes  903 out of 2616
# 2616
# succes  532 out of 2617
# partial succes  904 out of 2617
# 2617
# 2618
# succes  533 out of 2619
# partial succes  905 out of 2619
# 2619
# 2620
# 2621
# partial succes  906 out of 2622
# 2622
# 2623
# 2624
# succes  534 out of 2625
# partial succes  907 out of 2625
# 2625
# 2626
# partial succes  908 out of 2627
# 2627
# partial succes  909 out of 2628
# 2628
# 2629
# 2630
# 2631
# succes  535 out of 2632
# partial succes  910 out of 2632
# 2632
# 2633
# succes  536 out of 2634
# partial succes  911 out of 2634
# 2634
# 2635
# 2636
# 2637
# 2638
# succes  537 out of 2639
# partial succes  912 out of 2639
# 2639
# succes  538 out of 2640
# partial succes  913 out of 2640
# 2640
# succes  539 out of 2641
# partial succes  914 out of 2641
# 2641
# 2642
# 2643
# 2644
# 2645
# succes  540 out of 2646
# partial succes  915 out of 2646
# 2646
# 2647
# 2648
# 2649
# 2650
# 2651
# partial succes  916 out of 2652
# 2652
# partial succes  917 out of 2653
# 2653
# succes  541 out of 2654
# partial succes  918 out of 2654
# 2654
# 2655
# 2656
# 2657
# 2658
# 2659
# succes  542 out of 2660
# partial succes  919 out of 2660
# 2660
# 2661
# partial succes  920 out of 2662
# 2662
# succes  543 out of 2663
# partial succes  921 out of 2663
# 2663
# partial succes  922 out of 2664
# 2664
# 2665
# partial succes  923 out of 2666
# 2666
# 2667
# 2668
# 2669
# 2670
# succes  544 out of 2671
# partial succes  924 out of 2671
# 2671
# 2672
# 2673
# 2674
# succes  545 out of 2675
# partial succes  925 out of 2675
# 2675
# 2676
# partial succes  926 out of 2677
# 2677
# 2678
# 2679
# 2680
# 2681
# 2682
# 2683
# 2684
# 2685
# 2686
# 2687
# 2688
# succes  546 out of 2689
# partial succes  927 out of 2689
# 2689
# 2690
# 2691
# 2692
# partial succes  928 out of 2693
# 2693
# 2694
# 2695
# succes  547 out of 2696
# partial succes  929 out of 2696
# 2696
# 2697
# succes  548 out of 2698
# partial succes  930 out of 2698
# 2698
# 2699
# partial succes  931 out of 2700
# 2700
# partial succes  932 out of 2701
# 2701
# 2702
# 2703
# 2704
# 2705
# 2706
# 2707
# 2708
# 2709
# partial succes  933 out of 2710
# 2710
# partial succes  934 out of 2711
# 2711
# 2712
# 2713
# 2714
# partial succes  935 out of 2715
# 2715
# 2716
# 2717
# 2718
# succes  549 out of 2719
# partial succes  936 out of 2719
# 2719
# 2720
# succes  550 out of 2721
# partial succes  937 out of 2721
# 2721
# 2722
# partial succes  938 out of 2723
# 2723
# 2724
# 2725
# 2726
# 2727
# 2728
# partial succes  939 out of 2729
# 2729
# 2730
# 2731
# succes  551 out of 2732
# partial succes  940 out of 2732
# 2732
# partial succes  941 out of 2733
# 2733
# 2734
# succes  552 out of 2735
# partial succes  942 out of 2735
# 2735
# 2736
# 2737
# succes  553 out of 2738
# partial succes  943 out of 2738
# 2738
# 2739
# 2740
# 2741
# 2742
# succes  554 out of 2743
# partial succes  944 out of 2743
# 2743
# 2744
# 2745
# 2746
# 2747
# partial succes  945 out of 2748
# 2748
# 2749
# succes  555 out of 2750
# partial succes  946 out of 2750
# 2750
# 2751
# succes  556 out of 2752
# partial succes  947 out of 2752
# 2752
# 2753
# 2754
# 2755
# 2756
# 2757
# 2758
# 2759
# 2760
# 2761
# 2762
# succes  557 out of 2763
# partial succes  948 out of 2763
# 2763
# 2764
# 2765
# succes  558 out of 2766
# partial succes  949 out of 2766
# 2766
# 2767
# 2768
# succes  559 out of 2769
# partial succes  950 out of 2769
# 2769
# succes  560 out of 2770
# partial succes  951 out of 2770
# 2770
# 2771
# 2772
# 2773
# 2774
# 2775
# 2776
# 2777
# 2778
# 2779
# 2780
# 2781
# 2782
# 2783
# 2784
# 2785
# 2786
# partial succes  952 out of 2787
# 2787
# 2788
# partial succes  953 out of 2789
# 2789
# 2790
# 2791
# 2792
# partial succes  954 out of 2793
# 2793
# succes  561 out of 2794
# partial succes  955 out of 2794
# 2794
# 2795
# succes  562 out of 2796
# partial succes  956 out of 2796
# 2796
# 2797
# succes  563 out of 2798
# partial succes  957 out of 2798
# 2798
# 2799
# succes  564 out of 2800
# partial succes  958 out of 2800
# 2800
# 2801
# 2802
# partial succes  959 out of 2803
# 2803
# 2804
# 2805
# partial succes  960 out of 2806
# 2806
# 2807
# partial succes  961 out of 2808
# 2808
# 2809
# succes  565 out of 2810
# partial succes  962 out of 2810
# 2810
# succes  566 out of 2811
# partial succes  963 out of 2811
# 2811
# 2812
# succes  567 out of 2813
# partial succes  964 out of 2813
# 2813
# 2814
# 2815
# 2816
# 2817
# 2818
# 2819
# 2820
# 2821
# 2822
# succes  568 out of 2823
# partial succes  965 out of 2823
# 2823
# partial succes  966 out of 2824
# 2824
# partial succes  967 out of 2825
# 2825
# 2826
# 2827
# partial succes  968 out of 2828
# 2828
# 2829
# 2830
# succes  569 out of 2831
# partial succes  969 out of 2831
# 2831
# 2832
# 2833
# 2834
# 2835
# succes  570 out of 2836
# partial succes  970 out of 2836
# 2836
# partial succes  971 out of 2837
# 2837
# 2838
# 2839
# succes  571 out of 2840
# partial succes  972 out of 2840
# 2840
# succes  572 out of 2841
# partial succes  973 out of 2841
# 2841
# partial succes  974 out of 2842
# 2842
# succes  573 out of 2843
# partial succes  975 out of 2843
# 2843
# succes  574 out of 2844
# partial succes  976 out of 2844
# 2844
# 2845
# 2846
# 2847
# 2848
# succes  575 out of 2849
# partial succes  977 out of 2849
# 2849
# succes  576 out of 2850
# partial succes  978 out of 2850
# 2850
# 2851
# 2852
# succes  577 out of 2853
# partial succes  979 out of 2853
# 2853
# 2854
# 2855
# succes  578 out of 2856
# partial succes  980 out of 2856
# 2856
# 2857
# 2858
# 2859
# 2860
# partial succes  981 out of 2861
# 2861
# 2862
# partial succes  982 out of 2863
# 2863
# 2864
# 2865
# 2866
# succes  579 out of 2867
# partial succes  983 out of 2867
# 2867
# 2868
# 2869
# 2870
# 2871
# 2872
# succes  580 out of 2873
# partial succes  984 out of 2873
# 2873
# 2874
# 2875
# 2876
# 2877
# succes  581 out of 2878
# partial succes  985 out of 2878
# 2878
# 2879
# succes  582 out of 2880
# partial succes  986 out of 2880
# 2880
# partial succes  987 out of 2881
# 2881
# 2882
# 2883
# succes  583 out of 2884
# partial succes  988 out of 2884
# 2884
# 2885
# 2886
# 2887
# 2888
# 2889
# succes  584 out of 2890
# partial succes  989 out of 2890
# 2890
# 2891
# 2892
# 2893
# 2894
# 2895
# 2896
# 2897
# 2898
# succes  585 out of 2899
# partial succes  990 out of 2899
# 2899
# succes  586 out of 2900
# partial succes  991 out of 2900
# 2900
# partial succes  992 out of 2901
# 2901
# succes  587 out of 2902
# partial succes  993 out of 2902
# 2902
# 2903
# partial succes  994 out of 2904
# 2904
# 2905
# 2906
# 2907
# partial succes  995 out of 2908
# 2908
# 2909
# succes  588 out of 2910
# partial succes  996 out of 2910
# 2910
# succes  589 out of 2911
# partial succes  997 out of 2911
# 2911
# 2912
# 2913
# 2914
# 2915
# 2916
# 2917
# 2918
# 2919
# partial succes  998 out of 2920
# 2920
# 2921
# 2922
# 2923
# 2924
# 2925
# partial succes  999 out of 2926
# 2926
# 2927
# succes  590 out of 2928
# partial succes  1000 out of 2928
# 2928
# 2929
# 2930
# succes  591 out of 2931
# partial succes  1001 out of 2931
# 2931
# 2932
# succes  592 out of 2933
# partial succes  1002 out of 2933
# 2933
# succes  593 out of 2934
# partial succes  1003 out of 2934
# 2934
# 2935
# 2936
# 2937
# succes  594 out of 2938
# partial succes  1004 out of 2938
# 2938
# 2939
# 2940
# succes  595 out of 2941
# partial succes  1005 out of 2941
# 2941
# 2942
# 2943
# partial succes  1006 out of 2944
# 2944
# 2945
# 2946
# 2947
# partial succes  1007 out of 2948
# 2948
# partial succes  1008 out of 2949
# 2949
# succes  596 out of 2950
# partial succes  1009 out of 2950
# 2950
# 2951
# 2952
# 2953
# partial succes  1010 out of 2954
# 2954
# 2955
# partial succes  1011 out of 2956
# 2956
# 2957
# 2958
# partial succes  1012 out of 2959
# 2959
# 2960
# 2961
# 2962
# partial succes  1013 out of 2963
# 2963
# 2964
# 2965
# succes  597 out of 2966
# partial succes  1014 out of 2966
# 2966
# 2967
# partial succes  1015 out of 2968
# 2968
# 2969
# 2970
# succes  598 out of 2971
# partial succes  1016 out of 2971
# 2971
# succes  599 out of 2972
# partial succes  1017 out of 2972
# 2972
# 2973
# succes  600 out of 2974
# partial succes  1018 out of 2974
# 2974
# partial succes  1019 out of 2975
# 2975
# 2976
# 2977
# succes  601 out of 2978
# partial succes  1020 out of 2978
# 2978
# partial succes  1021 out of 2979
# 2979
# succes  602 out of 2980
# partial succes  1022 out of 2980
# 2980
# succes  603 out of 2981
# partial succes  1023 out of 2981
# 2981
# partial succes  1024 out of 2982
# 2982
# partial succes  1025 out of 2983
# 2983
# partial succes  1026 out of 2984
# 2984
# 2985
# succes  604 out of 2986
# partial succes  1027 out of 2986
# 2986
# 2987
# partial succes  1028 out of 2988
# 2988
# 2989
# 2990
# 2991
# 2992
# 2993
# 2994
# 2995
# 2996
# partial succes  1029 out of 2997
# 2997
# partial succes  1030 out of 2998
# 2998
# 2999
# 3000
# 3001
# 3002
# partial succes  1031 out of 3003
# 3003
# succes  605 out of 3004
# partial succes  1032 out of 3004
# 3004
# 3005
# 3006
# succes  606 out of 3007
# partial succes  1033 out of 3007
# 3007
# 3008
# succes  607 out of 3009
# partial succes  1034 out of 3009
# 3009
# partial succes  1035 out of 3010
# 3010
# 3011
# 3012
# 3013
# 3014
# 3015
# succes  608 out of 3016
# partial succes  1036 out of 3016
# 3016
# succes  609 out of 3017
# partial succes  1037 out of 3017
# 3017
# 3018
# 3019
# succes  610 out of 3020
# partial succes  1038 out of 3020
# 3020
# 3021
# 3022
# 3023
# 3024
# 3025
# 3026
# 3027
# 3028
# 3029
# 3030
# 3031
# 3032
# partial succes  1039 out of 3033
# 3033
# succes  611 out of 3034
# partial succes  1040 out of 3034
# 3034
# succes  612 out of 3035
# partial succes  1041 out of 3035
# 3035
# partial succes  1042 out of 3036
# 3036
# 3037
# 3038
# 3039
# 3040
# 3041
# 3042
# 3043
# 3044
# 3045
# 3046
# 3047
# succes  613 out of 3048
# partial succes  1043 out of 3048
# 3048
# 3049
# 3050
# 3051
# succes  614 out of 3052
# partial succes  1044 out of 3052
# 3052
# succes  615 out of 3053
# partial succes  1045 out of 3053
# 3053
# succes  616 out of 3054
# partial succes  1046 out of 3054
# 3054
# 3055
# 3056
# 3057
# 3058
# 3059
# 3060
# 3061
# partial succes  1047 out of 3062
# 3062
# 3063
# 3064
# 3065
# 3066
# 3067
# 3068
# succes  617 out of 3069
# partial succes  1048 out of 3069
# 3069
# 3070
# 3071
# partial succes  1049 out of 3072
# 3072
# 3073
# 3074
# 3075
# 3076
# succes  618 out of 3077
# partial succes  1050 out of 3077
# 3077
# 3078
# 3079
# succes  619 out of 3080
# partial succes  1051 out of 3080
# 3080
# 3081
# 3082
# succes  620 out of 3083
# partial succes  1052 out of 3083
# 3083
# 3084
# 3085
# succes  621 out of 3086
# partial succes  1053 out of 3086
# 3086
# 3087
# succes  622 out of 3088
# partial succes  1054 out of 3088
# 3088
# succes  623 out of 3089
# partial succes  1055 out of 3089
# 3089
# 3090
# succes  624 out of 3091
# partial succes  1056 out of 3091
# 3091
# 3092
# succes  625 out of 3093
# partial succes  1057 out of 3093
# 3093
# 3094
# partial succes  1058 out of 3095
# 3095
# 3096
# 3097
# 3098
# 3099
# partial succes  1059 out of 3100
# 3100
# 3101
# succes  626 out of 3102
# partial succes  1060 out of 3102
# 3102
# succes  627 out of 3103
# partial succes  1061 out of 3103
# 3103
# 3104
# 3105
# 3106
# 3107
# partial succes  1062 out of 3108
# 3108
# 3109
# 3110
# 3111
# 3112
# 3113
# succes  628 out of 3114
# partial succes  1063 out of 3114
# 3114
# 3115
# 3116
# partial succes  1064 out of 3117
# 3117
# 3118
# 3119
# 3120
# succes  629 out of 3121
# partial succes  1065 out of 3121
# 3121
# 3122
# 3123
# 3124
# 3125
# 3126
# 3127
# succes  630 out of 3128
# partial succes  1066 out of 3128
# 3128
# 3129
# partial succes  1067 out of 3130
# 3130
# 3131
# 3132
# 3133
# succes  631 out of 3134
# partial succes  1068 out of 3134
# 3134
# succes  632 out of 3135
# partial succes  1069 out of 3135
# 3135
# partial succes  1070 out of 3136
# 3136
# 3137
# partial succes  1071 out of 3138
# 3138
# 3139
# 3140
# 3141
# 3142
# succes  633 out of 3143
# partial succes  1072 out of 3143
# 3143
# succes  634 out of 3144
# partial succes  1073 out of 3144
# 3144
# succes  635 out of 3145
# partial succes  1074 out of 3145
# 3145
# 3146
# 3147
# succes  636 out of 3148
# partial succes  1075 out of 3148
# 3148
# 3149
# succes  637 out of 3150
# partial succes  1076 out of 3150
# 3150
# 3151
# succes  638 out of 3152
# partial succes  1077 out of 3152
# 3152
# succes  639 out of 3153
# partial succes  1078 out of 3153
# 3153
# succes  640 out of 3154
# partial succes  1079 out of 3154
# 3154
# succes  641 out of 3155
# partial succes  1080 out of 3155
# 3155
# succes  642 out of 3156
# partial succes  1081 out of 3156
# 3156
# partial succes  1082 out of 3157
# 3157
# 3158
# 3159
# partial succes  1083 out of 3160
# 3160
# 3161
# partial succes  1084 out of 3162
# 3162
# partial succes  1085 out of 3163
# 3163
# 3164
# 3165
# succes  643 out of 3166
# partial succes  1086 out of 3166
# 3166
# 3167
# succes  644 out of 3168
# partial succes  1087 out of 3168
# 3168
# 3169
# 3170
# 3171
# 3172
# succes  645 out of 3173
# partial succes  1088 out of 3173
# 3173
# 3174
# 3175
# succes  646 out of 3176
# partial succes  1089 out of 3176
# 3176
# 3177
# 3178
# 3179
# 3180
# 3181
# succes  647 out of 3182
# partial succes  1090 out of 3182
# 3182
# 3183
# partial succes  1091 out of 3184
# 3184
# 3185
# 3186
# 3187
# 3188
# partial succes  1092 out of 3189
# 3189
# 3190
# 3191
# 3192
# succes  648 out of 3193
# partial succes  1093 out of 3193
# 3193
# 3194
# 3195
# 3196
# 3197
# succes  649 out of 3198
# partial succes  1094 out of 3198
# 3198
# partial succes  1095 out of 3199
# 3199
# 3200
# 3201
# succes  650 out of 3202
# partial succes  1096 out of 3202
# 3202
# 3203
# 3204
# succes  651 out of 3205
# partial succes  1097 out of 3205
# 3205
# 3206
# 3207
# 3208
# 3209
# 3210
# succes  652 out of 3211
# partial succes  1098 out of 3211
# 3211
# partial succes  1099 out of 3212
# 3212
# 3213
# 3214
# 3215
# 3216
# 3217
# 3218
# 3219
# partial succes  1100 out of 3220
# 3220
# 3221
# 3222
# 3223
# 3224
# 3225
# 3226
# 3227
# 3228
# succes  653 out of 3229
# partial succes  1101 out of 3229
# 3229
# succes  654 out of 3230
# partial succes  1102 out of 3230
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# succes  655 out of 3236
# partial succes  1103 out of 3236
# 3236
# succes  656 out of 3237
# partial succes  1104 out of 3237
# 3237
# 3238
# succes  657 out of 3239
# partial succes  1105 out of 3239
# 3239
# 3240
# 3241
# partial succes  1106 out of 3242
# 3242
# 3243
# 3244
# 3245
# succes  658 out of 3246
# partial succes  1107 out of 3246
# 3246
# 3247
# succes  659 out of 3248
# partial succes  1108 out of 3248
# 3248
# 3249
# partial succes  1109 out of 3250
# 3250
# 3251
# 3252
# succes  660 out of 3253
# partial succes  1110 out of 3253
# 3253
# succes  661 out of 3254
# partial succes  1111 out of 3254
# 3254
# partial succes  1112 out of 3255
# 3255
# 3256
# 3257
# 3258
# 3259
# 3260
# 3261
# 3262
# partial succes  1113 out of 3263
# 3263
# 3264
# 3265
# 3266
# 3267
# partial succes  1114 out of 3268
# 3268
# 3269
# 3270
# 3271
# succes  662 out of 3272
# partial succes  1115 out of 3272
# 3272
# succes  663 out of 3273
# partial succes  1116 out of 3273
# 3273
# 3274
# succes  664 out of 3275
# partial succes  1117 out of 3275
# 3275
# partial succes  1118 out of 3276
# 3276
# 3277
# 3278
# 3279
# 3280
# 3281
# 3282
# succes  665 out of 3283
# partial succes  1119 out of 3283
# 3283
# succes  666 out of 3284
# partial succes  1120 out of 3284
# 3284
# succes  667 out of 3285
# partial succes  1121 out of 3285
# 3285
# succes  668 out of 3286
# partial succes  1122 out of 3286
# 3286
# ...
# 3467
# 3468
# succes  708 out of 3469
# partial succes  1187 out of 3469
# 3469
# 3470
# succes  709 out of 3471
# partial succes  1188 out of 3471
# 3471
# 3472
# succes  710 out of 3473
# partial succes  1189 out of 3473
# 3473
# 3474
# succes  711 out of 3475
# partial succes  1190 out of 3475
# 3475
# partial succes  1191 out of 3476
# 3476
# succes  712 out of 3477
# partial succes  1192 out of 3477
# 3477
# succes  713 out of 3478
# partial succes  1193 out of 3478
# 3478
# 3479
# 3480
# succes  714 out of 3481
# partial succes  1194 out of 3481
# 3481
# succes  715 out of 3482
# partial succes  1195 out of 3482
# 3482
# 3483
# succes  716 out of 3484
# partial succes  1196 out of 3484
# 3484
# 3485
# 3486
# partial succes  1197 out of 3487
# 3487
# partial succes  1198 out of 3488
# 3488
# 3489
# 3490
# 3491
# partial succes  1199 out of 3492
# 3492
# 3493
# 3494
# partial succes  1200 out of 3495
# 3495
# 3496
# succes  717 out of 3497
# partial succes  1201 out of 3497
# 3497
# 3498
# succes  718 out of 3499
# partial succes  1202 out of 3499
# 3499
# succes  719 out of 3500
# partial succes  1203 out of 3500
# 3500
# succes  720 out of 3501
# partial succes  1204 out of 3501
# 3501
# succes  721 out of 3502
# partial succes  1205 out of 3502
# 3502
# succes  722 out of 3503
# partial succes  1206 out of 3503
# 3503
# partial succes  1207 out of 3504
# 3504
# succes  723 out of 3505
# partial succes  1208 out of 3505
# 3505
# succes  724 out of 3506
# partial succes  1209 out of 3506
# 3506
# 3507
# 3508
# 3509
# succes  725 out of 3510
# partial succes  1210 out of 3510
# 3510
# 3511
# 3512
# 3513
# succes  726 out of 3514
# partial succes  1211 out of 3514
# 3514
# 3515
# 3516
# partial succes  1212 out of 3517
# 3517
# 3518
# 3519
# succes  727 out of 3520
# partial succes  1213 out of 3520
# 3520
# partial succes  1214 out of 3521
# 3521
# 3522
# succes  728 out of 3523
# partial succes  1215 out of 3523
# 3523
# 3524
# 3525
# 3526
# partial succes  1216 out of 3527
# 3527
# 3528
# succes  729 out of 3529
# partial succes  1217 out of 3529
# 3529
# partial succes  1218 out of 3530
# 3530
# 3531
# 3532
# 3533
# succes  730 out of 3534
# partial succes  1219 out of 3534
# 3534
# 3535
# 3536
# 3537
# 3538
# succes  731 out of 3539
# partial succes  1220 out of 3539
# 3539
# partial succes  1221 out of 3540
# 3540
# 3541
# 3542
# succes  732 out of 3543
# partial succes  1222 out of 3543
# 3543
# 3544
# 3545
# succes  733 out of 3546
# partial succes  1223 out of 3546
# 3546
# partial succes  1224 out of 3547
# 3547
# succes  734 out of 3548
# partial succes  1225 out of 3548
# 3548
# succes  735 out of 3549
# partial succes  1226 out of 3549
# 3549
# 3550
# 3551
# 3552
# 3553
# 3554
# 3555
# 3556
# succes  736 out of 3557
# partial succes  1227 out of 3557
# 3557
# 3558
# 3559
# partial succes  1228 out of 3560
# 3560
# 3561
# 3562
# succes  737 out of 3563
# partial succes  1229 out of 3563
# 3563
# partial succes  1230 out of 3564
# 3564
# 3565
# 3566
# 3567
# 3568
# 3569
# partial succes  1231 out of 3570
# 3570
# 3571
# 3572
# succes  738 out of 3573
# partial succes  1232 out of 3573
# 3573
# 3574
# 3575
# 3576
# 3577
# succes  739 out of 3578
# partial succes  1233 out of 3578
# 3578
# 3579
# 3580
# 3581
# 3582
# 3583
# 3584
# 3585
# succes  740 out of 3586
# partial succes  1234 out of 3586
# 3586
# 3587
# succes  741 out of 3588
# partial succes  1235 out of 3588
# 3588
# 3589
# succes  742 out of 3590
# partial succes  1236 out of 3590
# 3590
# succes  743 out of 3591
# partial succes  1237 out of 3591
# 3591
# 3592
# partial succes  1238 out of 3593
# 3593
# 3594
# partial succes  1239 out of 3595
# 3595
# 3596
# partial succes  1240 out of 3597
# 3597
# succes  744 out of 3598
# partial succes  1241 out of 3598
# 3598
# succes  745 out of 3599
# partial succes  1242 out of 3599
# 3599
# succes  746 out of 3600
# partial succes  1243 out of 3600
# 3600
# 3601
# 3602
# 3603
# 3604
# 3605
# 3606
# 3607
# 3608
# 3609
# partial succes  1244 out of 3610
# 3610
# 3611
# 3612
# 3613
# 3614
# 3615
# partial succes  1245 out of 3616
# 3616
# succes  747 out of 3617
# partial succes  1246 out of 3617
# 3617
# 3618
# 3619
# 3620
# 3621
# 3622
# succes  748 out of 3623
# partial succes  1247 out of 3623
# 3623
# partial succes  1248 out of 3624
# 3624
# 3625
# 3626
# 3627
# 3628
# 3629
# 3630
# succes  749 out of 3631
# partial succes  1249 out of 3631
# 3631
# 3632
# 3633
# 3634
# succes  750 out of 3635
# partial succes  1250 out of 3635
# 3635
# 3636
# partial succes  1251 out of 3637
# 3637
# partial succes  1252 out of 3638
# 3638
# 3639
# 3640
# 3641
# 3642
# 3643
# 3644
# 3645
# 3646
# 3647
# succes  751 out of 3648
# partial succes  1253 out of 3648
# 3648
# 3649
# 3650
# 3651
# partial succes  1254 out of 3652
# 3652
# 3653
# 3654
# succes  752 out of 3655
# partial succes  1255 out of 3655
# 3655
# 3656
# succes  753 out of 3657
# partial succes  1256 out of 3657
# 3657
# 3658
# succes  754 out of 3659
# partial succes  1257 out of 3659
# 3659
# 3660
# 3661
# 3662
# succes  755 out of 3663
# partial succes  1258 out of 3663
# 3663
# 3664
# 3665
# succes  756 out of 3666
# partial succes  1259 out of 3666
# 3666
# partial succes  1260 out of 3667
# 3667
# succes  757 out of 3668
# partial succes  1261 out of 3668
# 3668
# succes  758 out of 3669
# partial succes  1262 out of 3669
# 3669
# 3670
# 3671
# 3672
# 3673
# 3674
# 3675
# succes  759 out of 3676
# partial succes  1263 out of 3676
# 3676
# succes  760 out of 3677
# partial succes  1264 out of 3677
# 3677
# partial succes  1265 out of 3678
# 3678
# 3679
# succes  761 out of 3680
# partial succes  1266 out of 3680
# 3680
# succes  762 out of 3681
# partial succes  1267 out of 3681
# 3681
# 3682
# 3683
# succes  763 out of 3684
# partial succes  1268 out of 3684
# 3684
# succes  764 out of 3685
# partial succes  1269 out of 3685
# 3685
# succes  765 out of 3686
# partial succes  1270 out of 3686
# 3686
# 3687
# 3688
# 3689
# 3690
# 3691
# succes  766 out of 3692
# partial succes  1271 out of 3692
# 3692
# succes  767 out of 3693
# partial succes  1272 out of 3693
# 3693
# 3694
# 3695
# 3696
# 3697
# 3698
# 3699
# 3700
# 3701
# 3702
# succes  768 out of 3703
# partial succes  1273 out of 3703
# 3703
# succes  769 out of 3704
# partial succes  1274 out of 3704
# 3704
# succes  770 out of 3705
# partial succes  1275 out of 3705
# 3705
# 3706
# 3707
# 3708
# 3709
# 3710
# 3711
# partial succes  1276 out of 3712
# 3712
# partial succes  1277 out of 3713
# 3713
# 3714
# partial succes  1278 out of 3715
# 3715
# 3716
# 3717
# partial succes  1279 out of 3718
# 3718
# 3719
# 3720
# 3721
# 3722
# partial succes  1280 out of 3723
# 3723
# partial succes  1281 out of 3724
# 3724
# 3725
# 3726
# 3727
# 3728
# partial succes  1282 out of 3729
# 3729
# 3730
# 3731
# 3732
# 3733
# 3734
# 3735
# succes  771 out of 3736
# partial succes  1283 out of 3736
# 3736
# 3737
# 3738
# succes  772 out of 3739
# partial succes  1284 out of 3739
# 3739
# 3740
# partial succes  1285 out of 3741
# 3741
# 3742
# partial succes  1286 out of 3743
# 3743
# succes  773 out of 3744
# partial succes  1287 out of 3744
# 3744
# 3745
# 3746
# partial succes  1288 out of 3747
# 3747
# 3748
# 3749
# succes  774 out of 3750
# partial succes  1289 out of 3750
# 3750
# 3751
# 3752
# 3753
# succes  775 out of 3754
# partial succes  1290 out of 3754
# 3754
# 3755
# partial succes  1291 out of 3756
# 3756
# 3757
# 3758
# 3759
# 3760
# 3761
# 3762
# 3763
# partial succes  1292 out of 3764
# 3764
# partial succes  1293 out of 3765
# 3765
# 3766
# 3767
# succes  776 out of 3768
# partial succes  1294 out of 3768
# 3768
# 3769
# succes  777 out of 3770
# partial succes  1295 out of 3770
# 3770
# 3771
# 3772
# 3773
# partial succes  1296 out of 3774
# 3774
# 3775
# 3776
# 3777
# 3778
# 3779
# succes  778 out of 3780
# partial succes  1297 out of 3780
# 3780
# 3781
# partial succes  1298 out of 3782
# 3782
# partial succes  1299 out of 3783
# 3783
# 3784
# 3785
# 3786
# 3787
# succes  779 out of 3788
# partial succes  1300 out of 3788
# 3788
# succes  780 out of 3789
# partial succes  1301 out of 3789
# 3789
# 3790
# 3791
# 3792
# succes  781 out of 3793
# partial succes  1302 out of 3793
# 3793
# 3794
# succes  782 out of 3795
# partial succes  1303 out of 3795
# 3795
# partial succes  1304 out of 3796
# 3796
# 3797
# succes  783 out of 3798
# partial succes  1305 out of 3798
# 3798
# succes  784 out of 3799
# partial succes  1306 out of 3799
# 3799
# 3800
# succes  785 out of 3801
# partial succes  1307 out of 3801
# 3801
# 3802
# succes  786 out of 3803
# partial succes  1308 out of 3803
# 3803
# partial succes  1309 out of 3804
# 3804
# 3805
# 3806
# 3807
# succes  787 out of 3808
# partial succes  1310 out of 3808
# 3808
# 3809
# 3810
# 3811
# succes  788 out of 3812
# partial succes  1311 out of 3812
# 3812
# 3813
# 3814
# 3815
# 3816
# 3817
# 3818
# succes  789 out of 3819
# partial succes  1312 out of 3819
# 3819
# succes  790 out of 3820
# partial succes  1313 out of 3820
# 3820
# succes  791 out of 3821
# partial succes  1314 out of 3821
# 3821
# 3822
# succes  792 out of 3823
# partial succes  1315 out of 3823
# 3823
# 3824
# 3825
# 3826
# 3827
# 3828
# 3829
# 3830
# 3831
# succes  793 out of 3832
# partial succes  1316 out of 3832
# 3832
# partial succes  1317 out of 3833
# 3833
# 3834
# partial succes  1318 out of 3835
# 3835
# succes  794 out of 3836
# partial succes  1319 out of 3836
# 3836
# partial succes  1320 out of 3837
# 3837
# 3838
# succes  795 out of 3839
# partial succes  1321 out of 3839
# 3839
# 3840
# succes  796 out of 3841
# partial succes  1322 out of 3841
# 3841
# partial succes  1323 out of 3842
# 3842
# 3843
# partial succes  1324 out of 3844
# 3844
# 3845
# 3846
# 3847
# 3848
# 3849
# partial succes  1325 out of 3850
# 3850
# 3851
# 3852
# 3853
# succes  797 out of 3854
# partial succes  1326 out of 3854
# 3854
# succes  798 out of 3855
# partial succes  1327 out of 3855
# 3855
# 3856
# 3857
# succes  799 out of 3858
# partial succes  1328 out of 3858
# 3858
# succes  800 out of 3859
# partial succes  1329 out of 3859
# 3859
# 3860
# 3861
# 3862
# 3863
# 3864
# succes  801 out of 3865
# partial succes  1330 out of 3865
# 3865
# 3866
# 3867
# 3868
# 3869
# succes  802 out of 3870
# partial succes  1331 out of 3870
# 3870
# succes  803 out of 3871
# partial succes  1332 out of 3871
# 3871
# succes  804 out of 3872
# partial succes  1333 out of 3872
# 3872
# succes  805 out of 3873
# partial succes  1334 out of 3873
# 3873
# 3874
# 3875
# 3876
# 3877
# 3878
# partial succes  1335 out of 3879
# 3879
# succes  806 out of 3880
# partial succes  1336 out of 3880
# 3880
# 3881
# 3882
# succes  807 out of 3883
# partial succes  1337 out of 3883
# 3883
# 3884
# 3885
# 3886
# succes  808 out of 3887
# partial succes  1338 out of 3887
# 3887
# partial succes  1339 out of 3888
# 3888
# partial succes  1340 out of 3889
# 3889
# partial succes  1341 out of 3890
# 3890
# 3891
# succes  809 out of 3892
# partial succes  1342 out of 3892
# 3892
# 3893
# 3894
# 3895
# succes  810 out of 3896
# partial succes  1343 out of 3896
# 3896
# partial succes  1344 out of 3897
# 3897
# 3898
# 3899
# partial succes  1345 out of 3900
# 3900
# 3901
# 3902
# 3903
# 3904
# 3905
# 3906
# 3907
# partial succes  1346 out of 3908
# 3908
# 3909
# 3910
# succes  811 out of 3911
# partial succes  1347 out of 3911
# 3911
# 3912
# 3913
# succes  812 out of 3914
# partial succes  1348 out of 3914
# 3914
# succes  813 out of 3915
# partial succes  1349 out of 3915
# 3915
# 3916
# partial succes  1350 out of 3917
# 3917
# 3918
# 3919
# 3920
# 3921
# 3922
# 3923
# 3924
# 3925
# 3926
# succes  814 out of 3927
# partial succes  1351 out of 3927
# 3927
# 3928
# 3929
# succes  815 out of 3930
# partial succes  1352 out of 3930
# 3930
# 3931
# partial succes  1353 out of 3932
# 3932
# 3933
# partial succes  1354 out of 3934
# 3934
# 3935
# 3936
# succes  816 out of 3937
# partial succes  1355 out of 3937
# 3937
# 3938
# 3939
# partial succes  1356 out of 3940
# 3940
# succes  817 out of 3941
# partial succes  1357 out of 3941
# 3941
# 3942
# 3943
# 3944
# partial succes  1358 out of 3945
# 3945
# succes  818 out of 3946
# partial succes  1359 out of 3946
# 3946
# succes  819 out of 3947
# partial succes  1360 out of 3947
# 3947
# succes  820 out of 3948
# partial succes  1361 out of 3948
# 3948
# partial succes  1362 out of 3949
# 3949
# 3950
# succes  821 out of 3951
# partial succes  1363 out of 3951
# 3951
# 3952
# 3953
# 3954
# succes  822 out of 3955
# partial succes  1364 out of 3955
# 3955
# 3956
# succes  823 out of 3957
# partial succes  1365 out of 3957
# 3957
# 3958
# 3959
# 3960
# 3961
# partial succes  1366 out of 3962
# 3962
# 3963
# 3964
# 3965
# 3966
# 3967
# 3968
# succes  824 out of 3969
# partial succes  1367 out of 3969
# 3969
# 3970
# 3971
# partial succes  1368 out of 3972
# 3972
# 3973
# 3974
# partial succes  1369 out of 3975
# 3975
# succes  825 out of 3976
# partial succes  1370 out of 3976
# 3976
# 3977
# 3978
# partial succes  1371 out of 3979
# 3979
# succes  826 out of 3980
# partial succes  1372 out of 3980
# 3980
# 3981
# 3982
# 3983
# succes  827 out of 3984
# partial succes  1373 out of 3984
# 3984
# partial succes  1374 out of 3985
# 3985
# partial succes  1375 out of 3986
# 3986
# partial succes  1376 out of 3987
# 3987
# 3988
# 3989
# 3990
# 3991
# partial succes  1377 out of 3992
# 3992
# 3993
# 3994
# 3995
# 3996
# 3997
# 3998
# succes  828 out of 3999
# partial succes  1378 out of 3999
# 3999
# 4000
# 4001
# 4002
# partial succes  1379 out of 4003
# 4003
# partial succes  1380 out of 4004
# 4004
# 4005
# 4006
# partial succes  1381 out of 4007
# 4007
# 4008
# 4009
# 4010
# partial succes  1382 out of 4011
# 4011
# succes  829 out of 4012
# partial succes  1383 out of 4012
# 4012
# 4013
# partial succes  1384 out of 4014
# 4014
# 4015
# 4016
# 4017
# 4018
# succes  830 out of 4019
# partial succes  1385 out of 4019
# 4019
# 4020
# 4021
# 4022
# succes  831 out of 4023
# partial succes  1386 out of 4023
# 4023
# succes  832 out of 4024
# partial succes  1387 out of 4024
# 4024
# 4025
# 4026
# succes  833 out of 4027
# partial succes  1388 out of 4027
# 4027
# succes  834 out of 4028
# partial succes  1389 out of 4028
# 4028
# 4029
# 4030
# partial succes  1390 out of 4031
# 4031
# succes  835 out of 4032
# partial succes  1391 out of 4032
# 4032
# 4033
# 4034
# succes  836 out of 4035
# partial succes  1392 out of 4035
# 4035
# 4036
# 4037
# succes  837 out of 4038
# partial succes  1393 out of 4038
# 4038
# 4039
# 4040
# succes  838 out of 4041
# partial succes  1394 out of 4041
# 4041
# partial succes  1395 out of 4042
# 4042
# 4043
# 4044
# 4045
# 4046
# 4047
# 4048
# 4049
# succes  839 out of 4050
# partial succes  1396 out of 4050
# 4050
# partial succes  1397 out of 4051
# 4051
# partial succes  1398 out of 4052
# 4052
# 4053
# partial succes  1399 out of 4054
# 4054
# 4055
# 4056
# 4057
# 4058
# 4059
# 4060
# 4061
# partial succes  1400 out of 4062
# 4062
# 4063
# 4064
# 4065
# 4066
# 4067
# partial succes  1401 out of 4068
# 4068
# partial succes  1402 out of 4069
# 4069
# 4070
# partial succes  1403 out of 4071
# 4071
# succes  840 out of 4072
# partial succes  1404 out of 4072
# 4072
# 4073
# 4074
# 4075
# 4076
# 4077
# 4078
# 4079
# 4080
# 4081
# succes  841 out of 4082
# partial succes  1405 out of 4082
# 4082
# succes  842 out of 4083
# partial succes  1406 out of 4083
# 4083
# 4084
# 4085
# 4086
# 4087
# 4088
# 4089
# 4090
# 4091
# partial succes  1407 out of 4092
# 4092
# 4093
# partial succes  1408 out of 4094
# 4094
# 4095
# 4096
# 4097
# partial succes  1409 out of 4098
# 4098
# partial succes  1410 out of 4099
# 4099
# 4100
# 4101
# 4102
# 4103
# partial succes  1411 out of 4104
# 4104
# 4105
# succes  843 out of 4106
# partial succes  1412 out of 4106
# 4106
# 4107
# succes  844 out of 4108
# partial succes  1413 out of 4108
# 4108
# 4109
# succes  845 out of 4110
# partial succes  1414 out of 4110
# 4110
# 4111
# partial succes  1415 out of 4112
# 4112
# partial succes  1416 out of 4113
# 4113
# 4114
# partial succes  1417 out of 4115
# 4115
# succes  846 out of 4116
# partial succes  1418 out of 4116
# 4116
# 4117
# succes  847 out of 4118
# partial succes  1419 out of 4118
# 4118
# 4119
# 4120
# partial succes  1420 out of 4121
# 4121
# 4122
# partial succes  1421 out of 4123
# 4123
# 4124
# 4125
# partial succes  1422 out of 4126
# 4126
# 4127
# 4128
# 4129
# succes  848 out of 4130
# partial succes  1423 out of 4130
# 4130
# partial succes  1424 out of 4131
# 4131
# 4132
# 4133
# 4134
# 4135
# 4136
# 4137
# 4138
# partial succes  1425 out of 4139
# 4139
# 4140
# succes  849 out of 4141
# partial succes  1426 out of 4141
# 4141
# succes  850 out of 4142
# partial succes  1427 out of 4142
# 4142
# 4143
# succes  851 out of 4144
# partial succes  1428 out of 4144
# 4144
# succes  852 out of 4145
# partial succes  1429 out of 4145
# 4145
# 4146
# 4147
# 4148
# succes  853 out of 4149
# partial succes  1430 out of 4149
# 4149
# succes  854 out of 4150
# partial succes  1431 out of 4150
# 4150
# succes  855 out of 4151
# partial succes  1432 out of 4151
# 4151
# succes  856 out of 4152
# partial succes  1433 out of 4152
# 4152
# 4153
# 4154
# 4155
# succes  857 out of 4156
# partial succes  1434 out of 4156
# 4156
# 4157
# 4158
# 4159
# 4160
# partial succes  1435 out of 4161
# 4161
# succes  858 out of 4162
# partial succes  1436 out of 4162
# 4162
# 4163
# 4164
# 4165
# 4166
# succes  859 out of 4167
# partial succes  1437 out of 4167
# 4167
# 4168
# succes  860 out of 4169
# partial succes  1438 out of 4169
# 4169
# partial succes  1439 out of 4170
# 4170
# succes  861 out of 4171
# partial succes  1440 out of 4171
# 4171
# 4172
# 4173
# partial succes  1441 out of 4174
# 4174
# partial succes  1442 out of 4175
# 4175
# succes  862 out of 4176
# partial succes  1443 out of 4176
# 4176
# 4177
# succes  863 out of 4178
# partial succes  1444 out of 4178
# 4178
# partial succes  1445 out of 4179
# 4179
# 4180
# succes  864 out of 4181
# partial succes  1446 out of 4181
# 4181
# Exact match accuracy: 20.66%
# Partial match accuracy: 34.58%

# %% [markdown]
# 4%

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set_004, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size, dropout).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)

train(train_dataloader, encoder, decoder, 100000, print_every=1000, plot_every=500)

# %%
eval = [eval_set[i] for i in range(4182)]
encoder.eval()
decoder.eval()
result004 = evaluate(encoder, decoder, eval, input_vocab, output_vocab)
results.append(result004)

# %% [markdown]
# 8%

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set_008, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size, dropout).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)

train(train_dataloader, encoder, decoder, 100000, print_every=1000, plot_every=500)

# %%
eval = [eval_set[i] for i in range(4182)]
encoder.eval()
decoder.eval()
result008 = evaluate(encoder, decoder, eval, input_vocab, output_vocab)
results.append(result008)

# %% [markdown]
# 16%

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set_016, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size, dropout).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)

train(train_dataloader, encoder, decoder, 100000, print_every=1000, plot_every=500)
# Out:
# 0m 20s (- 34m 10s) (1000 1%) 0.9555
# 0m 38s (- 31m 37s) (2000 2%) 0.5306
# 0m 55s (- 29m 55s) (3000 3%) 0.3527
# 1m 12s (- 29m 3s) (4000 4%) 0.2420
# 1m 30s (- 28m 36s) (5000 5%) 0.1777
# 1m 47s (- 28m 6s) (6000 6%) 0.1358
# 2m 5s (- 27m 46s) (7000 7%) 0.1041
# 2m 22s (- 27m 23s) (8000 8%) 0.0907
# 2m 40s (- 26m 58s) (9000 9%) 0.0739
# 2m 56s (- 26m 32s) (10000 10%) 0.0650
# 3m 13s (- 26m 8s) (11000 11%) 0.0608
# 3m 31s (- 25m 50s) (12000 12%) 0.0515
# 3m 48s (- 25m 27s) (13000 13%) 0.0450
# 4m 5s (- 25m 6s) (14000 14%) 0.0423
# 4m 22s (- 24m 49s) (15000 15%) 0.0349
# 4m 39s (- 24m 29s) (16000 16%) 0.0343
# 4m 57s (- 24m 10s) (17000 17%) 0.0267
# 5m 13s (- 23m 50s) (18000 18%) 0.0327
# 5m 31s (- 23m 34s) (19000 19%) 0.0193
# 5m 49s (- 23m 18s) (20000 20%) 0.0253
# 6m 6s (- 22m 59s) (21000 21%) 0.0276
# 6m 24s (- 22m 44s) (22000 22%) 0.0219
# 6m 41s (- 22m 25s) (23000 23%) 0.0183
# 6m 59s (- 22m 7s) (24000 24%) 0.0189
# 7m 17s (- 21m 52s) (25000 25%) 0.0208
# 7m 34s (- 21m 33s) (26000 26%) 0.0106
# 7m 51s (- 21m 14s) (27000 27%) 0.0124
# 8m 8s (- 20m 57s) (28000 28%) 0.0182
# 8m 25s (- 20m 38s) (29000 28%) 0.0128
# 8m 43s (- 20m 20s) (30000 30%) 0.0104
# 9m 0s (- 20m 3s) (31000 31%) 0.0127
# 9m 17s (- 19m 45s) (32000 32%) 0.0106
# 9m 35s (- 19m 28s) (33000 33%) 0.0078
# 9m 52s (- 19m 10s) (34000 34%) 0.0192
# 10m 10s (- 18m 53s) (35000 35%) 0.0130
# 10m 27s (- 18m 36s) (36000 36%) 0.0065
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-1d8c50db7bda> in <cell line: 10>()
#       8 decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)
#       9
# ---> 10 train(train_dataloader, encoder, decoder, 100000, print_every=1000, plot_every=500)
#
# <ipython-input-17-b2ae206d090a> in train(train_dataloader, encoder, decoder, n_epochs, learning_rate, print_every, plot_every)
#      11
#      12     for epoch in range(1, n_epochs + 1):
# ---> 13         loss = train_epoch(train_dataloader, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
#      14         print_loss_total += loss
#      15         plot_loss_total += loss
#
# <ipython-input-20-5acb2f85ff65> in train_epoch(dataloader, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_norm)
#      11
#      12     encoder_outputs, encoder_hidden = encoder(input_tensor)
# ---> 13     decoder_outputs, _, _ = decoder(encoder_outputs, encoder_hidden, target_tensor)
#      14
#      15     #print("Decoder that get passed =", decoder_outputs.view(-1, decoder_outputs.size(-1)))
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# <ipython-input-13-80faa0153106> in forward(self, encoder_outputs, encoder_hidden, target_tensor)
#      24
#      25         for i in range(target_len):
# ---> 26             decoder_output, decoder_hidden  = self.forward_step(decoder_input, decoder_hidden)
#      27             decoder_outputs.append(decoder_output)
#      28             #print("decoder single output", decoder_output)
#
# <ipython-input-13-80faa0153106> in forward_step(self, input, hidden)
#      46         output = self.embedding(input)
#      47         output = F.relu(output)
# ---> 48         output, hidden = self.LSTM(output, hidden)
#      49         output = self.out(output)
#      50         return output, hidden
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     877
#     878         if batch_sizes is None:
# --> 879             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     880                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     881         else:
#
# KeyboardInterrupt:

# %%
eval = [eval_set[i] for i in range(4182)]
encoder.eval()
decoder.eval()
result016 = evaluate(encoder, decoder, eval, input_vocab, output_vocab)
results.append(result008)

# %% [markdown]
# full text

# %%
hidden_size = 200
batch_size = 1

train_dataset = CustomDataset(train_set, input_vocab, output_vocab)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)

encoder = EncoderLSTM(input_vocab.n_words, hidden_size, dropout).to(device)
decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)

train(train_dataloader, encoder, decoder, 100000, print_every=1000, plot_every=500)
# Out:
# 0m 21s (- 34m 55s) (1000 1%) 0.9421
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-efaa0ef06bd6> in <cell line: 10>()
#       8 decoder = DecoderLSTM(hidden_size, output_vocab.n_words).to(device)
#       9
# ---> 10 train(train_dataloader, encoder, decoder, 100000, print_every=1000, plot_every=500)
#
# <ipython-input-17-b2ae206d090a> in train(train_dataloader, encoder, decoder, n_epochs, learning_rate, print_every, plot_every)
#      11
#      12     for epoch in range(1, n_epochs + 1):
# ---> 13         loss = train_epoch(train_dataloader, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
#      14         print_loss_total += loss
#      15         plot_loss_total += loss
#
# <ipython-input-20-5acb2f85ff65> in train_epoch(dataloader, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_norm)
#      24     #print("decoder_outputs", decoder_outputs)
#      25     #print("target_tensor", target_tensor)
# ---> 26     loss.backward()
#      27
#      28     # Gradient clipping for both encoder and decoder
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     490                 inputs=inputs,
#     491             )
# --> 492         torch.autograd.backward(
#     493             self, gradient, retain_graph, create_graph, inputs=inputs
#     494         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     249     # some Python versions print out the first line of a multi-line function
#     250     # calls in the traceback and some print out the last line
# --> 251     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252         tensors,
#     253         grad_tensors_,
#
# KeyboardInterrupt:

# %%
eval = [eval_set[i] for i in range(4182)]
encoder.eval()
decoder.eval()
result= evaluate(encoder, decoder, eval, input_vocab, output_vocab)
